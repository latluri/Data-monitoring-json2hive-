# %%
import os
import sys
import re
import pandas as pd
import commands
import ast
from StringIO import StringIO
import itertools
import pyspark.sql.functions
from pyspark.sql.functions import col
from datetime import datetime
from collections import Counter
import re
import numpy as np
#from pyspark.sql import SparkSession
spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
if not os.path.isdir(spark_home):
    raise ValueError('SPARK_HOME environment variable is not a directory')
if not os.path.isdir(os.path.join(spark_home, 'python')):
    raise ValueError('SPARK_HOME directory does not contain python')
sys.path.insert(0, os.path.join(spark_home, 'python'))
pylib_list = (item for item in os.listdir(os.path.join(spark_home, 'python/lib/'))
              if re.match(r'py4j-\d+(\.\d+)+-src\.zip\Z', item)
              )
try:
    py4j_file = max(pylib_list)
    py4j = os.path.join(spark_home, os.path.join('python/lib', py4j_file))
except ValueError:
    raise ValueError(
        'Could not find py4j'
    )
sys.path.insert(0, py4j)

spark_release_file = spark_home + "/RELEASE"
if os.path.exists(spark_release_file) and "Spark" in  open(spark_release_file).read():
    pyspark_submit_args = os.environ.get("PYSPARK_SUBMIT_ARGS", " --master yarn-client \
                                         --executor-memory 4g --executor-cores 5 --driver-memory 16g"
                                        )
    if not "pyspark-shell" in pyspark_submit_args: pyspark_submit_args += " pyspark-shell"
    os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

with open(os.path.join(spark_home, 'python/pyspark/shell.py')) as f:
    code = compile(f.read(), os.path.join(spark_home, 'python/pyspark/shell.py'), 'exec')
    exec(code)
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.3.0.2.6.5.0-292
#       /_/
#
# Using Python version 2.7.15 (default, May  1 2018 23:32:55)
# SparkSession available as 'spark'.

# %%
database="dsc60230_gcct_tz_db"
sqlContext.sql("use "+database)
# Out:
# DataFrame[]

# %%
#Writes schema to excel file. All in one sheet uses the list of tables
df= pd.DataFrame(columns = ['col_name','data_type','table'])
writer = pd.ExcelWriter("GCCT_schema_Jan19.xlsx", engine = 'xlsxwriter')
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables(database).select('tableName').where("tableName not like '%temptz%'").where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%bad%'").collect():
for k in tab_list:
            #k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('desc '+k).toPandas()
            g1['table']=k
            g1=g1[['col_name','data_type','table']]
            df=df.append(g1, ignore_index=True)
            


df.to_excel(writer, sheet_name="sheet1", index=False)
writer.save()
writer.close()

# %%
#tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#df=pd.ExcelFile('/s/latluri1/DES/GCCT_schema_Jan19.xlsx').parse("sheet1")

# %%
commands.getstatusoutput("ls /s/latluri1/DES")[1].splitlines()
# Out:
# ['DESDEV_processed.csv',
#  'DESDEV.sql',
#  'DESDSC_Jan25_processed.csv',
#  'DESDSC_Jan25.sql',
#  'DESPRE-Prod_processed.csv',
#  'DESPRE-Prod.sql',
#  'DES_prod_processed.csv',
#  'DES_prod.sql',
#  'DESQA_processed.csv',
#  'DESQA.sql',
#  'DESscript_20190313_processed.csv',
#  'DESscript_20190313.sql',
#  'dev.xlsx',
#  'gcct_DES_added_cols.xlsx',
#  '~$GCCT_schema_Jan19.xlsx',
#  'GCCT_schema_Jan19.xlsx',
#  'pre_prod.xlsx',
#  '~$prod.xlsx',
#  'prod.xlsx',
#  'qa_mar_11.xlsx',
#  'sol_test.xlsx']

# %% [markdown]
# # DES_prod_processed.csv
# # DESQA_processed.csv
# # DESDSC_Jan25_processed.csv
# # DESDEV_processed.csv
# # DESscript_20190313_processed.csv
# # DESPRE-Prod_processed.csv',

# %%
old=df.apply(lambda x: x.astype(str).str.lower())
import xlrd
output_name='DESscript_20190313'
df_new=pd.read_csv('/s/latluri1/DES/DESscript_20190313_processed.csv')
new=df_new.apply(lambda x: x.astype(str).str.lower())

# %%
output_name
# Out:
# 'DESscript_20190313'

# %%
#bit->boolean
#uniqueidentifier->string
#datetime->timestamp
#bit->boolean
#nvarchar->string
#varchar->string
#timestamp->string

# %%
new.columns
# Out:
# Index([u'TABLE_NAME', u'COLUMN_NAME', u'DATA_TYPE', u'NUMERIC_PRECISION',
#        u'NUMERIC_SCALE'],
#       dtype='object')

# %%
set(list(new['DATA_TYPE']))
# Out:
# {'bigint',
#  'bit',
#  'datetime',
#  'decimal',
#  'float',
#  'int',
#  'nvarchar',
#  'timestamp',
#  'uniqueidentifier'}

# %%
#new=df_new.loc[new['DATA_TYPE'] == 'decimal' ]
#new.loc[pd.isnull(new['NUMERIC_SCALE']),['DATA_TYPE','NUMERIC_PRECISION','NUMERIC_SCALE']]
#new.loc[pd.isnull(new['NUMERIC_PRECISION']),['DATA_TYPE','NUMERIC_PRECISION','NUMERIC_SCALE']]

# %%
#df_new=df_new.loc[df_new['DATA_TYPE'] == 'decimal']
def get_decimal(a):
    if(a['DATA_TYPE']=='decimal'):
        if np.logical_not(pd.isnull(a['NUMERIC_PRECISION'])):
            if np.logical_not(pd.isnull(a['NUMERIC_SCALE'])):
                return(str(a['DATA_TYPE'])+"("+str(int(float(a['NUMERIC_PRECISION'])))+","+str(int(float(a['NUMERIC_SCALE'])))+")")
            else:
                return(str(a['DATA_TYPE'])+"("+str(int(float(a['NUMERIC_PRECISION'])))+")")
        else:
            return(a['DATA_TYPE'])
    else:
        return(a['DATA_TYPE'])
    
new.loc[:,'DATA_TYPE']=new[['DATA_TYPE','NUMERIC_PRECISION','NUMERIC_SCALE']].apply(lambda r: get_decimal(r), axis=1)

# %%
new
# Out:
#       TABLE_NAME                   COLUMN_NAME         DATA_TYPE  \
# 0        account              account_identity               int
# 1        account            account_rowversion         timestamp
# 2        account                            id  uniqueidentifier
# 3        account                 sinkcreatedon          datetime
# 4        account                sinkmodifiedon          datetime
# 5        account                     statecode               int
# 6        account                    statuscode               int
# 7        account              customertypecode               int
# 8        account     address1_freighttermscode               int
# 9        account      address1_addresstypecode               int
# 10       account     accountclassificationcode               int
# 11       account         gcct_bestdaytimephone               int
# 12       account            shippingmethodcode               int
# 13       account  preferredappointmenttimecode               int
# 14       account           gcct_preferredemail               int
# 15       account     address2_freighttermscode               int
# 16       account           accountcategorycode               int
# 17       account              paymenttermscode               int
# 18       account              businesstypecode               int
# 19       account                  industrycode               int
# 20       account          gcct_fleetstatuscode               int
# 21       account   address1_shippingmethodcode               int
# 22       account   preferredappointmentdaycode               int
# 23       account              customersizecode               int
# 24       account    preferredcontactmethodcode               int
# 25       account             accountratingcode               int
# 26       account              gcct_profiletype               int
# 27       account      address2_addresstypecode               int
# 28       account   address2_shippingmethodcode               int
# 29       account               gcct_dealertype               int
# ...          ...                           ...               ...
# 11411  territory                   description          nvarchar
# 11412  territory       gcct_territorygroupname          nvarchar
# 11413  territory         entityimage_timestamp            bigint
# 11414  territory                          name          nvarchar
# 11415  territory                 entityimageid  uniqueidentifier
# 11416  territory          importsequencenumber               int
# 11417  territory            organizationidname          nvarchar
# 11418  territory            modifiedbyyominame          nvarchar
# 11419  territory            gcct_territorycode          nvarchar
# 11420  territory     utcconversiontimezonecode               int
# 11421  territory             createdbyyominame          nvarchar
# 11422  territory                   territoryid  uniqueidentifier
# 11423  territory                modifiedbyname          nvarchar
# 11424  territory                 versionnumber            bigint
# 11425  territory     timezoneruleversionnumber               int
# 11426  territory            gcct_manageridname          nvarchar
# 11427  territory                     gcct_zone          nvarchar
# 11428  territory                    modifiedon          datetime
# 11429  territory                 manageridname          nvarchar
# 11430  territory                  exchangerate    decimal(38,10)
# 11431  territory             manageridyominame          nvarchar
# 11432  territory    modifiedonbehalfbyyominame          nvarchar
# 11433  territory                 createdbyname          nvarchar
# 11434  territory                     createdon          datetime
# 11435  territory         createdonbehalfbyname          nvarchar
# 11436  territory             gcct_facingregion          nvarchar
# 11437  territory        modifiedonbehalfbyname          nvarchar
# 11438  territory        gcct_manageridyominame          nvarchar
# 11439  territory           overriddencreatedon          datetime
# 11440  territory               entityimage_url          nvarchar
#
#       NUMERIC_PRECISION NUMERIC_SCALE
# 0              identity             1
# 1                   nan           nan
# 2                   not           nan
# 3                   nan           nan
# 4                   nan           nan
# 5                   nan           nan
# 6                   nan           nan
# 7                   nan           nan
# 8                   nan           nan
# 9                   nan           nan
# 10                  nan           nan
# 11                  nan           nan
# 12                  nan           nan
# 13                  nan           nan
# 14                  nan           nan
# 15                  nan           nan
# 16                  nan           nan
# 17                  nan           nan
# 18                  nan           nan
# 19                  nan           nan
# 20                  nan           nan
# 21                  nan           nan
# 22                  nan           nan
# 23                  nan           nan
# 24                  nan           nan
# 25                  nan           nan
# 26                  nan           nan
# 27                  nan           nan
# 28                  nan           nan
# 29                  nan           nan
# ...                 ...           ...
# 11411               max           nan
# 11412               200           nan
# 11413               nan           nan
# 11414               200           nan
# 11415               nan           nan
# 11416               nan           nan
# 11417               100           nan
# 11418               100           nan
# 11419               100           nan
# 11420               nan           nan
# 11421               100           nan
# 11422               nan           nan
# 11423               100           nan
# 11424               nan           nan
# 11425               nan           nan
# 11426               200           nan
# 11427                50           nan
# 11428               nan           nan
# 11429               100           nan
# 11430                38            10
# 11431               100           nan
# 11432               100           nan
# 11433               100           nan
# 11434               nan           nan
# 11435               100           nan
# 11436                50           nan
# 11437               100           nan
# 11438               200           nan
# 11439               nan           nan
# 11440               200           nan
#
# [11441 rows x 5 columns]

# %%
set(list(new['DATA_TYPE']))
# Out:
# {'bigint',
#  'bit',
#  'datetime',
#  'decimal(38,0)',
#  'decimal(38,10)',
#  'decimal(38,2)',
#  'decimal(38,3)',
#  'decimal(38,4)',
#  'decimal(38,5)',
#  'float',
#  'int',
#  'nvarchar',
#  'timestamp',
#  'uniqueidentifier'}

# %%
set(list(old['data_type']))
# Out:
# {'bigint',
#  'boolean',
#  'decimal(38,0)',
#  'decimal(38,10)',
#  'decimal(38,2)',
#  'decimal(38,3)',
#  'decimal(38,4)',
#  'decimal(38,5)',
#  'float',
#  'int',
#  'string',
#  'timestamp'}

# %%
new.loc[new['DATA_TYPE'] == 'nvarchar']
# Out:
#                   TABLE_CATALOG TABLE_SCHEMA               TABLE_NAME  \
# 6      fordgcctintegrationdesst          dbo              gcct_region
# 8      fordgcctintegrationdesst          dbo              gcct_region
# 10     fordgcctintegrationdesst          dbo              gcct_region
# 12     fordgcctintegrationdesst          dbo              gcct_region
# 14     fordgcctintegrationdesst          dbo              gcct_region
# 16     fordgcctintegrationdesst          dbo              gcct_region
# 18     fordgcctintegrationdesst          dbo              gcct_region
# 20     fordgcctintegrationdesst          dbo              gcct_region
# 21     fordgcctintegrationdesst          dbo              gcct_region
# 22     fordgcctintegrationdesst          dbo              gcct_region
# 23     fordgcctintegrationdesst          dbo              gcct_region
# 25     fordgcctintegrationdesst          dbo              gcct_region
# 27     fordgcctintegrationdesst          dbo              gcct_region
# 28     fordgcctintegrationdesst          dbo              gcct_region
# 30     fordgcctintegrationdesst          dbo              gcct_region
# 31     fordgcctintegrationdesst          dbo              gcct_region
# 32     fordgcctintegrationdesst          dbo              gcct_region
# 34     fordgcctintegrationdesst          dbo              gcct_region
# 35     fordgcctintegrationdesst          dbo              gcct_region
# 37     fordgcctintegrationdesst          dbo              gcct_region
# 38     fordgcctintegrationdesst          dbo              gcct_region
# 95     fordgcctintegrationdesst          dbo                 incident
# 97     fordgcctintegrationdesst          dbo                 incident
# 99     fordgcctintegrationdesst          dbo                 incident
# 101    fordgcctintegrationdesst          dbo                 incident
# 103    fordgcctintegrationdesst          dbo                 incident
# 105    fordgcctintegrationdesst          dbo                 incident
# 107    fordgcctintegrationdesst          dbo                 incident
# 109    fordgcctintegrationdesst          dbo                 incident
# 111    fordgcctintegrationdesst          dbo                 incident
# ...                         ...          ...                      ...
# 11397  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11399  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11401  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11403  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11405  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11406  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11407  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11409  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11410  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11413  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11415  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11418  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11419  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11420  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11421  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11426  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11428  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11429  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11430  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11431  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11432  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11437  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11438  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11439  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11441  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11442  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11443  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11444  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11447  fordgcctintegrationdesst          dbo  gcct_genericinformation
# 11449  fordgcctintegrationdesst          dbo  gcct_genericinformation
#
#                                     COLUMN_NAME ORDINAL_POSITION  \
# 6                         owninguser_entitytype                7
# 8                  createdonbehalfby_entitytype                9
# 10                owningbusinessunit_entitytype               11
# 12                        owningteam_entitytype               13
# 14                        modifiedby_entitytype               15
# 16                         createdby_entitytype               17
# 18                modifiedonbehalfby_entitytype               19
# 20                           ownerid_entitytype               21
# 21                    createdonbehalfbyyominame               22
# 22                                  owneridname               23
# 23                              gcct_regioncode               24
# 25                           modifiedbyyominame               26
# 27                            createdbyyominame               28
# 28                               modifiedbyname               29
# 30                                  owneridtype               31
# 31                                    gcct_name               32
# 32                              owneridyominame               33
# 34                   modifiedonbehalfbyyominame               35
# 35                                createdbyname               36
# 37                        createdonbehalfbyname               38
# 38                       modifiedonbehalfbyname               39
# 95                   socialprofileid_entitytype               54
# 97                    resolvebykpiid_entitytype               56
# 99               gcct_assigntoteamid_entitytype               58
# 101    gcct_caseclassificationlevel4_entitytype               60
# 103    gcct_caseclassificationlevel1_entitytype               62
# 105    gcct_caseclassificationlevel2_entitytype               64
# 107    gcct_caseclassificationlevel3_entitytype               66
# 109       gcct_enginespecificationid_entitytype               68
# 111    gcct_caseclassificationteamid_entitytype               70
# ...                                         ...              ...
# 11397                    gcct_legacy_modifiedby               58
# 11399                             traversedpath               60
# 11401                               owneridtype               62
# 11403                modifiedonbehalfbyyominame               64
# 11405                       sendermailboxidname               66
# 11406                 regardingobjectidyominame               67
# 11407                               owneridname               68
# 11409                          slainvokedidname               70
# 11410                            exchangeitemid               71
# 11413                 createdonbehalfbyyominame               74
# 11415                                   subject               76
# 11418                     regardingobjectidname               79
# 11419                  activityadditionalparams               80
# 11420                     createdonbehalfbyname               81
# 11421                          activitytypecode               82
# 11426                           owneridyominame               87
# 11428                               description               89
# 11429                                   slaname               90
# 11430                           gcct_teamidname               91
# 11431                             createdbyname               92
# 11432                   regardingobjecttypecode               93
# 11437                       gcct_teamidyominame               98
# 11438                         createdbyyominame               99
# 11439                 transactioncurrencyidname              100
# 11441                        modifiedbyyominame              102
# 11442                    modifiedonbehalfbyname              103
# 11443                             serviceidname              104
# 11444                           exchangeweblink              105
# 11447                            modifiedbyname              108
# 11449                  gcct_dm_source_record_id              110
#
#       COLUMN_DEFAULT IS_NULLABLE DATA_TYPE CHARACTER_MAXIMUM_LENGTH  \
# 6                nan         yes  nvarchar                    128.0
# 8                nan         yes  nvarchar                    128.0
# 10               nan         yes  nvarchar                    128.0
# 12               nan         yes  nvarchar                    128.0
# 14               nan         yes  nvarchar                    128.0
# 16               nan         yes  nvarchar                    128.0
# 18               nan         yes  nvarchar                    128.0
# 20               nan         yes  nvarchar                    128.0
# 21               nan         yes  nvarchar                    100.0
# 22               nan         yes  nvarchar                    100.0
# 23               nan         yes  nvarchar                    100.0
# 25               nan         yes  nvarchar                    100.0
# 27               nan         yes  nvarchar                    100.0
# 28               nan         yes  nvarchar                    100.0
# 30               nan         yes  nvarchar                   4000.0
# 31               nan         yes  nvarchar                    155.0
# 32               nan         yes  nvarchar                    100.0
# 34               nan         yes  nvarchar                    100.0
# 35               nan         yes  nvarchar                    100.0
# 37               nan         yes  nvarchar                    100.0
# 38               nan         yes  nvarchar                    100.0
# 95               nan         yes  nvarchar                    128.0
# 97               nan         yes  nvarchar                    128.0
# 99               nan         yes  nvarchar                    128.0
# 101              nan         yes  nvarchar                    128.0
# 103              nan         yes  nvarchar                    128.0
# 105              nan         yes  nvarchar                    128.0
# 107              nan         yes  nvarchar                    128.0
# 109              nan         yes  nvarchar                    128.0
# 111              nan         yes  nvarchar                    128.0
# ...              ...         ...       ...                      ...
# 11397            nan         yes  nvarchar                    100.0
# 11399            nan         yes  nvarchar                   1250.0
# 11401            nan         yes  nvarchar                   4000.0
# 11403            nan         yes  nvarchar                    100.0
# 11405            nan         yes  nvarchar                    100.0
# 11406            nan         yes  nvarchar                    400.0
# 11407            nan         yes  nvarchar                    100.0
# 11409            nan         yes  nvarchar                    100.0
# 11410            nan         yes  nvarchar                    200.0
# 11413            nan         yes  nvarchar                    100.0
# 11415            nan         yes  nvarchar                    200.0
# 11418            nan         yes  nvarchar                    400.0
# 11419            nan         yes  nvarchar                     -1.0
# 11420            nan         yes  nvarchar                    100.0
# 11421            nan         yes  nvarchar                   4000.0
# 11426            nan         yes  nvarchar                    100.0
# 11428            nan         yes  nvarchar                     -1.0
# 11429            nan         yes  nvarchar                    100.0
# 11430            nan         yes  nvarchar                    160.0
# 11431            nan         yes  nvarchar                    100.0
# 11432            nan         yes  nvarchar                   4000.0
# 11437            nan         yes  nvarchar                    160.0
# 11438            nan         yes  nvarchar                    100.0
# 11439            nan         yes  nvarchar                    100.0
# 11441            nan         yes  nvarchar                    100.0
# 11442            nan         yes  nvarchar                    100.0
# 11443            nan         yes  nvarchar                    100.0
# 11444            nan         yes  nvarchar                   1250.0
# 11447            nan         yes  nvarchar                    100.0
# 11449            nan         yes  nvarchar                    100.0
#
#       CHARACTER_OCTET_LENGTH     ...     DATETIME_PRECISION  \
# 6                      256.0     ...                    nan
# 8                      256.0     ...                    nan
# 10                     256.0     ...                    nan
# 12                     256.0     ...                    nan
# 14                     256.0     ...                    nan
# 16                     256.0     ...                    nan
# 18                     256.0     ...                    nan
# 20                     256.0     ...                    nan
# 21                     200.0     ...                    nan
# 22                     200.0     ...                    nan
# 23                     200.0     ...                    nan
# 25                     200.0     ...                    nan
# 27                     200.0     ...                    nan
# 28                     200.0     ...                    nan
# 30                    8000.0     ...                    nan
# 31                     310.0     ...                    nan
# 32                     200.0     ...                    nan
# 34                     200.0     ...                    nan
# 35                     200.0     ...                    nan
# 37                     200.0     ...                    nan
# 38                     200.0     ...                    nan
# 95                     256.0     ...                    nan
# 97                     256.0     ...                    nan
# 99                     256.0     ...                    nan
# 101                    256.0     ...                    nan
# 103                    256.0     ...                    nan
# 105                    256.0     ...                    nan
# 107                    256.0     ...                    nan
# 109                    256.0     ...                    nan
# 111                    256.0     ...                    nan
# ...                      ...     ...                    ...
# 11397                  200.0     ...                    nan
# 11399                 2500.0     ...                    nan
# 11401                 8000.0     ...                    nan
# 11403                  200.0     ...                    nan
# 11405                  200.0     ...                    nan
# 11406                  800.0     ...                    nan
# 11407                  200.0     ...                    nan
# 11409                  200.0     ...                    nan
# 11410                  400.0     ...                    nan
# 11413                  200.0     ...                    nan
# 11415                  400.0     ...                    nan
# 11418                  800.0     ...                    nan
# 11419                   -1.0     ...                    nan
# 11420                  200.0     ...                    nan
# 11421                 8000.0     ...                    nan
# 11426                  200.0     ...                    nan
# 11428                   -1.0     ...                    nan
# 11429                  200.0     ...                    nan
# 11430                  320.0     ...                    nan
# 11431                  200.0     ...                    nan
# 11432                 8000.0     ...                    nan
# 11437                  320.0     ...                    nan
# 11438                  200.0     ...                    nan
# 11439                  200.0     ...                    nan
# 11441                  200.0     ...                    nan
# 11442                  200.0     ...                    nan
# 11443                  200.0     ...                    nan
# 11444                 2500.0     ...                    nan
# 11447                  200.0     ...                    nan
# 11449                  200.0     ...                    nan
#
#       CHARACTER_SET_CATALOG CHARACTER_SET_SCHEMA CHARACTER_SET_NAME  \
# 6                       nan                  nan            unicode
# 8                       nan                  nan            unicode
# 10                      nan                  nan            unicode
# 12                      nan                  nan            unicode
# 14                      nan                  nan            unicode
# 16                      nan                  nan            unicode
# 18                      nan                  nan            unicode
# 20                      nan                  nan            unicode
# 21                      nan                  nan            unicode
# 22                      nan                  nan            unicode
# 23                      nan                  nan            unicode
# 25                      nan                  nan            unicode
# 27                      nan                  nan            unicode
# 28                      nan                  nan            unicode
# 30                      nan                  nan            unicode
# 31                      nan                  nan            unicode
# 32                      nan                  nan            unicode
# 34                      nan                  nan            unicode
# 35                      nan                  nan            unicode
# 37                      nan                  nan            unicode
# 38                      nan                  nan            unicode
# 95                      nan                  nan            unicode
# 97                      nan                  nan            unicode
# 99                      nan                  nan            unicode
# 101                     nan                  nan            unicode
# 103                     nan                  nan            unicode
# 105                     nan                  nan            unicode
# 107                     nan                  nan            unicode
# 109                     nan                  nan            unicode
# 111                     nan                  nan            unicode
# ...                     ...                  ...                ...
# 11397                   nan                  nan            unicode
# 11399                   nan                  nan            unicode
# 11401                   nan                  nan            unicode
# 11403                   nan                  nan            unicode
# 11405                   nan                  nan            unicode
# 11406                   nan                  nan            unicode
# 11407                   nan                  nan            unicode
# 11409                   nan                  nan            unicode
# 11410                   nan                  nan            unicode
# 11413                   nan                  nan            unicode
# 11415                   nan                  nan            unicode
# 11418                   nan                  nan            unicode
# 11419                   nan                  nan            unicode
# 11420                   nan                  nan            unicode
# 11421                   nan                  nan            unicode
# 11426                   nan                  nan            unicode
# 11428                   nan                  nan            unicode
# 11429                   nan                  nan            unicode
# 11430                   nan                  nan            unicode
# 11431                   nan                  nan            unicode
# 11432                   nan                  nan            unicode
# 11437                   nan                  nan            unicode
# 11438                   nan                  nan            unicode
# 11439                   nan                  nan            unicode
# 11441                   nan                  nan            unicode
# 11442                   nan                  nan            unicode
# 11443                   nan                  nan            unicode
# 11444                   nan                  nan            unicode
# 11447                   nan                  nan            unicode
# 11449                   nan                  nan            unicode
#
#       COLLATION_CATALOG COLLATION_SCHEMA                COLLATION_NAME  \
# 6                   nan              nan  sql_latin1_general_cp1_ci_as
# 8                   nan              nan  sql_latin1_general_cp1_ci_as
# 10                  nan              nan  sql_latin1_general_cp1_ci_as
# 12                  nan              nan  sql_latin1_general_cp1_ci_as
# 14                  nan              nan  sql_latin1_general_cp1_ci_as
# 16                  nan              nan  sql_latin1_general_cp1_ci_as
# 18                  nan              nan  sql_latin1_general_cp1_ci_as
# 20                  nan              nan  sql_latin1_general_cp1_ci_as
# 21                  nan              nan  sql_latin1_general_cp1_ci_as
# 22                  nan              nan  sql_latin1_general_cp1_ci_as
# 23                  nan              nan  sql_latin1_general_cp1_ci_as
# 25                  nan              nan  sql_latin1_general_cp1_ci_as
# 27                  nan              nan  sql_latin1_general_cp1_ci_as
# 28                  nan              nan  sql_latin1_general_cp1_ci_as
# 30                  nan              nan  sql_latin1_general_cp1_ci_as
# 31                  nan              nan  sql_latin1_general_cp1_ci_as
# 32                  nan              nan  sql_latin1_general_cp1_ci_as
# 34                  nan              nan  sql_latin1_general_cp1_ci_as
# 35                  nan              nan  sql_latin1_general_cp1_ci_as
# 37                  nan              nan  sql_latin1_general_cp1_ci_as
# 38                  nan              nan  sql_latin1_general_cp1_ci_as
# 95                  nan              nan  sql_latin1_general_cp1_ci_as
# 97                  nan              nan  sql_latin1_general_cp1_ci_as
# 99                  nan              nan  sql_latin1_general_cp1_ci_as
# 101                 nan              nan  sql_latin1_general_cp1_ci_as
# 103                 nan              nan  sql_latin1_general_cp1_ci_as
# 105                 nan              nan  sql_latin1_general_cp1_ci_as
# 107                 nan              nan  sql_latin1_general_cp1_ci_as
# 109                 nan              nan  sql_latin1_general_cp1_ci_as
# 111                 nan              nan  sql_latin1_general_cp1_ci_as
# ...                 ...              ...                           ...
# 11397               nan              nan  sql_latin1_general_cp1_ci_as
# 11399               nan              nan  sql_latin1_general_cp1_ci_as
# 11401               nan              nan  sql_latin1_general_cp1_ci_as
# 11403               nan              nan  sql_latin1_general_cp1_ci_as
# 11405               nan              nan  sql_latin1_general_cp1_ci_as
# 11406               nan              nan  sql_latin1_general_cp1_ci_as
# 11407               nan              nan  sql_latin1_general_cp1_ci_as
# 11409               nan              nan  sql_latin1_general_cp1_ci_as
# 11410               nan              nan  sql_latin1_general_cp1_ci_as
# 11413               nan              nan  sql_latin1_general_cp1_ci_as
# 11415               nan              nan  sql_latin1_general_cp1_ci_as
# 11418               nan              nan  sql_latin1_general_cp1_ci_as
# 11419               nan              nan  sql_latin1_general_cp1_ci_as
# 11420               nan              nan  sql_latin1_general_cp1_ci_as
# 11421               nan              nan  sql_latin1_general_cp1_ci_as
# 11426               nan              nan  sql_latin1_general_cp1_ci_as
# 11428               nan              nan  sql_latin1_general_cp1_ci_as
# 11429               nan              nan  sql_latin1_general_cp1_ci_as
# 11430               nan              nan  sql_latin1_general_cp1_ci_as
# 11431               nan              nan  sql_latin1_general_cp1_ci_as
# 11432               nan              nan  sql_latin1_general_cp1_ci_as
# 11437               nan              nan  sql_latin1_general_cp1_ci_as
# 11438               nan              nan  sql_latin1_general_cp1_ci_as
# 11439               nan              nan  sql_latin1_general_cp1_ci_as
# 11441               nan              nan  sql_latin1_general_cp1_ci_as
# 11442               nan              nan  sql_latin1_general_cp1_ci_as
# 11443               nan              nan  sql_latin1_general_cp1_ci_as
# 11444               nan              nan  sql_latin1_general_cp1_ci_as
# 11447               nan              nan  sql_latin1_general_cp1_ci_as
# 11449               nan              nan  sql_latin1_general_cp1_ci_as
#
#       DOMAIN_CATALOG DOMAIN_SCHEMA DOMAIN_NAME
# 6                nan           nan         nan
# 8                nan           nan         nan
# 10               nan           nan         nan
# 12               nan           nan         nan
# 14               nan           nan         nan
# 16               nan           nan         nan
# 18               nan           nan         nan
# 20               nan           nan         nan
# 21               nan           nan         nan
# 22               nan           nan         nan
# 23               nan           nan         nan
# 25               nan           nan         nan
# 27               nan           nan         nan
# 28               nan           nan         nan
# 30               nan           nan         nan
# 31               nan           nan         nan
# 32               nan           nan         nan
# 34               nan           nan         nan
# 35               nan           nan         nan
# 37               nan           nan         nan
# 38               nan           nan         nan
# 95               nan           nan         nan
# 97               nan           nan         nan
# 99               nan           nan         nan
# 101              nan           nan         nan
# 103              nan           nan         nan
# 105              nan           nan         nan
# 107              nan           nan         nan
# 109              nan           nan         nan
# 111              nan           nan         nan
# ...              ...           ...         ...
# 11397            nan           nan         nan
# 11399            nan           nan         nan
# 11401            nan           nan         nan
# 11403            nan           nan         nan
# 11405            nan           nan         nan
# 11406            nan           nan         nan
# 11407            nan           nan         nan
# 11409            nan           nan         nan
# 11410            nan           nan         nan
# 11413            nan           nan         nan
# 11415            nan           nan         nan
# 11418            nan           nan         nan
# 11419            nan           nan         nan
# 11420            nan           nan         nan
# 11421            nan           nan         nan
# 11426            nan           nan         nan
# 11428            nan           nan         nan
# 11429            nan           nan         nan
# 11430            nan           nan         nan
# 11431            nan           nan         nan
# 11432            nan           nan         nan
# 11437            nan           nan         nan
# 11438            nan           nan         nan
# 11439            nan           nan         nan
# 11441            nan           nan         nan
# 11442            nan           nan         nan
# 11443            nan           nan         nan
# 11444            nan           nan         nan
# 11447            nan           nan         nan
# 11449            nan           nan         nan
#
# [5327 rows x 23 columns]

# %%
# df['BrandName'].replace(['ABC', 'AB'], 'A')
#              conversionMap.put("int"                 , "int"      );
#              conversionMap.put("uniqueidentifier"   , "string"   );
#              conversionMap.put("datetime"            , "timestamp" );
#              conversionMap.put("bit"                 , "boolean"  );
#              conversionMap.put("nvarchar"            , "string"   );
#              conversionMap.put("decimal"             , "decimal"  );
#              conversionMap.put("bigint"              , "bigint"   );
#              conversionMap.put("timestamp"           , "string"   );
#              conversionMap.put("float"               , "float"    );


new.loc[:,'DATA_TYPE']=new['DATA_TYPE'].replace('bit', 'boolean')
new.loc[:,'DATA_TYPE']=new['DATA_TYPE'].replace(['uniqueidentifier','varchar','nvarchar'], 'string')
new.loc[:,'DATA_TYPE']=new['DATA_TYPE'].replace('timestamp', 'string')
new.loc[:,'DATA_TYPE']=new['DATA_TYPE'].replace('datetime', 'timestamp')

# %%
set(list(new['DATA_TYPE']))
# Out:
# {'bigint',
#  'boolean',
#  'decimal(38,0)',
#  'decimal(38,10)',
#  'decimal(38,2)',
#  'decimal(38,3)',
#  'decimal(38,4)',
#  'decimal(38,5)',
#  'float',
#  'int',
#  'string',
#  'timestamp'}

# %%
#new_df = pd.merge(A_df, B_df,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])
final_1=old.merge(new,how='outer',left_on=['table','col_name'],right_on=['TABLE_NAME','COLUMN_NAME'],suffixes=('_old','new') )
final_2=final_1[['TABLE_NAME','COLUMN_NAME','table','col_name','data_type','DATA_TYPE']]
final=final_2.loc[(final_2['TABLE_NAME'].isin(tab_list)) | (final_2['table'].isin(tab_list))]
#final.loc[:,'data_type']=final.data_type.apply(lambda x: x.strip())
#final.loc[:,'DATA_TYPE']=final.DATA_TYPE.apply(lambda x: x.strip())

# %%
print(len(old),len(new),len(final_1))
# Out:
# (12341, 11441, 12539)

# %%
#df[['Len_old', 'Len_new']].assign(NE=df.Len_old != df.Len_new)
#df.loc[df['A'] == 'foo']
delta=final[['TABLE_NAME','COLUMN_NAME','data_type', 'DATA_TYPE']].assign(NE=final.data_type != final.DATA_TYPE)
delta = delta.dropna(subset=['data_type','DATA_TYPE'])
delta.rename(columns={'TABLE_NAME':'Table_name','COLUMN_NAME':'Column_name','data_type':'Old_data_type(DSC)','DATA_TYPE':'New_data_type(DES)'}, inplace=True)

# %%
writer = pd.ExcelWriter("GCCT_schema_changes_"+output_name+".xlsx", engine = 'xlsxwriter')
dtype_changes=delta.loc[delta['NE'] == True]
#removed
ignore_list=['entityid','entitystring','eventdatetime','eventtype','lastupdatedatetime','lastupdtby','message__id','process__id','shakey']
#set(list(final.loc[final['TABLE_NAME'].isnull(),]['col_name']))
#removed=final.loc[(final['TABLE_NAME'].isnull()) &( np.logical_not(final['col_name'].isin(ignore_list))),]
#added
added=final.loc[final['table'].isnull(),['TABLE_NAME','COLUMN_NAME','DATA_TYPE']]


#Tables removed
#tab_removed_1=((set(list(final_1.table)).difference(set(list(final_1.TABLE_NAME)))).difference(set(tab_list)))
#tab_removed='tables added'+str(tab_removed_1).replace("set(","").replace(")","")
#Tables added
#tab_added_1=((set(list(final_1.TABLE_NAME)).difference(set(list(final_1.table)))).difference(set(tab_list)))
#tab_added='tables added'+str(tab_added_1).replace("set(","").replace(")","")

#Tables added
tab_added_1=set(list(final_1.TABLE_NAME)).difference(set(list(final_1.table)))
tables_added= pd.DataFrame({'Tables added': list(tab_added_1)})



#Tables removed
tab_removed_1=set(list(final_1.table)).difference(set(list(final_1.TABLE_NAME)))
tab_removed=pd.DataFrame({'Tables Removed':list(tab_removed_1)})

#this will ignore the columns in removed tables
removed=final.loc[(final['TABLE_NAME'].isnull()) &( np.logical_not(final['col_name'].isin(ignore_list))) & ( np.logical_not(final['table'].isin(tab_removed_1))),['table','col_name','data_type']]



dtype_changes.to_excel(writer, sheet_name="dtype_changes", index=False)
removed.to_excel(writer, sheet_name="removed_fields", index=False)
#removed_ignoring_removed_tables.to_excel(writer, sheet_name="removed_fields_addn", index=False)
added.to_excel(writer, sheet_name="fields added", index=False)
tables_added.to_excel(writer, sheet_name="Tables added", index=False)
tab_removed.to_excel(writer, sheet_name="Tables removed", index=False)



#dummy=pd.DataFrame()
#dummy.to_excel(writer, sheet_name="Tables", index=False)
#worksheet = writer.sheets["Tables"]
#worksheet.write(2, 0, tab_added)
#worksheet.write(4, 0, tab_removed)

#writer.write_cells(tab_added,sheet_name="Tables", startrow=4, startcol=0)
#writer.write_cells(tab_removed,sheet_name="Tables", startrow=8, startcol=0)
writer.save()
writer.close()

# %%
stmnt='echo \"Schema changes for GCCT when we compare DSC current schema with DES '+output_name+'\" | mailx -a GCCT_schema_changes_'+output_name+'.xlsx -s GCCT\ Schema\ Changes\ DSC\ VS\ DES\ '+output_name+' latluri1@ford.com'

# %%
print(stmnt)
# Out:
# echo "Schema changes for GCCT when we compare DSC current schema with DES DESscript_20190313" | mailx -a GCCT_schema_changes_DESscript_20190313.xlsx -s GCCT\ Schema\ Changes\ DSC\ VS\ DES\ DESscript_20190313 latluri1@ford.com

# %%
commands.getstatusoutput(stmnt)
# Out:
# (0, '')
