# %%
import os
import sys
import re
import pandas as pd
import commands
import ast
import itertools
import pyspark.sql.functions
from pyspark.sql.functions import col
from datetime import datetime
from collections import Counter
import re
import numpy as np
#from pyspark.sql import SparkSession
spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
if not os.path.isdir(spark_home):
    raise ValueError('SPARK_HOME environment variable is not a directory')
if not os.path.isdir(os.path.join(spark_home, 'python')):
    raise ValueError('SPARK_HOME directory does not contain python')
sys.path.insert(0, os.path.join(spark_home, 'python'))
pylib_list = (item for item in os.listdir(os.path.join(spark_home, 'python/lib/'))
              if re.match(r'py4j-\d+(\.\d+)+-src\.zip\Z', item)
              )
try:
    py4j_file = max(pylib_list)
    py4j = os.path.join(spark_home, os.path.join('python/lib', py4j_file))
except ValueError:
    raise ValueError(
        'Could not find py4j'
    )
sys.path.insert(0, py4j)

spark_release_file = spark_home + "/RELEASE"
if os.path.exists(spark_release_file) and "Spark" in  open(spark_release_file).read():
    pyspark_submit_args = os.environ.get("PYSPARK_SUBMIT_ARGS", " --master yarn-client \
                                         --executor-memory 4g --executor-cores 5 --driver-memory 16g"
                                        )
    if not "pyspark-shell" in pyspark_submit_args: pyspark_submit_args += " pyspark-shell"
    os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

with open(os.path.join(spark_home, 'python/pyspark/shell.py')) as f:
    code = compile(f.read(), os.path.join(spark_home, 'python/pyspark/shell.py'), 'exec')
    exec(code)
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.3.0.2.6.5.0-292
#       /_/
#
# Using Python version 2.7.15 (default, May  1 2018 23:32:55)
# SparkSession available as 'spark'.

# %%
sqlContext.sql("use dsc60230_gcct_tz_db")
# Out:
# DataFrame[]

# %%
import xlrd
old=pd.ExcelFile('/s/latluri1/GCCT_old.xlsx')
new=pd.ExcelFile('/s/latluri1/GCCT_new.xlsx')

# %%
common= set(old.sheet_names).intersection(new.sheet_names)
print(len(common),len(old.sheet_names),len(new.sheet_names))
# Out:
# (1, 1, 1)

# %%
a=new.parse("account")
b=old.parse("account")
a[a["col_name"]=='id']["data_type"].to_string(index=False)
str(b[b["col_name"]=='id']["data_type"].to_string(index=False))
# Out:
# 'string'

# %%
for sheet in common:
    a=new.parse(sheet)
    b=old.parse(sheet)
    for col in new.parse(sheet)["col_name"]:
        try:
            x1=str(a[a["col_name"]==col]["data_type"].to_string(index=False)).lower()
            x2=str(b[b["col_name"]==col]["data_type"].to_string(index=False)).lower()
        except:
            pass
        if(x2!='series([], )'):
            if(x1!=x2):
                    print str(sheet)+","+str(col)+","+"dtype changed"+","+x1+","+x2
        else:
            print str(sheet)+","+str(col)+","+"New column added"
# Out:
# gcct_specialloanercode,entityid,New column added
# gcct_specialloanercode,eventdatetime,New column added
# gcct_specialloanercode,eventtype,New column added
# msdyn_questionresponse,entityid,New column added
# msdyn_questionresponse,eventdatetime,New column added
# msdyn_questionresponse,eventtype,New column added
# phonecall,gcct_legacy_createdby,New column added
# phonecall,gcct_dm_source_record_id,New column added
# phonecall,gcct_legacy_modifiedon,New column added
# phonecall,gcct_legacy_modifiedby,New column added
# phonecall,entityid,New column added
# phonecall,eventdatetime,New column added
# phonecall,eventtype,New column added
# incidentresolution,entityid,New column added
# incidentresolution,eventdatetime,New column added
# incidentresolution,eventtype,New column added
# gcct_addportalmessage,gcct_legacy_createdby,New column added
# gcct_addportalmessage,gcct_legacy_modifiedby,New column added
# gcct_addportalmessage,gcct_legacy_modifiedon,New column added
# gcct_addportalmessage,gcct_dm_source_record_id,New column added
# gcct_addportalmessage,entityid,New column added
# gcct_addportalmessage,eventdatetime,New column added
# gcct_addportalmessage,eventtype,New column added
# gcct_priordealerdecision,gcct_priordealerdecision_identity,New column added
# gcct_priordealerdecision,gcct_priordealerdecision_rowversion,New column added
# gcct_priordealerdecision,entityid,New column added
# gcct_priordealerdecision,eventdatetime,New column added
# gcct_priordealerdecision,eventtype,New column added
# gcct_partsordersystems,gcct_partsordersystems_identity,New column added
# gcct_partsordersystems,gcct_partsordersystems_rowversion,New column added
# gcct_partsordersystems,entityid,New column added
# gcct_partsordersystems,eventdatetime,New column added
# gcct_partsordersystems,eventtype,New column added
# gcct_vehicleowner,gcct_sourcesystemid,New column added
# gcct_vehicleowner,gcct_sourcesystemname,New column added
# gcct_vehicleowner,gcct_dm_source_record_id,New column added
# gcct_vehicleowner,gcct_legacy_modifiedon,New column added
# gcct_vehicleowner,gcct_legacy_createdby,New column added
# gcct_vehicleowner,gcct_legacy_modifiedby,New column added
# gcct_vehicleowner,gcct_datasourcesystemname,New column added
# gcct_vehicleowner,entityid,New column added
# gcct_vehicleowner,eventdatetime,New column added
# gcct_vehicleowner,eventtype,New column added
# gcct_warrantyloanerrequest,gcct_vehicleoffroad,dtype changed,int,boolean
# gcct_warrantyloanerrequest,gcct_customerinrental,dtype changed,int,boolean
# gcct_warrantyloanerrequest,gcct_vehiclemodelcostfound,New column added
# gcct_warrantyloanerrequest,gcct_legacy_modifiedby,New column added
# gcct_warrantyloanerrequest,gcct_legacy_createdby,New column added
# gcct_warrantyloanerrequest,gcct_dm_source_record_id,New column added
# gcct_warrantyloanerrequest,gcct_legacy_modifiedon,New column added
# gcct_warrantyloanerrequest,entityid,New column added
# gcct_warrantyloanerrequest,eventdatetime,New column added
# gcct_warrantyloanerrequest,eventtype,New column added
# gcct_sms,entityid,New column added
# gcct_sms,eventdatetime,New column added
# gcct_sms,eventtype,New column added
# gcct_surveyconfiguration,entityid,New column added
# gcct_surveyconfiguration,eventdatetime,New column added
# gcct_surveyconfiguration,eventtype,New column added
# msdyn_surveyresponse,entityid,New column added
# msdyn_surveyresponse,eventdatetime,New column added
# msdyn_surveyresponse,eventtype,New column added
# gcct_symptomclassification,gcct_isfullsymptomclassification,New column added
# gcct_symptomclassification,entityid,New column added
# gcct_symptomclassification,eventdatetime,New column added
# gcct_symptomclassification,eventtype,New column added
# fax,gcct_legacy_createdby,New column added
# fax,gcct_datasourcesystemname,New column added
# fax,gcct_dm_source_record_id,New column added
# fax,gcct_legacy_modifiedon,New column added
# fax,gcct_legacy_modifiedby,New column added
# fax,entityid,New column added
# fax,eventdatetime,New column added
# fax,eventtype,New column added
# statusmetadata,entityid,New column added
# statusmetadata,eventdatetime,New column added
# statusmetadata,eventtype,New column added
# appointment,gcct_legacy_createdby,New column added
# appointment,gcct_legacy_modifiedby,New column added
# appointment,gcct_legacy_modifiedon,New column added
# appointment,gcct_dm_source_record_id,New column added
# appointment,entityid,New column added
# appointment,eventdatetime,New column added
# appointment,eventtype,New column added
# activityparty,entityid,New column added
# activityparty,eventdatetime,New column added
# activityparty,eventtype,New column added
# gcct_vehicle,gcct_legacy_createdby,New column added
# gcct_vehicle,gcct_sourcesystemname,New column added
# gcct_vehicle,gcct_dm_source_record_id,New column added
# gcct_vehicle,gcct_legacy_modifiedon,New column added
# gcct_vehicle,gcct_legacy_modifiedby,New column added
# gcct_vehicle,entityid,New column added
# gcct_vehicle,eventdatetime,New column added
# gcct_vehicle,eventtype,New column added
# gcct_onlinegaragevehicles,gcct_onlinegaragevehicles_identity,New column added
# gcct_onlinegaragevehicles,gcct_onlinegaragevehicles_rowversion,New column added
# gcct_onlinegaragevehicles,entityid,New column added
# gcct_onlinegaragevehicles,eventdatetime,New column added
# gcct_onlinegaragevehicles,eventtype,New column added
# gcct_region,entityid,New column added
# gcct_region,eventdatetime,New column added
# gcct_region,eventtype,New column added
# gcct_vehicleoffroad,entityid,New column added
# gcct_vehicleoffroad,eventdatetime,New column added
# gcct_vehicleoffroad,eventtype,New column added
# gcct_executiveliaison,entityid,New column added
# gcct_executiveliaison,eventdatetime,New column added
# gcct_executiveliaison,eventtype,New column added
# gcct_caseclassification,gcct_isfullcaseclassification,New column added
# gcct_caseclassification,entityid,New column added
# gcct_caseclassification,eventdatetime,New column added
# gcct_caseclassification,eventtype,New column added
# gcct_fmcccontract,gcct_fmcccontract_identity,New column added
# gcct_fmcccontract,gcct_fmcccontract_rowversion,New column added
# gcct_fmcccontract,ccof_donotcall,New column added
# gcct_fmcccontract,ccof_buyerid,New column added
# gcct_fmcccontract,ccof_buyerid_entitytype,New column added
# gcct_fmcccontract,ccof_vinid,New column added
# gcct_fmcccontract,ccof_vinid_entitytype,New column added
# gcct_fmcccontract,ccof_cobuyerid,New column added
# gcct_fmcccontract,ccof_cobuyerid_entitytype,New column added
# gcct_fmcccontract,ccof_servicingdealerid,New column added
# gcct_fmcccontract,ccof_servicingdealerid_entitytype,New column added
# gcct_fmcccontract,ccof_country,New column added
# gcct_fmcccontract,ccof_country_entitytype,New column added
# gcct_fmcccontract,ccof_buyeridname,New column added
# gcct_fmcccontract,ccof_contractstateprovince,New column added
# gcct_fmcccontract,ccof_stateprovince,New column added
# gcct_fmcccontract,ccof_financelabel,New column added
# gcct_fmcccontract,ccof_collateralmodelyear,New column added
# gcct_fmcccontract,ccof_buyeridyominame,New column added
# gcct_fmcccontract,ccof_cobuyeridname,New column added
# gcct_fmcccontract,ccof_addressline2,New column added
# gcct_fmcccontract,ccof_sourcesystemid,New column added
# gcct_fmcccontract,ccof_collateralmodel,New column added
# gcct_fmcccontract,ccof_addressline1,New column added
# gcct_fmcccontract,ccof_product,New column added
# gcct_fmcccontract,ccof_cobuyeridyominame,New column added
# gcct_fmcccontract,ccof_zippostalcode,New column added
# gcct_fmcccontract,ccof_collateralmake,New column added
# gcct_fmcccontract,ccof_companybusinesscode,New column added
# gcct_fmcccontract,ccof_vin,New column added
# gcct_fmcccontract,ccof_vinidname,New column added
# gcct_fmcccontract,ccof_countryname,New column added
# gcct_fmcccontract,ccof_servicingdealeridname,New column added
# gcct_fmcccontract,ccof_servicingdealeridyominame,New column added
# gcct_fmcccontract,ccof_sourcesystemname,New column added
# gcct_fmcccontract,ccof_businesscenter,New column added
# gcct_fmcccontract,entityid,New column added
# gcct_fmcccontract,eventdatetime,New column added
# gcct_fmcccontract,eventtype,New column added
# gcct_qamonitoring,entityid,New column added
# gcct_qamonitoring,eventdatetime,New column added
# gcct_qamonitoring,eventtype,New column added
# team,gcct_defaultsettings,New column added
# team,entityid,New column added
# team,eventdatetime,New column added
# team,eventtype,New column added
# gcct_recall,gcct_legacy_createdby,New column added
# gcct_recall,gcct_legacy_modifiedby,New column added
# gcct_recall,gcct_dm_source_record_id,New column added
# gcct_recall,gcct_legacy_modifiedon,New column added
# gcct_recall,entityid,New column added
# gcct_recall,eventdatetime,New column added
# gcct_recall,eventtype,New column added
# msdyn_survey,entityid,New column added
# msdyn_survey,eventdatetime,New column added
# msdyn_survey,eventtype,New column added
# gcct_country,entityid,New column added
# gcct_country,eventdatetime,New column added
# gcct_country,eventtype,New column added
# statemetadata,entityid,New column added
# statemetadata,eventdatetime,New column added
# statemetadata,eventtype,New column added
# gcct_materialrequest,gcct_legacy_createdby,New column added
# gcct_materialrequest,gcct_datasourcesystemname,New column added
# gcct_materialrequest,gcct_legacy_modifiedon,New column added
# gcct_materialrequest,gcct_legacy_modifiedby,New column added
# gcct_materialrequest,gcct_dm_source_record_id,New column added
# gcct_materialrequest,entityid,New column added
# gcct_materialrequest,eventdatetime,New column added
# gcct_materialrequest,eventtype,New column added
# calendar,entityid,New column added
# calendar,eventdatetime,New column added
# calendar,eventtype,New column added
# calendarrule,entityid,New column added
# calendarrule,eventdatetime,New column added
# calendarrule,eventtype,New column added
# email,gcct_legacy_createdby,New column added
# email,gcct_dm_source_record_id,New column added
# email,gcct_legacy_modifiedon,New column added
# email,gcct_datasourcesystemname,New column added
# email,gcct_legacy_modifiedby,New column added
# email,entityid,New column added
# email,eventdatetime,New column added
# email,eventtype,New column added
# socialactivity,entityid,New column added
# socialactivity,eventdatetime,New column added
# socialactivity,eventtype,New column added
# gcct_vehiclebrand,entityid,New column added
# gcct_vehiclebrand,eventdatetime,New column added
# gcct_vehiclebrand,eventtype,New column added
# gcct_loanercost,gcct_loanercost_identity,New column added
# gcct_loanercost,gcct_loanercost_rowversion,New column added
# gcct_loanercost,entityid,New column added
# gcct_loanercost,eventdatetime,New column added
# gcct_loanercost,eventtype,New column added
# gcct_executive,gcct_executive_identity,New column added
# gcct_executive,gcct_executive_rowversion,New column added
# gcct_executive,entityid,New column added
# gcct_executive,eventdatetime,New column added
# gcct_executive,eventtype,New column added
# optionsetmetadata,entityid,New column added
# optionsetmetadata,eventdatetime,New column added
# optionsetmetadata,eventtype,New column added
# cxlvhlp_chatqueuestatistic,entityid,New column added
# cxlvhlp_chatqueuestatistic,eventdatetime,New column added
# cxlvhlp_chatqueuestatistic,eventtype,New column added
# gcct_delegationofauthority,gcct_delegationofauthority_identity,New column added
# gcct_delegationofauthority,gcct_delegationofauthority_rowversion,New column added
# gcct_delegationofauthority,entityid,New column added
# gcct_delegationofauthority,eventdatetime,New column added
# gcct_delegationofauthority,eventtype,New column added
# incident,gcct_legacy_createdby,New column added
# incident,gcct_dm_source_record_id,New column added
# incident,gcct_customerdelegaterelaationship,New column added
# incident,gcct_legacy_modifiedon,New column added
# incident,ccof_caserecordurlhidden,New column added
# incident,gcct_legacy_modifiedby,New column added
# incident,entityid,New column added
# incident,eventdatetime,New column added
# incident,eventtype,New column added
# gcct_vehicleclass,gcct_isfullvehcileclassification,New column added
# gcct_vehicleclass,gcct_code,New column added
# gcct_vehicleclass,entityid,New column added
# gcct_vehicleclass,eventdatetime,New column added
# gcct_vehicleclass,eventtype,New column added
# gcct_socialmediaconversation,entityid,New column added
# gcct_socialmediaconversation,eventdatetime,New column added
# gcct_socialmediaconversation,eventtype,New column added
# gcct_rentaldetail,gcct_rental_detailsid,New column added
# gcct_rentaldetail,gcct_rental_detailsid_entitytype,New column added
# gcct_rentaldetail,gcct_wl_rental_detailsid,New column added
# gcct_rentaldetail,gcct_wl_rental_detailsid_entitytype,New column added
# gcct_rentaldetail,gcct_rentaldetailid,New column added
# gcct_rentaldetail,gcct_rentaldetailid_entitytype,New column added
# gcct_rentaldetail,gcct_rentaldetailsid,New column added
# gcct_rentaldetail,gcct_rentaldetailsid_entitytype,New column added
# gcct_rentaldetail,gcct_rentaldailycost_base,dtype changed,decimal(38,2),decimal(38,4)
# gcct_rentaldetail,gcct_rentaldailycost,dtype changed,decimal(38,2),decimal(38,4)
# gcct_rentaldetail,gcct_legacy_createdby,New column added
# gcct_rentaldetail,gcct_rentaldetailidname,New column added
# gcct_rentaldetail,gcct_rental_detailsidname,New column added
# gcct_rentaldetail,gcct_dm_source_record_id,New column added
# gcct_rentaldetail,gcct_legacy_modifiedon,New column added
# gcct_rentaldetail,gcct_wl_rental_detailsidname,New column added
# gcct_rentaldetail,gcct_rentaldetailsidname,New column added
# gcct_rentaldetail,gcct_legacy_modifiedby,New column added
# gcct_rentaldetail,entityid,New column added
# gcct_rentaldetail,eventdatetime,New column added
# gcct_rentaldetail,eventtype,New column added
# gcct_warrantyloanerrequesthisto,gcct_systemapprovedmaxdays,New column added
# gcct_warrantyloanerrequesthisto,entityid,New column added
# gcct_warrantyloanerrequesthisto,eventdatetime,New column added
# gcct_warrantyloanerrequesthisto,eventtype,New column added
# slaitem,entityid,New column added
# slaitem,eventdatetime,New column added
# slaitem,eventtype,New column added
# gcct_engine,entityid,New column added
# gcct_engine,eventdatetime,New column added
# gcct_engine,eventtype,New column added
# queue,entityid,New column added
# queue,eventdatetime,New column added
# queue,eventtype,New column added
# gcct_technicalassistancerequest,gcct_customerinrental,New column added
# gcct_technicalassistancerequest,gcct_rentaldetailactivityid,New column added
# gcct_technicalassistancerequest,gcct_rentaldetailactivityid_entitytype,New column added
# gcct_technicalassistancerequest,gcct_legacy_createdby,New column added
# gcct_technicalassistancerequest,gcct_rentaldetailactivityidname,New column added
# gcct_technicalassistancerequest,gcct_dm_source_record_id,New column added
# gcct_technicalassistancerequest,gcct_legacy_modifiedon,New column added
# gcct_technicalassistancerequest,gcct_legacy_modifiedby,New column added
# gcct_technicalassistancerequest,entityid,New column added
# gcct_technicalassistancerequest,eventdatetime,New column added
# gcct_technicalassistancerequest,eventtype,New column added
# gcct_loyaltycostdetails,gcct_legacy_createdby,New column added
# gcct_loyaltycostdetails,gcct_legacy_modifiedby,New column added
# gcct_loyaltycostdetails,gcct_dm_source_record_id,New column added
# gcct_loyaltycostdetails,gcct_legacy_modifiedon,New column added
# gcct_loyaltycostdetails,entityid,New column added
# gcct_loyaltycostdetails,eventdatetime,New column added
# gcct_loyaltycostdetails,eventtype,New column added
# socialprofile,entityid,New column added
# socialprofile,eventdatetime,New column added
# socialprofile,eventtype,New column added
# gcct_userdelegationofauthority,entityid,New column added
# gcct_userdelegationofauthority,eventdatetime,New column added
# gcct_userdelegationofauthority,eventtype,New column added
# gcct_pcarequest,gcct_legacy_createdby,New column added
# gcct_pcarequest,gcct_dm_source_record_id,New column added
# gcct_pcarequest,gcct_legacy_modifiedon,New column added
# gcct_pcarequest,gcct_legacy_modifiedby,New column added
# gcct_pcarequest,entityid,New column added
# gcct_pcarequest,eventdatetime,New column added
# gcct_pcarequest,eventtype,New column added
# gcct_offerdetail,gcct_offerdetail_identity,New column added
# gcct_offerdetail,gcct_offerdetail_rowversion,New column added
# gcct_offerdetail,gcct_dm_source_record_id,New column added
# gcct_offerdetail,gcct_legacy_createdby,New column added
# gcct_offerdetail,gcct_legacy_modifiedby,New column added
# gcct_offerdetail,gcct_legacy_modifiedon,New column added
# gcct_offerdetail,entityid,New column added
# gcct_offerdetail,eventdatetime,New column added
# gcct_offerdetail,eventtype,New column added
# letter,gcct_legacy_createdby,New column added
# letter,gcct_datasourcesystemname,New column added
# letter,gcct_legacy_modifiedon,New column added
# letter,gcct_legacy_modifiedby,New column added
# letter,gcct_dm_source_record_id,New column added
# letter,entityid,New column added
# letter,eventdatetime,New column added
# letter,eventtype,New column added
# gcct_socialmediamessage,gcct_socialmediaconversationid,New column added
# gcct_socialmediamessage,gcct_socialmediaconversationid_entitytype,New column added
# gcct_socialmediamessage,gcct_socialmediaconversationidname,New column added
# gcct_socialmediamessage,entityid,New column added
# gcct_socialmediamessage,eventdatetime,New column added
# gcct_socialmediamessage,eventtype,New column added
# gcct_lemonlawcriteria,gcct_lemonlawcriteria_identity,New column added
# gcct_lemonlawcriteria,gcct_lemonlawcriteria_rowversion,New column added
# gcct_lemonlawcriteria,entityid,New column added
# gcct_lemonlawcriteria,eventdatetime,New column added
# gcct_lemonlawcriteria,eventtype,New column added
# gcct_goodfaithreview,gcct_legacy_createdby,New column added
# gcct_goodfaithreview,gcct_legacy_modifiedon,New column added
# gcct_goodfaithreview,gcct_dm_source_record_id,New column added
# gcct_goodfaithreview,gcct_legacy_modifiedby,New column added
# gcct_goodfaithreview,entityid,New column added
# gcct_goodfaithreview,eventdatetime,New column added
# gcct_goodfaithreview,eventtype,New column added
# gcct_coachback,gcct_legacy_createdby,New column added
# gcct_coachback,gcct_legacy_modifiedby,New column added
# gcct_coachback,gcct_dm_source_record_id,New column added
# gcct_coachback,gcct_legacy_modifiedon,New column added
# gcct_coachback,entityid,New column added
# gcct_coachback,eventdatetime,New column added
# gcct_coachback,eventtype,New column added
# gcct_loyaltyprogramcode,gcct_loyaltyprogramcode_identity,New column added
# gcct_loyaltyprogramcode,gcct_loyaltyprogramcode_rowversion,New column added
# gcct_loyaltyprogramcode,entityid,New column added
# gcct_loyaltyprogramcode,eventdatetime,New column added
# gcct_loyaltyprogramcode,eventtype,New column added
# gcct_loyaltyassistance,gcct_vehicleoffroad,dtype changed,int,boolean
# gcct_loyaltyassistance,gcct_customerinrental,dtype changed,int,boolean
# gcct_loyaltyassistance,gcct_doesthevehiclehaveanonfordlincolnesp,New column added
# gcct_loyaltyassistance,gcct_legacy_createdby,New column added
# gcct_loyaltyassistance,gcct_legacy_modifiedby,New column added
# gcct_loyaltyassistance,gcct_dm_source_record_id,New column added
# gcct_loyaltyassistance,gcct_legacy_modifiedon,New column added
# gcct_loyaltyassistance,gcct_datasourcesystemname,New column added
# gcct_loyaltyassistance,entityid,New column added
# gcct_loyaltyassistance,eventdatetime,New column added
# gcct_loyaltyassistance,eventtype,New column added
# teammembership,entityid,New column added
# teammembership,eventdatetime,New column added
# teammembership,eventtype,New column added
# gcct_offer,gcct_legacy_createdby,New column added
# gcct_offer,gcct_legacy_modifiedby,New column added
# gcct_offer,gcct_dm_source_record_id,New column added
# gcct_offer,gcct_legacy_modifiedon,New column added
# gcct_offer,entityid,New column added
# gcct_offer,eventdatetime,New column added
# gcct_offer,eventtype,New column added
# gcct_reacttransmission,entityid,New column added
# gcct_reacttransmission,eventdatetime,New column added
# gcct_reacttransmission,eventtype,New column added
# gcct_generictopic,gcct_generictopic_identity,New column added
# gcct_generictopic,gcct_generictopic_rowversion,New column added
# gcct_generictopic,entityid,New column added
# gcct_generictopic,eventdatetime,New column added
# gcct_generictopic,eventtype,New column added
# territory,entityid,New column added
# territory,eventdatetime,New column added
# territory,eventtype,New column added
# gcct_ravprocessingmilestones,gcct_legacy_createdby,New column added
# gcct_ravprocessingmilestones,gcct_dm_source_record_id,New column added
# gcct_ravprocessingmilestones,gcct_legacy_modifiedon,New column added
# gcct_ravprocessingmilestones,gcct_legacy_modifiedby,New column added
# gcct_ravprocessingmilestones,entityid,New column added
# gcct_ravprocessingmilestones,eventdatetime,New column added
# gcct_ravprocessingmilestones,eventtype,New column added
# gcct_state,entityid,New column added
# gcct_state,eventdatetime,New column added
# gcct_state,eventtype,New column added
# gcct_queuepriority,entityid,New column added
# gcct_queuepriority,eventdatetime,New column added
# gcct_queuepriority,eventtype,New column added
# gcct_qaincident,entityid,New column added
# gcct_qaincident,eventdatetime,New column added
# gcct_qaincident,eventtype,New column added
# gcct_buybackevaluationmilestone,shakey,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,process__id,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,message__id,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,entitystring,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,shakey,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,process__id,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,message__id,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,entitystring,dtype changed,string
# string,string
# gcct_buybackevaluationmilestone,entityid,New column added
# gcct_buybackevaluationmilestone,eventdatetime,New column added
# gcct_buybackevaluationmilestone,eventtype,New column added
# slakpiinstance,entityid,New column added
# slakpiinstance,eventdatetime,New column added
# slakpiinstance,eventtype,New column added
# account,gcct_bestdaytimephone,dtype changed,int,string
# account,gcct_mastermarketingphonepreference,New column added
# account,gcct_mastermarketingemailpreference,New column added
# account,gcct_mastermarketingsmstextpreference,New column added
# account,gcct_mastermarketingmailpreference,New column added
# account,gcct_sourcesystemerror,New column added
# account,gcct_mobilephone,New column added
# account,gcct_legacy_modifiedby,New column added
# account,gcct_legacy_createdby,New column added
# account,gcct_dm_source_record_id,New column added
# account,gcct_preferredlanguage,New column added
# account,gcct_legacy_modifiedon,New column added
# account,gcct_telephone2,New column added
# account,entityid,New column added
# account,eventdatetime,New column added
# account,eventtype,New column added
# gcct_warrantyhistory,gcct_legacy_modifiedon,New column added
# gcct_warrantyhistory,gcct_dm_source_record_id,New column added
# gcct_warrantyhistory,gcct_legacy_createdby,New column added
# gcct_warrantyhistory,gcct_legacy_modifiedby,New column added
# gcct_warrantyhistory,entityid,New column added
# gcct_warrantyhistory,eventdatetime,New column added
# gcct_warrantyhistory,eventtype,New column added
# gcct_additionalsymptomcodes,gcct_additionalsymptomcodes_identity,New column added
# gcct_additionalsymptomcodes,gcct_additionalsymptomcodes_rowversion,New column added
# gcct_additionalsymptomcodes,gcct_legacy_modifiedon,New column added
# gcct_additionalsymptomcodes,gcct_dm_source_record_id,New column added
# gcct_additionalsymptomcodes,gcct_legacy_createdby,New column added
# gcct_additionalsymptomcodes,gcct_legacy_modifiedby,New column added
# gcct_additionalsymptomcodes,entityid,New column added
# gcct_additionalsymptomcodes,eventdatetime,New column added
# gcct_additionalsymptomcodes,eventtype,New column added
# gcct_documentcustomerrecontact,gcct_documentcustomerrecontac_identity,New column added
# gcct_documentcustomerrecontact,gcct_documentcustomerrecontac_rowversion,New column added
# gcct_documentcustomerrecontact,gcct_legacy_createdby,New column added
# gcct_documentcustomerrecontact,gcct_legacy_modifiedby,New column added
# gcct_documentcustomerrecontact,gcct_dm_source_record_id,New column added
# gcct_documentcustomerrecontact,gcct_legacy_modifiedon,New column added
# gcct_documentcustomerrecontact,entityid,New column added
# gcct_documentcustomerrecontact,eventdatetime,New column added
# gcct_documentcustomerrecontact,eventtype,New column added
# gcct_genericinformationtopic,gcct_genericinformationtopic_identity,New column added
# gcct_genericinformationtopic,gcct_genericinformationtopic_rowversion,New column added
# gcct_genericinformationtopic,gcct_dm_source_record_id,New column added
# gcct_genericinformationtopic,gcct_legacy_createdby,New column added
# gcct_genericinformationtopic,gcct_legacy_modifiedby,New column added
# gcct_genericinformationtopic,gcct_legacy_modifiedon,New column added
# gcct_genericinformationtopic,entityid,New column added
# gcct_genericinformationtopic,eventdatetime,New column added
# gcct_genericinformationtopic,eventtype,New column added
# msdyn_answer,entityid,New column added
# msdyn_answer,eventdatetime,New column added
# msdyn_answer,eventtype,New column added
# sla,entityid,New column added
# sla,eventdatetime,New column added
# sla,eventtype,New column added
# gcct_customersatisfactiontools,gcct_legacy_createdby,New column added
# gcct_customersatisfactiontools,gcct_dm_source_record_id,New column added
# gcct_customersatisfactiontools,gcct_legacy_modifiedon,New column added
# gcct_customersatisfactiontools,gcct_legacy_modifiedby,New column added
# gcct_customersatisfactiontools,entityid,New column added
# gcct_customersatisfactiontools,eventdatetime,New column added
# gcct_customersatisfactiontools,eventtype,New column added
# gcct_warrantyloanerpartsdelay,entityid,New column added
# gcct_warrantyloanerpartsdelay,eventdatetime,New column added
# gcct_warrantyloanerpartsdelay,eventtype,New column added
# cxlvhlp_surveyitem,entityid,New column added
# cxlvhlp_surveyitem,eventdatetime,New column added
# cxlvhlp_surveyitem,eventtype,New column added
# gcct_arbitrationclaimprocessing,gcct_legacy_modifiedby,New column added
# gcct_arbitrationclaimprocessing,gcct_dm_source_record_id,New column added
# gcct_arbitrationclaimprocessing,gcct_legacy_modifiedon,New column added
# gcct_arbitrationclaimprocessing,gcct_legacy_createdby,New column added
# gcct_arbitrationclaimprocessing,entityid,New column added
# gcct_arbitrationclaimprocessing,eventdatetime,New column added
# gcct_arbitrationclaimprocessing,eventtype,New column added
# gcct_slaconfiguration,entityid,New column added
# gcct_slaconfiguration,eventdatetime,New column added
# gcct_slaconfiguration,eventtype,New column added
# gcct_tasktype,entityid,New column added
# gcct_tasktype,eventdatetime,New column added
# gcct_tasktype,eventtype,New column added
# gcct_reactdata,gcct_legacy_createdby,New column added
# gcct_reactdata,gcct_dm_source_record_id,New column added
# gcct_reactdata,gcct_legacy_modifiedon,New column added
# gcct_reactdata,gcct_legacy_modifiedby,New column added
# gcct_reactdata,gcct_datasourcesystemname,New column added
# gcct_reactdata,entityid,New column added
# gcct_reactdata,eventdatetime,New column added
# gcct_reactdata,eventtype,New column added
# gcct_doaprogramcode,entityid,New column added
# gcct_doaprogramcode,eventdatetime,New column added
# gcct_doaprogramcode,eventtype,New column added
# gcct_fieldinvolvementassistance,gcct_rescityname,New column added
# gcct_fieldinvolvementassistance,gcct_legacy_createdby,New column added
# gcct_fieldinvolvementassistance,gcct_dm_source_record_id,New column added
# gcct_fieldinvolvementassistance,gcct_legacy_modifiedon,New column added
# gcct_fieldinvolvementassistance,gcct_legacy_modifiedby,New column added
# gcct_fieldinvolvementassistance,entityid,New column added
# gcct_fieldinvolvementassistance,eventdatetime,New column added
# gcct_fieldinvolvementassistance,eventtype,New column added
# gcct_materialrequestdetail,gcct_dm_source_record_id,New column added
# gcct_materialrequestdetail,gcct_legacy_createdby,New column added
# gcct_materialrequestdetail,gcct_legacy_modifiedby,New column added
# gcct_materialrequestdetail,gcct_legacy_modifiedon,New column added
# gcct_materialrequestdetail,entityid,New column added
# gcct_materialrequestdetail,eventdatetime,New column added
# gcct_materialrequestdetail,eventtype,New column added
# msdyn_surveyinvite,entityid,New column added
# msdyn_surveyinvite,eventdatetime,New column added
# msdyn_surveyinvite,eventtype,New column added
# businessunit,entityid,New column added
# businessunit,eventdatetime,New column added
# businessunit,eventtype,New column added
# globaloptionsetmetadata,entityid,New column added
# globaloptionsetmetadata,eventdatetime,New column added
# globaloptionsetmetadata,eventtype,New column added
# gcct_casedispositiontype,gcct_casedispositiontype_identity,New column added
# gcct_casedispositiontype,gcct_casedispositiontype_rowversion,New column added
# gcct_casedispositiontype,entityid,New column added
# gcct_casedispositiontype,eventdatetime,New column added
# gcct_casedispositiontype,eventtype,New column added
# gcct_material,entityid,New column added
# gcct_material,eventdatetime,New column added
# gcct_material,eventtype,New column added
# cxlvhlp_chatactivity,cxlvhlp_endreason,New column added
# cxlvhlp_chatactivity,gcct_thevisitorwasa,New column added
# cxlvhlp_chatactivity,gcct_agentsurveycompleted,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel3,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel3_entitytype,New column added
# cxlvhlp_chatactivity,gcct_vehicleclassification,New column added
# cxlvhlp_chatactivity,gcct_vehicleclassification_entitytype,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasabout,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasabout_entitytype,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel1,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel1_entitytype,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel2,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel2_entitytype,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel4,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel4_entitytype,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel1name,New column added
# cxlvhlp_chatactivity,gcct_vehicleclassificationname,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutname,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel4name,New column added
# cxlvhlp_chatactivity,gcct_comments,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel2name,New column added
# cxlvhlp_chatactivity,gcct_theinteractionwasaboutlevel3name,New column added
# cxlvhlp_chatactivity,entityid,New column added
# cxlvhlp_chatactivity,eventdatetime,New column added
# cxlvhlp_chatactivity,eventtype,New column added
# msdyn_question,entityid,New column added
# msdyn_question,eventdatetime,New column added
# msdyn_question,eventtype,New column added
# gcct_fulfillmentvendor,gcct_fulfillmentvendor_identity,New column added
# gcct_fulfillmentvendor,gcct_fulfillmentvendor_rowversion,New column added
# gcct_fulfillmentvendor,entityid,New column added
# gcct_fulfillmentvendor,eventdatetime,New column added
# gcct_fulfillmentvendor,eventtype,New column added
# gcct_genericinformation,gcct_legacy_modifiedby,New column added
# gcct_genericinformation,gcct_legacy_modifiedon,New column added
# gcct_genericinformation,gcct_legacy_createdby,New column added
# gcct_genericinformation,gcct_dm_source_record_id,New column added
# gcct_genericinformation,entityid,New column added
# gcct_genericinformation,eventdatetime,New column added
# gcct_genericinformation,eventtype,New column added
# gcct_knownpartsdelay,gcct_knownpartsdelay_identity,New column added
# gcct_knownpartsdelay,gcct_knownpartsdelay_rowversion,New column added
# gcct_knownpartsdelay,entityid,New column added
# gcct_knownpartsdelay,eventdatetime,New column added
# gcct_knownpartsdelay,eventtype,New column added
# systemuser,entityid,New column added
# systemuser,eventdatetime,New column added
# systemuser,eventtype,New column added
# gcct_reasoncode,entityid,New column added
# gcct_reasoncode,eventdatetime,New column added
# gcct_reasoncode,eventtype,New column added
# gcct_partsorderstatus,entityid,New column added
# gcct_partsorderstatus,eventdatetime,New column added
# gcct_partsorderstatus,eventtype,New column added
# gcct_socialmediaprofile,gcct_legacy_modifiedby,New column added
# gcct_socialmediaprofile,gcct_dm_source_record_id,New column added
# gcct_socialmediaprofile,gcct_legacy_createdby,New column added
# gcct_socialmediaprofile,gcct_legacy_modifiedon,New column added
# gcct_socialmediaprofile,entityid,New column added
# gcct_socialmediaprofile,eventdatetime,New column added
# gcct_socialmediaprofile,eventtype,New column added
# gcct_partssmeassistancerequest,gcct_legacy_createdby,New column added
# gcct_partssmeassistancerequest,gcct_dm_source_record_id,New column added
# gcct_partssmeassistancerequest,gcct_legacy_modifiedon,New column added
# gcct_partssmeassistancerequest,gcct_legacy_modifiedby,New column added
# gcct_partssmeassistancerequest,entityid,New column added
# gcct_partssmeassistancerequest,eventdatetime,New column added
# gcct_partssmeassistancerequest,eventtype,New column added
# annotation,entityid,New column added
# annotation,eventdatetime,New column added
# annotation,eventtype,New column added
# gcct_demandltrtpsmclaimsprocess,gcct_legacy_createdby,New column added
# gcct_demandltrtpsmclaimsprocess,gcct_dm_source_record_id,New column added
# gcct_demandltrtpsmclaimsprocess,gcct_legacy_modifiedon,New column added
# gcct_demandltrtpsmclaimsprocess,gcct_legacy_modifiedby,New column added
# gcct_demandltrtpsmclaimsprocess,entityid,New column added
# gcct_demandltrtpsmclaimsprocess,eventdatetime,New column added
# gcct_demandltrtpsmclaimsprocess,eventtype,New column added
# gcct_vehicleloyaltyallowance,gcct_testcurrency,New column added
# gcct_vehicleloyaltyallowance,gcct_testcurrency_base,New column added
# gcct_vehicleloyaltyallowance,gcct_legacy_createdby,New column added
# gcct_vehicleloyaltyallowance,gcct_dm_source_record_id,New column added
# gcct_vehicleloyaltyallowance,gcct_legacy_modifiedon,New column added
# gcct_vehicleloyaltyallowance,gcct_legacy_modifiedby,New column added
# gcct_vehicleloyaltyallowance,entityid,New column added
# gcct_vehicleloyaltyallowance,eventdatetime,New column added
# gcct_vehicleloyaltyallowance,eventtype,New column added
# task,gcct_legacy_createdby,New column added
# task,gcct_dm_source_record_id,New column added
# task,gcct_legacy_modifiedon,New column added
# task,gcct_legacy_modifiedby,New column added
# task,entityid,New column added
# task,eventdatetime,New column added
# task,eventtype,New column added
# queueitem,entityid,New column added
# queueitem,eventdatetime,New column added
# queueitem,eventtype,New column added
# gcct_testdriverequest,gcct_legacy_createdby,New column added
# gcct_testdriverequest,gcct_dm_source_record_id,New column added
# gcct_testdriverequest,gcct_selectedtimezonedate,New column added
# gcct_testdriverequest,gcct_legacy_modifiedon,New column added
# gcct_testdriverequest,gcct_localtime,New column added
# gcct_testdriverequest,gcct_vendorsourcesystemcaseid,New column added
# gcct_testdriverequest,gcct_vendorsourcesystemname,New column added
# gcct_testdriverequest,gcct_datasourcesystemname,New column added
# gcct_testdriverequest,gcct_legacy_modifiedby,New column added
# gcct_testdriverequest,entityid,New column added
# gcct_testdriverequest,eventdatetime,New column added
# gcct_testdriverequest,eventtype,New column added
# contact,entityid,New column added
# contact,eventdatetime,New column added
# contact,eventtype,New column added
# contact,gcct_bestdaytimephone,dtype changed,int,string
# contact,gcct_customerdelegaterelationship,New column added
# contact,gcct_dm_source_record_id,New column added
# contact,gcct_legacy_createdby,New column added
# contact,gcct_legacy_modifiedby,New column added
# contact,gcct_legacy_modifiedon,New column added
# contact,gcct_mastermarketingemailpreference,New column added
# contact,gcct_mastermarketingmailpreference,New column added
# contact,gcct_mastermarketingphonecallspreference,New column added
# contact,gcct_mastermarketingsmstextpreference,New column added
# contact,gcct_onlineprofileaccountregistrationdate,New column added
# contact,gcct_sourcesystemerror,New column added
# gcct_caseassignment,gcct_canbeclosed,New column added
# gcct_caseassignment,gcct_legacy_createdby,New column added
# gcct_caseassignment,gcct_legacy_modifiedby,New column added
# gcct_caseassignment,gcct_dm_source_record_id,New column added
# gcct_caseassignment,gcct_legacy_modifiedon,New column added
# gcct_caseassignment,entityid,New column added
# gcct_caseassignment,eventdatetime,New column added
# gcct_caseassignment,eventtype,New column added
# gcct_timezone,entityid,New column added
# gcct_timezone,eventdatetime,New column added
# gcct_timezone,eventtype,New column added
