# %%
import os
import sys
import re
import pandas as pd
import commands
import ast
import itertools
import pyspark.sql.functions
from pyspark.sql.functions import col
from datetime import datetime
from collections import Counter
import re
import numpy as np
#from pyspark.sql import SparkSession
spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
if not os.path.isdir(spark_home):
    raise ValueError('SPARK_HOME environment variable is not a directory')
if not os.path.isdir(os.path.join(spark_home, 'python')):
    raise ValueError('SPARK_HOME directory does not contain python')
sys.path.insert(0, os.path.join(spark_home, 'python'))
pylib_list = (item for item in os.listdir(os.path.join(spark_home, 'python/lib/'))
              if re.match(r'py4j-\d+(\.\d+)+-src\.zip\Z', item)
              )
try:
    py4j_file = max(pylib_list)
    py4j = os.path.join(spark_home, os.path.join('python/lib', py4j_file))
except ValueError:
    raise ValueError(
        'Could not find py4j'
    )
sys.path.insert(0, py4j)

spark_release_file = spark_home + "/RELEASE"
if os.path.exists(spark_release_file) and "Spark" in  open(spark_release_file).read():
    pyspark_submit_args = os.environ.get("PYSPARK_SUBMIT_ARGS", " --master yarn-client \
                                         --executor-memory 4g --executor-cores 5 --driver-memory 16g"
                                        )
    if not "pyspark-shell" in pyspark_submit_args: pyspark_submit_args += " pyspark-shell"
    os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

with open(os.path.join(spark_home, 'python/pyspark/shell.py')) as f:
    code = compile(f.read(), os.path.join(spark_home, 'python/pyspark/shell.py'), 'exec')
    exec(code)
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.3.0.2.6.5.0-292
#       /_/
#
# Using Python version 2.7.15 (default, May  1 2018 23:32:55)
# SparkSession available as 'spark'.

# %%
lookup_tables=pd.ExcelFile("/s/latluri1/GCCT_lookup_issues.xlsx").parse('Sheet2')

# %%
reporting_tables=pd.ExcelFile("/s/latluri1/GCCT_lookup_issues.xlsx").parse('Sheet1')

# %%
q1=reporting_tables.set_index('Additional data').filter(like='systemuser', axis=0)["Table__column"].to_string(index=False).split("\n")[1:]

# %%
lookup_tables
# Out:
#                       CRM Table                   Available  \
# 0                    systemuser                  systemuser
# 1                 externalparty                         NaN
# 2                    pricelevel                         NaN
# 3                  gcct_country                gcct_country
# 4                       contact                     contact
# 5                     territory                   territory
# 6                       account                     account
# 7                   gcct_region                 gcct_region
# 8                          lead                         NaN
# 9                  businessunit                businessunit
# 10                         team                        team
# 11                    equipment                         NaN
# 12                      service                         NaN
# 13                          sla                         sla
# 14          transactioncurrency                         NaN
# 15              activitypointer                         NaN
# 16                bulkoperation                         NaN
# 17                     campaign                         NaN
# 18             campaignactivity                         NaN
# 19                     contract                         NaN
# 20                  entitlement                         NaN
# 21                     incident                    incident
# 22                      invoice                         NaN
# 23             knowledgearticle                         NaN
# 24         msdyn_responseaction                         NaN
# 25          msdyn_responseerror                         NaN
# 26                 msdyn_survey                msdyn_survey
# 27         msdyn_surveyresponse        msdyn_surveyresponse
# 28                  opportunity                         NaN
# 29                        queue                       queue
# ..                          ...                         ...
# 215  gcct_symptomclassification  gcct_symptomclassification
# 216       gcct_languageresource                         NaN
# 217     gcct_caseclassification     gcct_caseclassification
# 218     gcct_loyaltyprogramcode     gcct_loyaltyprogramcode
# 219              gcct_executive              gcct_executive
# 220           gcct_generictopic           gcct_generictopic
# 221                  gcct_state                  gcct_state
# 222  gcct_delegationofauthority  gcct_delegationofauthority
# 223      gcct_fulfillmentvendor      gcct_fulfillmentvendor
# 224               gcct_material               gcct_material
# 225      gcct_partsordersystems      gcct_partsordersystems
# 226              gcct_reactdata              gcct_reactdata
# 227               gcct_tasktype               gcct_tasktype
# 228     gcct_socialmediaprofile     gcct_socialmediaprofile
# 229           gcct_vehiclebrand           gcct_vehiclebrand
# 230                 gcct_engine                 gcct_engine
# 231               socialprofile               socialprofile
# 232                     subject                         NaN
# 233         msdyn_questiongroup                         NaN
# 234          msdyn_linkedanswer                         NaN
# 235                  msdyn_page                         NaN
# 236          msdyn_questiontype                         NaN
# 237       msdyn_feedbackmapping                         NaN
# 238                 msdyn_theme                         NaN
# 239    gcct_surveyconfiguration    gcct_surveyconfiguration
# 240        mobileofflineprofile                         NaN
# 241                    position                         NaN
# 242                        role                         NaN
# 243           gcct_akmsendpoint                         NaN
# 244                teamtemplate                         NaN
#
#                                            description              addn info  \
# 0                                                  NaN                    NaN
# 1    Information about external parties that need t...          externalparty
# 2                  Entity that defines pricing levels.             pricelevel
# 3                                                  NaN                    NaN
# 4                                                  NaN                    NaN
# 5                                                  NaN                    NaN
# 6                                                  NaN                    NaN
# 7                                                  NaN                    NaN
# 8    Prospect or potential sales opportunity. Leads...                   lead
# 9                                                  NaN                    NaN
# 10                                                 NaN                    NaN
# 11                     Resource that can be scheduled.              equipment
# 12   Activity that represents work done to satisfy ...                service
# 13                                                 NaN                    NaN
# 14   Currency in which a financial transaction is c...    transactioncurrency
# 15   Task performed, or to be performed, by a user....        activitypointer
# 16   System operation used to perform lengthy and a...          bulkoperation
# 17   Container for campaign activities and response...               campaign
# 18   Task performed, or to be performed, by a user ...       campaignactivity
# 19   Agreement to provide customer service during a...               contract
# 20   Defines the amount and type of support a custo...            entitlement
# 21                                                 NaN                    NaN
# 22                         Order that has been billed.                invoice
# 23   Organizational knowledge for internal and exte...       knowledgearticle
# 24   Actions that can occur when the respondent ent...   msdyn_responseaction
# 25                          Erroneous survey response.    msdyn_responseerror
# 26                                                 NaN                    NaN
# 27                                                 NaN                    NaN
# 28   Potential revenue-generating event, or sale to...            opportunity
# 29                                                 NaN                    NaN
# ..                                                 ...                    ...
# 215                                                NaN                    NaN
# 216                                                NaN  gcct_languageresource
# 217                                                NaN                    NaN
# 218                                                NaN                    NaN
# 219                                                NaN                    NaN
# 220                                                NaN                    NaN
# 221                                                NaN                    NaN
# 222                                                NaN                    NaN
# 223                                                NaN                    NaN
# 224                                                NaN                    NaN
# 225                                                NaN                    NaN
# 226                                                NaN                    NaN
# 227                                                NaN                    NaN
# 228                                                NaN                    NaN
# 229                                                NaN                    NaN
# 230                                                NaN                    NaN
# 231                                                NaN                    NaN
# 232  Information regarding subjects available in th...                subject
# 233  Represents one or more questions - primarily c...    msdyn_questiongroup
# 234  Information for linking common answers on mult...     msdyn_linkedanswer
# 235                                  Page of a survey.             msdyn_page
# 236  Logical linking of questions for reporting pur...     msdyn_questiontype
# 237  Container for the relationship between survey ...  msdyn_feedbackmapping
# 238  Container for the information about the colors...            msdyn_theme
# 239                                                NaN                    NaN
# 240  Information to administer and manage the data ...   mobileofflineprofile
# 241                Position of a user in the hierarchy               position
# 242  Grouping of security privileges. Users are ass...                   role
# 243                           Astute Widget Endpoints.      gcct_akmsendpoint
# 244  Team template for an entity enabled for automa...           teamtemplate
#
#                                        Derived columns
# 0    ['gcct_pcarequest__modifiedby', 'gcct_reacttra...
# 1    ['incidentresolution__modifiedbyexternalparty'...
# 2    ['account__defaultpricelevelid', 'contact__def...
# 3    ['gcct_partsorderstatus__gcct_countryid', 'gcc...
# 4    ['socialactivity__regardingobjectid', 'gcct_ra...
# 5    ['systemuser__territoryid', 'account__territor...
# 6    ['gcct_ravprocessingmilestones__regardingobjec...
# 7    ['gcct_userdelegationofauthority__gcct_region'...
# 8    ['socialactivity__regardingobjectid', 'gcct_ra...
# 9    ['cxlvhlp_chatqueuestatistic__owningbusinessun...
# 10   ['gcct_arbitrationclaimprocessing__owningteam'...
# 11   ['email__emailsender', 'annotation__objectid',...
# 12   ['gcct_customersatisfactiontools__serviceid', ...
# 13   ['incident__slainvokedid', 'letter__slainvoked...
# 14   ['gcct_ravprocessingmilestones__transactioncur...
# 15   ['queueitem__objectid', 'activityparty__activi...
# 16   ['socialactivity__regardingobjectid', 'gcct_ra...
# 17   ['socialactivity__regardingobjectid', 'gcct_ra...
# 18   ['socialactivity__regardingobjectid', 'gcct_ra...
# 19   ['socialactivity__regardingobjectid', 'gcct_ra...
# 20   ['socialactivity__regardingobjectid', 'gcct_ra...
# 21   ['socialactivity__regardingobjectid', 'inciden...
# 22   ['socialactivity__regardingobjectid', 'gcct_ra...
# 23   ['socialactivity__regardingobjectid', 'gcct_ra...
# 24   ['socialactivity__regardingobjectid', 'gcct_ra...
# 25   ['socialactivity__regardingobjectid', 'gcct_ra...
# 26   ['socialactivity__regardingobjectid', 'msdyn_s...
# 27   ['socialactivity__regardingobjectid', 'gcct_ra...
# 28   ['socialactivity__regardingobjectid', 'gcct_ra...
# 29   ['team__queueid', 'incident__gcct_queueid', 'e...
# ..                                                 ...
# 215  ['gcct_additionalsymptomcodes__gcct_symptomcla...
# 216  ['gcct_caseclassification__gcct_fetchxmlerrorm...
# 217  ['gcct_slaconfiguration__gcct_caseclassificati...
# 218  ['gcct_doaprogramcode__gcct_programcode', 'gcc...
# 219  ['annotation__objectid', 'annotation__objectid...
# 220     ['gcct_genericinformationtopic__gcct_topicid']
# 221  ['gcct_goodfaithreview__gcct_stateregisteredid...
# 222  ['gcct_loyaltycostdetails__gcct_delegationleve...
# 223        ['gcct_material__gcct_fulfillmentvendorid']
# 224  ['gcct_materialrequestdetail__gcct_materialid'...
# 225  ['gcct_partssmeassistancerequest__gcct_partord...
# 226       ['gcct_reacttransmission__gcct_reactdataid']
# 227  ['gcct_slaconfiguration__gcct_tasktypeid', 'ta...
# 228  ['gcct_socialmediamessage__gcct_socialmediapro...
# 229  ['gcct_testdriverequest__gcct_currentvehiclebr...
# 230  ['gcct_vehicle__gcct_enginesspecification', 'i...
# 231  ['socialactivity__postfromprofileid', 'inciden...
# 232                            ['incident__subjectid']
# 233  ['msdyn_question__msdyn_questiongroupid', 'msd...
# 234  ['msdyn_surveyresponse__msdyn_linkedanswer6', ...
# 235                   ['msdyn_question__msdyn_pageid']
# 236  ['msdyn_question__msdyn_questiontypelookup', '...
# 237          ['msdyn_survey__msdyn_keymeasuremapping']
# 238                    ['msdyn_survey__msdyn_themeid']
# 239   ['msdyn_surveyinvite__gcct_surveyconfiguration']
# 240             ['systemuser__mobileofflineprofileid']
# 241  ['annotation__objectid', 'annotation__objectid...
# 242  ['annotation__objectid', 'annotation__objectid...
# 243               ['team__gcct_primaryakmsendpointid']
# 244                           ['team__teamtemplateid']
#
# [245 rows x 5 columns]

# %%
for i in lookup_tables["CRM Table"]:
        list_=list(set(reporting_tables.set_index('Additional data').filter(like=i, axis=0)["Table__column"].to_string(index=False).split("\n")[1:]))
        list_1=[str(re.sub(" ","",k)) for k in set(list_)]
        lookup_tables.loc[lookup_tables['CRM Table'] == i, 'Derived columns']=str(list_1)

# %%
lookup_tables.to_csv("/s/latluri1/gcct_lookup_issues.csv",index=False)
