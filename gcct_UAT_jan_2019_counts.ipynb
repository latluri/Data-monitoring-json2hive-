# %%
import os
import sys
import re
import pandas as pd
import commands
import ast
import itertools
import pyspark.sql.functions
from pyspark.sql.functions import col
from datetime import datetime
from collections import Counter
import re
import numpy as np
#from pyspark.sql import SparkSession
spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
if not os.path.isdir(spark_home):
    raise ValueError('SPARK_HOME environment variable is not a directory')
if not os.path.isdir(os.path.join(spark_home, 'python')):
    raise ValueError('SPARK_HOME directory does not contain python')
sys.path.insert(0, os.path.join(spark_home, 'python'))
pylib_list = (item for item in os.listdir(os.path.join(spark_home, 'python/lib/'))
              if re.match(r'py4j-\d+(\.\d+)+-src\.zip\Z', item)
              )
try:
    py4j_file = max(pylib_list)
    py4j = os.path.join(spark_home, os.path.join('python/lib', py4j_file))
except ValueError:
    raise ValueError(
        'Could not find py4j'
    )
sys.path.insert(0, py4j)

spark_release_file = spark_home + "/RELEASE"
if os.path.exists(spark_release_file) and "Spark" in  open(spark_release_file).read():
    pyspark_submit_args = os.environ.get("PYSPARK_SUBMIT_ARGS", " --master yarn-client \
                                         --executor-memory 4g --executor-cores 5 --driver-memory 16g"
                                        )
    if not "pyspark-shell" in pyspark_submit_args: pyspark_submit_args += " pyspark-shell"
    os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

with open(os.path.join(spark_home, 'python/pyspark/shell.py')) as f:
    code = compile(f.read(), os.path.join(spark_home, 'python/pyspark/shell.py'), 'exec')
    exec(code)
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.3.0.2.6.5.0-292
#       /_/
#
# Using Python version 2.7.15 (default, May  1 2018 23:32:55)
# SparkSession available as 'spark'.

# %%
sqlContext.sql("use dsc10742_gcctmsd_lz_db")
# Out:
# DataFrame[]

# %%
print("data_captured_on,01/17/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/17/2019
# Table,Data(rows)
# account,1
# account_dup,126760
# activityparty,0
# activityparty_dup,31706
# annotation,5
# appointment,0
# appointment_dup,574
# bad_record,4325501
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# contact_dup,24879
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# email_dup,1809
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_buybackevaluationmilestones_dup,995
# gcct_caseassignment,0
# gcct_caseassignment_dup,4735
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,01/22/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/22/2019
# Table,Data(rows)
# account,1
# account_dup,126760
# activityparty,0
# activityparty_dup,31706
# annotation,5
# appointment,0
# appointment_dup,574
# bad_record,4325521
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# contact_dup,24879
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# email_dup,1809
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_buybackevaluationmilestones_dup,995
# gcct_caseassignment,0
# gcct_caseassignment_dup,4735
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,1
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,01/23/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/23/2019
# Table,Data(rows)
# account,1
# activityparty,0
# annotation,5
# appointment,0
# bad_record,4325521
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0

# %%
print("data_captured_on,01/24/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/24/2019
# Table,Data(rows)
# account,1
# activityparty,0
# annotation,5
# appointment,0
# bad_record,4325521
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,1
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,01/28/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/28/2019
# Table,Data(rows)
# account,1
# activityparty,0
# annotation,5
# appointment,0
# bad_record,4325521
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,1
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,01/29/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/29/2019
# Table,Data(rows)
# account,1
# activityparty,0
# annotation,7
# appointment,0
# bad_record,4325533
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,01/30/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,01/30/2019
# Table,Data(rows)
# account,1
# activityparty,0
# annotation,7
# appointment,0
# bad_record,4325533
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,1
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,02/01/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,02/01/2019
# Table,Data(rows)
# account,119277
# activityparty,23114
# annotation,27
# appointment,35
# bad_record,4763582
# businessunit,0
# calendar,29
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,168
# cxlvhlp_chatqueuestatistic,24
# cxlvhlp_surveyitem,27
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,1
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0

# %%
print("data_captured_on,02/01/2019")
print("Table,Data(rows)")
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
# Out:
# data_captured_on,02/01/2019
# Table,Data(rows)
# account,119277
# activityparty,23114
# annotation,27
# appointment,35
# bad_record,4763583
# businessunit,0
# calendar,29
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,168
# cxlvhlp_chatqueuestatistic,24
# cxlvhlp_surveyitem,27
# email,390
# fax,369
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,13
# gcct_arbitrationclaimprocessing,3
# gcct_buybackevaluationmilestones,3
# gcct_caseassignment,2527
# gcct_caseclassification,7435
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,1
# gcct_customersatisfactiontools,131
# gcct_delegationofauthority,2
# gcct_demandltrtpsmclaimsprocessing,3
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,1
# gcct_engine,4
# gcct_executive,0
# gcct_executiveliaison,2
# gcct_fieldinvolvementassistancerequest,1
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,1
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,50
# gcct_loyaltycostdetails,22
# gcct_loyaltyprogramcode,0
# gcct_material,179
# gcct_materialrequest,3
# gcct_materialrequestdetail,0
# gcct_offer,6
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,3
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,10
# gcct_pcarequest,1
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,6
# gcct_ravprocessingmilestones,0
# gcct_reactdata,25897
# gcct_reacttransmission,1
# gcct_reasoncode,0
# gcct_recall,32
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,38
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,4987
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,28
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,633
# gcct_vehiclebrand,0
# gcct_vehicleclass,20
# gcct_vehicleloyaltyallowance,8
# gcct_vehicleoffroad,0
# gcct_vehicleowner,2096
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,3539
# incidentresolution,522
# letter,1
# msdyn_answer,48
# msdyn_question,3
# msdyn_questionresponse,3
# msdyn_survey,2
# msdyn_surveyinvite,6
# msdyn_surveyresponse,26
# optionsetmetadata,0
# phonecall,299
# queue,65
# queueitem,6432
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,350
# task,0
# team,190
# teammembership,0
# territory,0

# %%
print("data_captured_on,02/04/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/04/2019
# Table,Data(rows)
# account,202423
# activityparty,76390
# annotation,16461
# appointment,135
# bad_record,7177164
# businessunit,0
# calendar,100
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,377
# cxlvhlp_chatqueuestatistic,55
# cxlvhlp_surveyitem,166
# email,889
# fax,9211
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,22
# gcct_arbitrationclaimprocessing,13
# gcct_buybackevaluationmilestones,229
# gcct_caseassignment,144939
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,7
# gcct_country,746
# gcct_customersatisfactiontools,1547
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,155
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,7
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,4
# gcct_fieldinvolvementassistancerequest,1326
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,7
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12559
# gcct_loyaltycostdetails,928
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,12
# gcct_materialrequestdetail,0
# gcct_offer,763
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,16
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,36
# gcct_pcarequest,5
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,3
# gcct_reactdata,25914
# gcct_reacttransmission,9
# gcct_reasoncode,0
# gcct_recall,66
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,51
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,800
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1553
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,23
# gcct_vehicleoffroad,0
# gcct_vehicleowner,9746
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,53345
# incidentresolution,4134
# letter,1
# msdyn_answer,75
# msdyn_question,25
# msdyn_questionresponse,43
# msdyn_survey,22
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,2691
# queue,94
# queueitem,25591
# sla,53
# slaitem,0
# slakpiinstance,162881
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75178
# task,0
# team,399
# teammembership,0
# territory,0
# Total: 8195455

# %%
print("data_captured_on,02/04/2019_10:36_3248_added")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/04/2019_10:36_3248_added
# Table,Data(rows)
# account,202482
# activityparty,76489
# annotation,17250
# appointment,135
# bad_record,7177438
# businessunit,0
# calendar,100
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,377
# cxlvhlp_chatqueuestatistic,55
# cxlvhlp_surveyitem,166
# email,894
# fax,9211
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,23
# gcct_arbitrationclaimprocessing,13
# gcct_buybackevaluationmilestones,229
# gcct_caseassignment,144958
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,76
# gcct_country,746
# gcct_customersatisfactiontools,1548
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,155
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,8
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,4
# gcct_fieldinvolvementassistancerequest,1326
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,7
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12567
# gcct_loyaltycostdetails,948
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,13
# gcct_materialrequestdetail,0
# gcct_offer,763
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,16
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,42
# gcct_pcarequest,5
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,3
# gcct_reactdata,25914
# gcct_reacttransmission,9
# gcct_reasoncode,0
# gcct_recall,66
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,51
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,801
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1590
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,23
# gcct_vehicleoffroad,0
# gcct_vehicleowner,9800
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,53474
# incidentresolution,4138
# letter,1
# msdyn_answer,75
# msdyn_question,25
# msdyn_questionresponse,43
# msdyn_survey,22
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,2693
# queue,94
# queueitem,25619
# sla,53
# slaitem,0
# slakpiinstance,164516
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75182
# task,0
# team,401
# teammembership,0
# territory,0
# Total: 8198703

# %%
print("data_captured_on,02/04/2019_10:36_3248_added")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k+' where process__id = "PN_31752081489949434"').select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/04/2019_10:36_3248_added
# Table,Data(rows)
# account,59
# activityparty,99
# annotation,789
# appointment,0
# bad_record,274
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,5
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,1
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,19
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,69
# gcct_country,0
# gcct_customersatisfactiontools,1
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,1
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,8
# gcct_loyaltycostdetails,20
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,1
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,6
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,1
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,37
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,54
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,129
# incidentresolution,4
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,2
# queue,0
# queueitem,28
# sla,0
# slaitem,0
# slakpiinstance,1635
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,4
# task,0
# team,2
# teammembership,0
# territory,0
# Total: 3248

# %%
print("data_captured_on,02/05/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/05/2019
# Table,Data(rows)
# account,202489
# activityparty,77294
# annotation,17258
# appointment,138
# bad_record,7178008
# businessunit,0
# calendar,106
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,384
# cxlvhlp_chatqueuestatistic,62
# cxlvhlp_surveyitem,166
# email,920
# fax,9214
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,23
# gcct_arbitrationclaimprocessing,14
# gcct_buybackevaluationmilestones,231
# gcct_caseassignment,145059
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,76
# gcct_country,746
# gcct_customersatisfactiontools,1551
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,158
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,24
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,6
# gcct_fieldinvolvementassistancerequest,1327
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,8
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12570
# gcct_loyaltycostdetails,950
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,13
# gcct_materialrequestdetail,0
# gcct_offer,764
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,16
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,43
# gcct_pcarequest,6
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,3
# gcct_reactdata,25914
# gcct_reacttransmission,10
# gcct_reasoncode,0
# gcct_recall,69
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,51
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,809
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1595
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,23
# gcct_vehicleoffroad,0
# gcct_vehicleowner,10304
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,53850
# incidentresolution,4144
# letter,1
# msdyn_answer,75
# msdyn_question,25
# msdyn_questionresponse,43
# msdyn_survey,22
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,2703
# queue,95
# queueitem,25721
# sla,59
# slaitem,0
# slakpiinstance,165173
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75196
# task,0
# team,401
# teammembership,0
# territory,0
# Total: 8201976

# %%
print("data_captured_on,02/05/2019_PN_12723534335642745_1758")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k+' where process__id = "PN_12723534335642745"').select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/05/2019_PN_12723534335642745_1758
# Table,Data(rows)
# account,0
# activityparty,530
# annotation,4
# appointment,0
# bad_record,326
# businessunit,0
# calendar,4
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,7
# cxlvhlp_chatqueuestatistic,7
# cxlvhlp_surveyitem,0
# email,6
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,25
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,6
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,379
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,252
# incidentresolution,3
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,2
# queue,1
# queueitem,29
# sla,0
# slaitem,0
# slakpiinstance,167
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,10
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 1758

# %%
print("data_captured_on,02/05/2019_PN_12752362043610445_1515")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k+' where process__id = "PN_12752362043610445"').select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/05/2019_PN_12752362043610445_1515
# Table,Data(rows)
# account,7
# activityparty,275
# annotation,4
# appointment,3
# bad_record,244
# businessunit,0
# calendar,2
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,20
# fax,3
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,1
# gcct_buybackevaluationmilestones,2
# gcct_caseassignment,76
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,3
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,3
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,16
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,2
# gcct_fieldinvolvementassistancerequest,1
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,1
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,3
# gcct_loyaltycostdetails,2
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,1
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,1
# gcct_pcarequest,1
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,1
# gcct_reasoncode,0
# gcct_recall,3
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,2
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,5
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,125
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,124
# incidentresolution,3
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,8
# queue,0
# queueitem,73
# sla,6
# slaitem,0
# slakpiinstance,490
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,4
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 1515

# %%
print("data_captured_on,02/05/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/05/2019
# Table,Data(rows)
# account,202519
# activityparty,77709
# annotation,27045
# appointment,158
# bad_record,7178355
# businessunit,0
# calendar,108
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,386
# cxlvhlp_chatqueuestatistic,62
# cxlvhlp_surveyitem,166
# email,943
# fax,9214
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,28
# gcct_arbitrationclaimprocessing,16
# gcct_buybackevaluationmilestones,232
# gcct_caseassignment,145138
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,77
# gcct_country,746
# gcct_customersatisfactiontools,1552
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,159
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,25
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,7
# gcct_fieldinvolvementassistancerequest,1328
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,8
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12584
# gcct_loyaltycostdetails,960
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,14
# gcct_materialrequestdetail,0
# gcct_offer,768
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,16
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,46
# gcct_pcarequest,8
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,4
# gcct_reactdata,25914
# gcct_reacttransmission,11
# gcct_reasoncode,0
# gcct_recall,71
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,51
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,811
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1632
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,27
# gcct_vehicleoffroad,0
# gcct_vehicleowner,10432
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,53986
# incidentresolution,4157
# letter,1
# msdyn_answer,75
# msdyn_question,25
# msdyn_questionresponse,43
# msdyn_survey,22
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,2713
# queue,97
# queueitem,25794
# sla,59
# slaitem,0
# slakpiinstance,165173
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75196
# task,0
# team,401
# teammembership,0
# territory,0
# Total: 8213526

# %%
print("data_captured_on,02/05/2019_PN_5488693650904256_12272")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k+' where process__id = "PN_5488693650904256"').select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/05/2019_PN_5488693650904256_12272
# Table,Data(rows)
# account,30
# activityparty,415
# annotation,9787
# appointment,20
# bad_record,348
# businessunit,0
# calendar,2
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,2
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,23
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,5
# gcct_arbitrationclaimprocessing,2
# gcct_buybackevaluationmilestones,1
# gcct_caseassignment,79
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,1
# gcct_country,0
# gcct_customersatisfactiontools,1
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,1
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,1
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,1
# gcct_fieldinvolvementassistancerequest,1
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,14
# gcct_loyaltycostdetails,10
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,1
# gcct_materialrequestdetail,0
# gcct_offer,4
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,3
# gcct_pcarequest,2
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,1
# gcct_reactdata,0
# gcct_reacttransmission,1
# gcct_reasoncode,0
# gcct_recall,2
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,2
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,37
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,4
# gcct_vehicleoffroad,0
# gcct_vehicleowner,128
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,136
# incidentresolution,13
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,10
# queue,2
# queueitem,73
# sla,0
# slaitem,0
# slakpiinstance,709
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,12
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 12272

# %%
print("data_captured_on,02/08/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql('select count(*) from '+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/08/2019
# Table,Data(rows)
# account,202707
# activityparty,125105
# annotation,38770
# appointment,170
# bad_record,7209787
# businessunit,0
# calendar,118
# calendarrule,0
# contact,16
# cxlvhlp_chatactivity,551
# cxlvhlp_chatqueuestatistic,77
# cxlvhlp_surveyitem,231
# email,1058
# fax,9214
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,7308
# gcct_arbitrationclaimprocessing,16
# gcct_buybackevaluationmilestones,232
# gcct_caseassignment,155242
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,83
# gcct_country,746
# gcct_customersatisfactiontools,2618
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,159
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,201
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,7
# gcct_fieldinvolvementassistancerequest,1328
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,8
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12591
# gcct_loyaltycostdetails,972
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,16
# gcct_materialrequestdetail,0
# gcct_offer,768
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,17
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,51
# gcct_pcarequest,8
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,4
# gcct_reactdata,25914
# gcct_reacttransmission,11
# gcct_reasoncode,0
# gcct_recall,79
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,54
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,822
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1776
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,31
# gcct_vehicleoffroad,0
# gcct_vehicleowner,11885
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,70049
# incidentresolution,5075
# letter,1
# msdyn_answer,75
# msdyn_question,29
# msdyn_questionresponse,43
# msdyn_survey,27
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,4345
# queue,103
# queueitem,34471
# sla,62
# slaitem,0
# slakpiinstance,249617
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75238
# task,0
# team,405
# teammembership,0
# territory,0
# Total: 8436745

# %%
print("data_captured_on,02/08/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) = '2019-02-07'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/08/2019
# Table,Data(rows)
# account,61
# activityparty,34470
# annotation,6371
# appointment,0
# bad_record,21919
# businessunit,0
# calendar,4
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,99
# cxlvhlp_chatqueuestatistic,15
# cxlvhlp_surveyitem,65
# email,53
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,5316
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,6912
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,3
# gcct_country,0
# gcct_customersatisfactiontools,849
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,175
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,2
# gcct_loyaltycostdetails,5
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,1
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,4
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,1
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,4
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,60
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,722
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,13661
# incidentresolution,630
# letter,0
# msdyn_answer,0
# msdyn_question,4
# msdyn_questionresponse,0
# msdyn_survey,5
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,1410
# queue,2
# queueitem,6972
# sla,0
# slaitem,0
# slakpiinstance,69609
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,9
# task,0
# team,2
# teammembership,0
# territory,0
# Total: 169415

# %%
print("data_captured_on,02/11/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/11/2019
# Table,Data(rows)
# account,202730
# activityparty,125408
# annotation,38774
# appointment,170
# bad_record,7210118
# businessunit,0
# calendar,118
# calendarrule,0
# contact,58
# cxlvhlp_chatactivity,551
# cxlvhlp_chatqueuestatistic,82
# cxlvhlp_surveyitem,231
# email,1079
# fax,9214
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,7329
# gcct_arbitrationclaimprocessing,16
# gcct_buybackevaluationmilestones,232
# gcct_caseassignment,155323
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,85
# gcct_country,746
# gcct_customersatisfactiontools,2629
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,159
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,202
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,7
# gcct_fieldinvolvementassistancerequest,1328
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,8
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12601
# gcct_loyaltycostdetails,989
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,17
# gcct_materialrequestdetail,0
# gcct_offer,768
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,17
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,51
# gcct_pcarequest,8
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,4
# gcct_reactdata,25914
# gcct_reacttransmission,11
# gcct_reasoncode,0
# gcct_recall,82
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,55
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,824
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,1868
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,32
# gcct_vehicleoffroad,0
# gcct_vehicleowner,12112
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,54
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,71913
# incidentresolution,5415
# letter,1
# msdyn_answer,86
# msdyn_question,36
# msdyn_questionresponse,43
# msdyn_survey,37
# msdyn_surveyinvite,53
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,4440
# queue,103
# queueitem,36038
# sla,62
# slaitem,0
# slakpiinstance,266024
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75243
# task,0
# team,410
# teammembership,0
# territory,0
# Total: 8458255

# %%
print("data_captured_on,02/12/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/12/2019
# Table,Data(rows)
# account,204414
# activityparty,125640
# annotation,45403
# appointment,172
# bad_record,7210413
# businessunit,0
# calendar,144
# calendarrule,0
# contact,235
# cxlvhlp_chatactivity,566
# cxlvhlp_chatqueuestatistic,90
# cxlvhlp_surveyitem,256
# email,1125
# fax,9214
# gcct_accountresponsibleagent,1
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,7330
# gcct_arbitrationclaimprocessing,16
# gcct_buybackevaluationmilestones,240
# gcct_caseassignment,155378
# gcct_caseclassification,160082
# gcct_casedispositiontype,0
# gcct_coachback,87
# gcct_country,746
# gcct_customersatisfactiontools,2629
# gcct_delegationofauthority,4
# gcct_demandltrtpsmclaimsprocessing,159
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,203
# gcct_engine,277
# gcct_executive,0
# gcct_executiveliaison,7
# gcct_fieldinvolvementassistancerequest,1328
# gcct_fmcccontract,1
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,8
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12620
# gcct_loyaltycostdetails,996
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,18
# gcct_materialrequestdetail,0
# gcct_offer,768
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,17
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,51
# gcct_pcarequest,8
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,11
# gcct_ravprocessingmilestones,4
# gcct_reactdata,25915
# gcct_reacttransmission,11
# gcct_reasoncode,0
# gcct_recall,87
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,39
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,56
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,13
# gcct_symptomclassification,14104
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,830
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,2040
# gcct_vehiclebrand,4
# gcct_vehicleclass,9930
# gcct_vehicleloyaltyallowance,32
# gcct_vehicleoffroad,0
# gcct_vehicleowner,12336
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,64
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,71995
# incidentresolution,5420
# letter,1
# msdyn_answer,86
# msdyn_question,59
# msdyn_questionresponse,43
# msdyn_survey,63
# msdyn_surveyinvite,55
# msdyn_surveyresponse,43
# optionsetmetadata,0
# phonecall,4458
# queue,115
# queueitem,36090
# sla,62
# slaitem,0
# slakpiinstance,279642
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75275
# task,0
# team,412
# teammembership,0
# territory,0
# Total: 8481779

# %%
sqlContext.tables("dsc60230_gcct_tz_db").count()
# Out:
# 239

# %%
import os
from datetime import date, timedelta
a=commands.getstatusoutput("hadoop fs -ls -t /project/dsc/qa/archive/60230_gcct/")[1].splitlines()[2:]
b=pd.DataFrame([sub.split() for sub in a]).apply(lambda x: x.str.strip())

# %%
c=b[b[5]==(date.today() - timedelta(1)).strftime('%Y-%m-%d')][7].tolist()

# %%
# Out:
# '/project/dsc/qa/archive/60230_gcct/PN_19195717322628084'

# %%
# Out:
# ['/project/dsc/qa/archive/60230_gcct/PN_19195717322628084',
#  '/project/dsc/qa/archive/60230_gcct/PN_31962691868476926',
#  '/project/dsc/qa/archive/60230_gcct/PN_1957696086997572']

# %%
commands.getstatusoutput("hadoop fs -cat "+c[0])[1].splitlines()[2:]
# Out:
# []

# %%
b[5]
# Out:
# 0      2019-02-08
# 1      2019-02-07
# 2      2019-02-07
# 3      2019-02-07
# 4      2019-02-06
# 5      2019-02-06
# 6      2019-02-06
# 7      2019-02-05
# 8      2019-02-05
# 9      2019-02-05
# 10     2019-02-04
# 11     2019-02-04
# 12     2019-02-04
# 13     2019-02-03
# 14     2019-02-03
# 15     2019-02-03
# 16     2019-02-02
# 17     2019-02-02
# 18     2019-02-02
# 19     2019-02-01
# 20     2019-02-01
# 21     2019-02-01
# 22     2019-02-01
# 23     2019-01-31
# 24     2019-01-31
# 25     2019-01-31
# 26     2019-01-30
# 27     2019-01-30
# 28     2019-01-30
# 29     2019-01-29
#           ...
# 490    2018-09-15
# 491    2018-09-15
# 492    2018-09-14
# 493    2018-09-14
# 494    2018-09-14
# 495    2018-09-13
# 496    2018-09-13
# 497    2018-09-13
# 498    2018-09-12
# 499    2018-09-12
# 500    2018-09-12
# 501    2018-09-11
# 502    2018-09-11
# 503    2018-09-11
# 504    2018-09-11
# 505    2018-09-11
# 506    2018-09-11
# 507    2018-09-10
# 508    2018-09-10
# 509    2018-09-10
# 510    2018-09-09
# 511    2018-09-09
# 512    2018-09-09
# 513    2018-09-08
# 514    2018-09-08
# 515    2018-09-08
# 516    2018-09-07
# 517    2018-09-07
# 518    2018-09-07
# 519    2018-09-07
# Name: 5, Length: 520, dtype: object

# %%
print("data_captured_on,02/17/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) = '2019-02-17'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,02/17/2019
# Table,Data(rows)
# account,0
# activityparty,0
# annotation,0
# appointment,0
# bad_record,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 0

# %%
print("data_captured_on,03/01/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) = '2019-02-28'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,03/01/2019
# Table,Data(rows)
# account,0
# activityparty,0
# annotation,0
# appointment,0
# bad_record,0
# bad_record_bak,0
# bad_record_part,0
# bad_record_tx,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 0

# %%
print("data_captured_on or after 02-15-2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) > '2019-02-15'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on or after 02-15-2019
# Table,Data(rows)
# account,352
# activityparty,25215
# annotation,515730
# appointment,24
# bad_record,66122
# bad_record_bak,9525
# bad_record_part,0
# bad_record_tx,0
# businessunit,0
# calendar,64
# calendarrule,0
# contact,462
# cxlvhlp_chatactivity,61
# cxlvhlp_chatqueuestatistic,26
# cxlvhlp_surveyitem,3
# email,251
# fax,20242
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,115
# gcct_addportalmessage,70
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,2
# gcct_caseassignment,7515
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,81
# gcct_country,0
# gcct_customersatisfactiontools,5
# gcct_delegationofauthority,1
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,115
# gcct_engine,259
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,74
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,1
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,27
# gcct_loyaltycostdetails,41
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,5
# gcct_materialrequestdetail,0
# gcct_offer,19
# gcct_offerdetail,1442
# gcct_onlinegaragevehicles,3
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,7
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,1
# gcct_queuepriority,2
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,16
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,12
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,9
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,5
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,21
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,418
# gcct_vehiclebrand,0
# gcct_vehicleclass,2
# gcct_vehicleloyaltyallowance,12
# gcct_vehicleoffroad,0
# gcct_vehicleowner,453
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,7714
# incidentresolution,99
# letter,0
# msdyn_answer,71
# msdyn_question,204
# msdyn_questionresponse,125
# msdyn_survey,65
# msdyn_surveyinvite,69
# msdyn_surveyresponse,19
# optionsetmetadata,0
# phonecall,107
# queue,34
# queueitem,7618
# sla,0
# slaitem,0
# slakpiinstance,62405
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,123
# task,0
# team,7
# teammembership,0
# territory,0
# Total: 727470

# %%
print("data_captured_on,03/12/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,03/12/2019
# Table,Data(rows)
# account,205356
# activityparty,158412
# annotation,561389
# appointment,270
# bad_record,7296140
# bad_record_bak,7222154
# bad_record_part,0
# bad_record_tx,0
# businessunit,7
# calendar,298
# calendarrule,29
# contact,1397
# cxlvhlp_chatactivity,668
# cxlvhlp_chatqueuestatistic,137
# cxlvhlp_surveyitem,283
# email,1924
# fax,29459
# gcct_accountresponsibleagent,5
# gcct_additionalsymptomcodes,124
# gcct_addportalmessage,7636
# gcct_arbitrationclaimprocessing,33
# gcct_buybackevaluationmilestones,315
# gcct_caseassignment,164246
# gcct_caseclassification,174294
# gcct_casedispositiontype,0
# gcct_coachback,184
# gcct_country,747
# gcct_customersatisfactiontools,2693
# gcct_delegationofauthority,6
# gcct_demandltrtpsmclaimsprocessing,184
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,324
# gcct_engine,536
# gcct_executive,0
# gcct_executiveliaison,15
# gcct_fieldinvolvementassistancerequest,1337
# gcct_fmcccontract,111
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,24
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,12847
# gcct_loyaltycostdetails,1105
# gcct_loyaltyprogramcode,0
# gcct_material,614
# gcct_materialrequest,31
# gcct_materialrequestdetail,0
# gcct_offer,800
# gcct_offerdetail,1442
# gcct_onlinegaragevehicles,28
# gcct_partsorderstatus,0
# gcct_partsordersystems,1
# gcct_partssmeassistancerequest,87
# gcct_pcarequest,19
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,4
# gcct_queuepriority,18
# gcct_ravprocessingmilestones,8
# gcct_reactdata,25926
# gcct_reacttransmission,27
# gcct_reasoncode,0
# gcct_recall,158
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,51
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,79
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,59
# gcct_symptomclassification,14121
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,909
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,3177
# gcct_vehiclebrand,4
# gcct_vehicleclass,9932
# gcct_vehicleloyaltyallowance,148
# gcct_vehicleoffroad,0
# gcct_vehicleowner,14930
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,64
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,83551
# incidentresolution,5717
# letter,2
# msdyn_answer,457
# msdyn_question,673
# msdyn_questionresponse,212
# msdyn_survey,398
# msdyn_surveyinvite,299
# msdyn_surveyresponse,70
# optionsetmetadata,0
# phonecall,4763
# queue,188
# queueitem,45368
# sla,75
# slaitem,0
# slakpiinstance,371690
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75552
# task,0
# team,436
# teammembership,0
# territory,0
# Total: 16508001

# %%
print("data_captured_on,03/25/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,03/25/2019
# Table,Data(rows)
# account,205835
# activityparty,216059
# annotation,562081
# appointment,395
# bad_record,7345772
# bad_record_bak,7222154
# bad_record_part,0
# bad_record_tx,0
# businessunit,9
# calendar,424
# calendarrule,29
# calendarrule_20190315,29
# contact,547
# contact_20190315,1550
# cxlvhlp_chatactivity,706
# cxlvhlp_chatqueuestatistic,147
# cxlvhlp_surveyitem,316
# email,4041
# fax,29502
# gcct_accountresponsibleagent,8
# gcct_additionalsymptomcodes,128
# gcct_addportalmessage,7692
# gcct_arbitrationclaimprocessing,3
# gcct_arbitrationclaimprocessing_20190315,39
# gcct_buybackevaluationmilestones,340
# gcct_caseassignment,13720
# gcct_caseassignment_20150315,164682
# gcct_caseclassification,188603
# gcct_casedispositiontype,19
# gcct_coachback,193
# gcct_country,1002
# gcct_customersatisfactiontools,3775
# gcct_delegationofauthority,9
# gcct_demandltrtpsmclaimsprocessing,206
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,334
# gcct_engine,537
# gcct_executive,0
# gcct_executiveliaison,21
# gcct_fieldinvolvementassistancerequest,1343
# gcct_fmcccontract,137
# gcct_fulfillmentvendor,0
# gcct_genericinformation,1
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,32
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,13013
# gcct_loyaltycostdetails,1150
# gcct_loyaltyprogramcode,3
# gcct_material,614
# gcct_materialrequest,38
# gcct_materialrequestdetail,0
# gcct_offer,822
# gcct_offerdetail,1442
# gcct_onlinegaragevehicles,36
# gcct_partsorderstatus,0
# gcct_partsordersystems,4
# gcct_partssmeassistancerequest,6
# gcct_partssmeassistancerequest_20190315,0
# gcct_partssmeassistancerequest_bak,87
# gcct_pcarequest,25
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,20
# gcct_queuepriority,18
# gcct_ravprocessingmilestones,8
# gcct_reactdata,25951
# gcct_reacttransmission,33
# gcct_reasoncode,0
# gcct_recall,179
# gcct_region,0
# gcct_rentaldetail,19
# gcct_slaconfiguration,83
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,93
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,100
# gcct_symptomclassification,16599
# gcct_tasktype,0
# gcct_technicalassistancerequest,836
# gcct_testdriverequest,961
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,4008
# gcct_vehiclebrand,4
# gcct_vehicleclass,10964
# gcct_vehicleloyaltyallowance,167
# gcct_vehicleoffroad,21
# gcct_vehicleowner,1329
# gcct_vehicleowner_20190315,15100
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,71
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,17872
# incident_20190315,84334
# incidentresolution,8253
# letter,6
# msdyn_answer,576
# msdyn_question,981
# msdyn_questionresponse,356
# msdyn_survey,537
# msdyn_surveyinvite,3226
# msdyn_surveyresponse,103
# optionsetmetadata,0
# phonecall,7100
# queue,251
# queueitem,59286
# sla,442
# slaitem,0
# slakpiinstance,380304
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75765
# task,12
# team,676
# teammembership,13
# territory,0
# Total: 16706705

# %%
print("data_captured_on or after 03-22-2019")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) >= '2019-03-22'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on or after 03-22-2019
# Table,Data(rows)
# account,97
# activityparty,50879
# annotation,429
# appointment,95
# businessunit,2
# calendar,0
# calendarrule,0
# contact,145
# cxlvhlp_chatactivity,9
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,1784
# fax,42
# gcct_accountresponsibleagent,3
# gcct_additionalsymptomcodes,4
# gcct_addportalmessage,8
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,1
# gcct_caseassignment,12501
# gcct_caseclassification,14271
# gcct_casedispositiontype,10
# gcct_coachback,1
# gcct_country,5
# gcct_customersatisfactiontools,1038
# gcct_delegationofauthority,3
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,5
# gcct_engine,1
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,26
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,96
# gcct_loyaltycostdetails,3
# gcct_loyaltyprogramcode,3
# gcct_material,0
# gcct_materialrequest,2
# gcct_materialrequestdetail,0
# gcct_offer,10
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,7
# gcct_partsorderstatus,0
# gcct_partsordersystems,3
# gcct_partssmeassistancerequest,3
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,6
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,5
# gcct_region,0
# gcct_rentaldetail,18
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,8
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,2
# gcct_symptomclassification,2478
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,85
# gcct_vehiclebrand,0
# gcct_vehicleclass,1029
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,16
# gcct_vehicleowner,441
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,5
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,16174
# incidentresolution,2093
# letter,4
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,17
# msdyn_survey,2
# msdyn_surveyinvite,2703
# msdyn_surveyresponse,11
# optionsetmetadata,0
# phonecall,1388
# queue,0
# queueitem,12088
# sla,0
# slaitem,0
# slakpiinstance,6915
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,17
# task,6
# team,18
# teammembership,4
# territory,0
# Total: 127019

# %%
print("data_captured_on or after 03-22-2019 ")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) >= '2019-03-22'").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on or after 03-22-2019
# Table,Data(rows)
# account,125
# activityparty,235263
# annotation,2737
# appointment,10042
# businessunit,2
# calendar,261
# calendarrule,24
# contact,69912
# cxlvhlp_chatactivity,26
# cxlvhlp_chatqueuestatistic,150
# cxlvhlp_surveyitem,293
# email,10164
# fax,347
# gcct_accountresponsibleagent,3
# gcct_additionalsymptomcodes,27
# gcct_addportalmessage,12321
# gcct_arbitrationclaimprocessing,2
# gcct_buybackevaluationmilestones,24
# gcct_caseassignment,65189
# gcct_caseclassification,14274
# gcct_casedispositiontype,23
# gcct_coachback,8
# gcct_country,253
# gcct_customersatisfactiontools,6279
# gcct_delegationofauthority,5
# gcct_demandltrtpsmclaimsprocessing,100
# gcct_doaprogramcode,200
# gcct_documentcustomerrecontact,6
# gcct_engine,3
# gcct_executive,192
# gcct_executiveliaison,266
# gcct_fieldinvolvementassistancerequest,24
# gcct_fmcccontract,32
# gcct_fulfillmentvendor,12
# gcct_genericinformation,1278
# gcct_genericinformationtopic,14
# gcct_generictopic,267
# gcct_goodfaithreview,26
# gcct_knownpartsdelay,505
# gcct_lemonlawcriteria,4
# gcct_loanercost,3
# gcct_loyaltyassistance,553
# gcct_loyaltycostdetails,397
# gcct_loyaltyprogramcode,106
# gcct_material,811
# gcct_materialrequest,141
# gcct_materialrequestdetail,18
# gcct_offer,252
# gcct_offerdetail,2
# gcct_onlinegaragevehicles,92
# gcct_partsorderstatus,69
# gcct_partsordersystems,10
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,124
# gcct_priordealerdecision,7
# gcct_qaincident,8
# gcct_qamonitoring,20
# gcct_queuepriority,31
# gcct_ravprocessingmilestones,10
# gcct_reactdata,504
# gcct_reacttransmission,92
# gcct_reasoncode,18
# gcct_recall,17
# gcct_region,11
# gcct_rentaldetail,99
# gcct_slaconfiguration,9
# gcct_sms,303
# gcct_socialmediaconversation,26
# gcct_socialmediamessage,3
# gcct_socialmediaprofile,132
# gcct_specialloanercode,488
# gcct_state,9
# gcct_surveyconfiguration,100
# gcct_symptomclassification,2482
# gcct_tasktype,5
# gcct_technicalassistancerequest,508
# gcct_testdriverequest,149
# gcct_timezone,120
# gcct_userdelegationofauthority,4
# gcct_vehicle,256
# gcct_vehiclebrand,4
# gcct_vehicleclass,4606
# gcct_vehicleloyaltyallowance,191
# gcct_vehicleoffroad,179
# gcct_vehicleowner,1361
# gcct_warrantyhistory,4
# gcct_warrantyloanerpartsdelay,10
# gcct_warrantyloanerrequest,96
# gcct_warrantyloanerrequesthistory,6
# globaloptionsetmetadata,653
# incident,73029
# incidentresolution,32451
# letter,14
# msdyn_answer,367
# msdyn_question,262
# msdyn_questionresponse,371
# msdyn_survey,68
# msdyn_surveyinvite,6893
# msdyn_surveyresponse,18
# optionsetmetadata,4976
# phonecall,20440
# queue,453
# queueitem,131997
# sla,444
# slaitem,222
# slakpiinstance,164500
# socialactivity,0
# socialprofile,0
# statemetadata,14
# statusmetadata,14
# systemuser,571
# task,517
# team,289
# teammembership,21
# territory,171
# Total: 883884

# %%
sqlContext.table("territory").columns
# Out:
# ['id',
#  'sinkcreatedon',
#  'sinkmodifiedon',
#  'gcct_territorytypecode',
#  'gcct_csmtypecode',
#  'gcct_isterritorygroup',
#  'gcct_csmtypeoptioncode',
#  'modifiedonbehalfby',
#  'modifiedonbehalfby_entitytype',
#  'managerid',
#  'managerid_entitytype',
#  'createdonbehalfby',
#  'createdonbehalfby_entitytype',
#  'transactioncurrencyid',
#  'transactioncurrencyid_entitytype',
#  'gcct_managerid',
#  'gcct_managerid_entitytype',
#  'modifiedby',
#  'modifiedby_entitytype',
#  'createdby',
#  'createdby_entitytype',
#  'gcct_territorygroup',
#  'gcct_territorygroup_entitytype',
#  'organizationid',
#  'organizationid_entitytype',
#  'createdonbehalfbyyominame',
#  'gcct_region',
#  'transactioncurrencyidname',
#  'description',
#  'gcct_territorygroupname',
#  'entityimage_timestamp',
#  'name',
#  'entityimageid',
#  'importsequencenumber',
#  'organizationidname',
#  'modifiedbyyominame',
#  'gcct_territorycode',
#  'utcconversiontimezonecode',
#  'createdbyyominame',
#  'territoryid',
#  'modifiedbyname',
#  'versionnumber',
#  'timezoneruleversionnumber',
#  'gcct_manageridname',
#  'gcct_zone',
#  'modifiedon',
#  'manageridname',
#  'exchangerate',
#  'manageridyominame',
#  'modifiedonbehalfbyyominame',
#  'createdbyname',
#  'createdon',
#  'createdonbehalfbyname',
#  'gcct_facingregion',
#  'modifiedonbehalfbyname',
#  'gcct_manageridyominame',
#  'overriddencreatedon',
#  'entityimage_url',
#  'lastupdtby',
#  'lastupdatedatetime',
#  'shakey',
#  'process__id',
#  'message__id',
#  'entitystring',
#  'entityid',
#  'eventdatetime',
#  'eventtype']

# %%
sqlCtx.sql("select * from territory where to_date(lastupdatedatetime) >= '2019-03-22'").groupby("to_date(lastupdatedatetime)").count().show(10,False)
# Out:
# +------------------+-----+
# |lastupdatedatetime|count|
# +------------------+-----+
# +------------------+-----+

# %%
print("data_captured_on,03/26/2019")
print("Table,Data(rows)")
g2=0
for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            k=m.asDict().values()[0].encode('utf-8')
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on,03/26/2019
# Table,Data(rows)
# account,205845
# activityparty,219359
# annotation,562199
# appointment,411
# bad_record,7678537
# bad_record_bak,7222154
# bad_record_part,0
# bad_record_tx,0
# businessunit,9
# calendar,642
# calendarrule,36
# calendarrule_20190315,29
# contact,794
# contact_20190315,1550
# cxlvhlp_chatactivity,706
# cxlvhlp_chatqueuestatistic,230
# cxlvhlp_surveyitem,316
# email,4106
# fax,29504
# gcct_accountresponsibleagent,8
# gcct_additionalsymptomcodes,129
# gcct_addportalmessage,8267
# gcct_arbitrationclaimprocessing,12
# gcct_arbitrationclaimprocessing_20190315,39
# gcct_buybackevaluationmilestones,340
# gcct_caseassignment,15251
# gcct_caseassignment_20150315,164682
# gcct_caseclassification,188603
# gcct_casedispositiontype,21
# gcct_coachback,193
# gcct_country,1002
# gcct_customersatisfactiontools,3908
# gcct_delegationofauthority,9
# gcct_demandltrtpsmclaimsprocessing,208
# gcct_doaprogramcode,49
# gcct_documentcustomerrecontact,334
# gcct_engine,537
# gcct_executive,0
# gcct_executiveliaison,23
# gcct_fieldinvolvementassistancerequest,1352
# gcct_fmcccontract,137
# gcct_fulfillmentvendor,1
# gcct_genericinformation,678
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,38
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,13024
# gcct_loyaltycostdetails,1165
# gcct_loyaltyprogramcode,4
# gcct_material,831
# gcct_materialrequest,41
# gcct_materialrequestdetail,0
# gcct_offer,833
# gcct_offerdetail,1442
# gcct_onlinegaragevehicles,39
# gcct_partsorderstatus,6
# gcct_partsordersystems,5
# gcct_partssmeassistancerequest,6
# gcct_partssmeassistancerequest_20190315,0
# gcct_partssmeassistancerequest_bak,87
# gcct_pcarequest,32
# gcct_priordealerdecision,1
# gcct_qaincident,1
# gcct_qamonitoring,28
# gcct_queuepriority,22
# gcct_ravprocessingmilestones,9
# gcct_reactdata,25952
# gcct_reacttransmission,42
# gcct_reasoncode,1
# gcct_recall,181
# gcct_region,1
# gcct_rentaldetail,22
# gcct_slaconfiguration,83
# gcct_sms,0
# gcct_socialmediaconversation,1
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,95
# gcct_specialloanercode,0
# gcct_state,2
# gcct_surveyconfiguration,100
# gcct_symptomclassification,16599
# gcct_tasktype,1
# gcct_technicalassistancerequest,1078
# gcct_testdriverequest,1016
# gcct_timezone,78
# gcct_userdelegationofauthority,0
# gcct_vehicle,4094
# gcct_vehiclebrand,4
# gcct_vehicleclass,10964
# gcct_vehicleloyaltyallowance,234
# gcct_vehicleoffroad,22
# gcct_vehicleowner,1569
# gcct_vehicleowner_20190315,15100
# gcct_warrantyhistory,388
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,77
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,19629
# incident_20190315,84334
# incidentresolution,9589
# letter,6
# msdyn_answer,770
# msdyn_question,1122
# msdyn_questionresponse,356
# msdyn_survey,552
# msdyn_surveyinvite,3239
# msdyn_surveyresponse,104
# optionsetmetadata,0
# phonecall,7117
# queue,345
# queueitem,60610
# sla,504
# slaitem,117
# slakpiinstance,380304
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,75775
# task,12
# team,677
# teammembership,13
# territory,77
# Total: 17052780

# %%
print("data_captured_on 04-03-2019 ")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) = CAST(current_timestamp() as DATE)").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-03-2019
# Table,Data(rows)
# account,9
# activityparty,79242
# annotation,22
# appointment,39
# businessunit,0
# calendar,0
# calendarrule,0
# contact,2878
# cxlvhlp_chatactivity,3
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,293
# email,6638
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,44
# gcct_arbitrationclaimprocessing,2
# gcct_buybackevaluationmilestones,13
# gcct_caseassignment,17503
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,4
# gcct_country,248
# gcct_customersatisfactiontools,1651
# gcct_delegationofauthority,1
# gcct_demandltrtpsmclaimsprocessing,14
# gcct_doaprogramcode,2
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,4
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,5
# gcct_genericinformationtopic,6
# gcct_generictopic,4
# gcct_goodfaithreview,7
# gcct_knownpartsdelay,18
# gcct_lemonlawcriteria,1
# gcct_loanercost,0
# gcct_loyaltyassistance,33
# gcct_loyaltycostdetails,31
# gcct_loyaltyprogramcode,0
# gcct_material,4
# gcct_materialrequest,2
# gcct_materialrequestdetail,7
# gcct_offer,5
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,10
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,2
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,3
# gcct_queuepriority,5
# gcct_ravprocessingmilestones,3
# gcct_reactdata,2
# gcct_reacttransmission,2
# gcct_reasoncode,0
# gcct_recall,4
# gcct_region,0
# gcct_rentaldetail,14
# gcct_slaconfiguration,0
# gcct_sms,69
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,33
# gcct_specialloanercode,7
# gcct_state,2
# gcct_surveyconfiguration,52
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,13
# gcct_testdriverequest,18
# gcct_timezone,2
# gcct_userdelegationofauthority,1
# gcct_vehicle,50
# gcct_vehiclebrand,0
# gcct_vehicleclass,1
# gcct_vehicleloyaltyallowance,21
# gcct_vehicleoffroad,10
# gcct_vehicleowner,243
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,3
# gcct_warrantyloanerrequest,13
# gcct_warrantyloanerrequesthistory,3
# globaloptionsetmetadata,0
# incident,18829
# incidentresolution,5577
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,14
# msdyn_survey,0
# msdyn_surveyinvite,4050
# msdyn_surveyresponse,2
# optionsetmetadata,4966
# phonecall,6305
# queue,107
# queueitem,24403
# sla,0
# slaitem,0
# slakpiinstance,139178
# socialactivity,0
# socialprofile,0
# statemetadata,4
# statusmetadata,4
# systemuser,159
# task,24
# team,3
# teammembership,1
# territory,0
# Total: 312945

# %%
print("data_captured_on 04-08-2019 ")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime) = CAST(current_timestamp() as DATE)").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-03-2019
# Table,Data(rows)
# account,9
# activityparty,79242
# annotation,22
# appointment,39
# businessunit,0
# calendar,0
# calendarrule,0
# contact,2878
# cxlvhlp_chatactivity,3
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,293
# email,6638
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,44
# gcct_arbitrationclaimprocessing,2
# gcct_buybackevaluationmilestones,13
# gcct_caseassignment,17503
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,4
# gcct_country,248
# gcct_customersatisfactiontools,1651
# gcct_delegationofauthority,1
# gcct_demandltrtpsmclaimsprocessing,14
# gcct_doaprogramcode,2
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,4
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,5
# gcct_genericinformationtopic,6
# gcct_generictopic,4
# gcct_goodfaithreview,7
# gcct_knownpartsdelay,18
# gcct_lemonlawcriteria,1
# gcct_loanercost,0
# gcct_loyaltyassistance,33
# gcct_loyaltycostdetails,31
# gcct_loyaltyprogramcode,0
# gcct_material,4
# gcct_materialrequest,2
# gcct_materialrequestdetail,7
# gcct_offer,5
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,10
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,2
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,3
# gcct_queuepriority,5
# gcct_ravprocessingmilestones,3
# gcct_reactdata,2
# gcct_reacttransmission,2
# gcct_reasoncode,0
# gcct_recall,4
# gcct_region,0
# gcct_rentaldetail,14
# gcct_slaconfiguration,0
# gcct_sms,69
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,33
# gcct_specialloanercode,7
# gcct_state,2
# gcct_surveyconfiguration,52
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,13
# gcct_testdriverequest,18
# gcct_timezone,2
# gcct_userdelegationofauthority,1
# gcct_vehicle,50
# gcct_vehiclebrand,0
# gcct_vehicleclass,1
# gcct_vehicleloyaltyallowance,21
# gcct_vehicleoffroad,10
# gcct_vehicleowner,243
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,3
# gcct_warrantyloanerrequest,13
# gcct_warrantyloanerrequesthistory,3
# globaloptionsetmetadata,0
# incident,18829
# incidentresolution,5577
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,14
# msdyn_survey,0
# msdyn_surveyinvite,4050
# msdyn_surveyresponse,2
# optionsetmetadata,4966
# phonecall,6305
# queue,107
# queueitem,24403
# sla,0
# slaitem,0
# slakpiinstance,139178
# socialactivity,0
# socialprofile,0
# statemetadata,4
# statusmetadata,4
# systemuser,159
# task,24
# team,3
# teammembership,1
# territory,0
# Total: 312945

# %%
print("data_captured_on 04-24-2019 ")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-24-2019
# Table,Data(rows)
# account,156
# activityparty,618173
# annotation,3344
# appointment,10065
# businessunit,16
# calendar,271
# calendarrule,68
# contact,84541
# cxlvhlp_chatactivity,171
# cxlvhlp_chatqueuestatistic,159
# cxlvhlp_surveyitem,336
# email,39078
# fax,353
# gcct_accountresponsibleagent,6
# gcct_additionalsymptomcodes,69
# gcct_addportalmessage,12352
# gcct_arbitrationclaimprocessing,8
# gcct_buybackevaluationmilestones,46
# gcct_caseassignment,99660
# gcct_caseclassification,14304
# gcct_casedispositiontype,154
# gcct_coachback,10
# gcct_country,257
# gcct_customersatisfactiontools,13121
# gcct_delegationofauthority,8
# gcct_demandltrtpsmclaimsprocessing,124
# gcct_doaprogramcode,202
# gcct_documentcustomerrecontact,108
# gcct_engine,8
# gcct_executive,196
# gcct_executiveliaison,279
# gcct_fieldinvolvementassistancerequest,34
# gcct_fmcccontract,13062
# gcct_fulfillmentvendor,17
# gcct_genericinformation,1305
# gcct_genericinformationtopic,29
# gcct_generictopic,279
# gcct_goodfaithreview,28
# gcct_knownpartsdelay,577
# gcct_lemonlawcriteria,8
# gcct_loanercost,6
# gcct_loyaltyassistance,763
# gcct_loyaltycostdetails,621
# gcct_loyaltyprogramcode,108
# gcct_material,818
# gcct_materialrequest,141
# gcct_materialrequestdetail,30
# gcct_offer,277
# gcct_offerdetail,4
# gcct_onlinegaragevehicles,101
# gcct_partsorderstatus,71
# gcct_partsordersystems,14
# gcct_partssmeassistancerequest,26
# gcct_pcarequest,134
# gcct_priordealerdecision,11
# gcct_qaincident,13
# gcct_qamonitoring,46
# gcct_queuepriority,33
# gcct_ravprocessingmilestones,12
# gcct_reactdata,507
# gcct_reacttransmission,97
# gcct_reasoncode,20
# gcct_recall,33
# gcct_region,13
# gcct_rentaldetail,107
# gcct_slaconfiguration,9
# gcct_sms,305
# gcct_socialmediaconversation,26
# gcct_socialmediamessage,5
# gcct_socialmediaprofile,140
# gcct_specialloanercode,515
# gcct_state,15
# gcct_surveyconfiguration,233
# gcct_symptomclassification,2497
# gcct_tasktype,8
# gcct_technicalassistancerequest,519
# gcct_testdriverequest,175
# gcct_timezone,122
# gcct_userdelegationofauthority,10
# gcct_vehicle,269
# gcct_vehiclebrand,6
# gcct_vehicleclass,4613
# gcct_vehicleloyaltyallowance,208
# gcct_vehicleoffroad,185
# gcct_vehicleowner,2658
# gcct_warrantyhistory,9
# gcct_warrantyloanerpartsdelay,14
# gcct_warrantyloanerrequest,158
# gcct_warrantyloanerrequesthistory,10
# globaloptionsetmetadata,840
# incident,139137
# incidentresolution,51967
# letter,20
# msdyn_answer,435
# msdyn_question,318
# msdyn_questionresponse,458
# msdyn_survey,103
# msdyn_surveyinvite,12697
# msdyn_surveyresponse,118
# optionsetmetadata,5002
# phonecall,23122
# queue,468
# queueitem,195745
# sla,446
# slaitem,222
# slakpiinstance,177046
# socialactivity,0
# socialprofile,0
# statemetadata,18
# statusmetadata,18
# systemuser,830
# task,556
# team,488
# teammembership,26
# territory,177
# Total: 1539954

# %%
print("data_captured_on 04-25-2019 ")
print("Table,Data(rows)")
g2=0
tab_list=['account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-25-2019
# Table,Data(rows)
# account,0
# activityparty,0
# annotation,0
# appointment,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,3
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,4
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,22
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,1
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,164
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 194

# %%
print("data_captured_on 04-25-2019 1:40PM")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-25-2019 1:40PM
# Table,Data(rows)
# bad_record,177
# account,0
# activityparty,0
# annotation,0
# appointment,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,3
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,4
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,22
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,1
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,164
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 371

# %%
print("data_captured_on 04-26-2019 2:55PM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-26-2019 2:55PM
# Environment: prod
# Table,Data(rows)
# bad_record,2
# account,167
# activityparty,0
# annotation,0
# appointment,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 169

# %%
print("data_captured_on 04-29-2019 11:30AM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 04-29-2019 11:30AM
# Environment: prod
# Table,Data(rows)
# bad_record,9
# account,828
# activityparty,0
# annotation,0
# appointment,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 837

# %%
print("data_captured_on 05-01-2019 11:30AM")
print("Environment: prod, special requirement by praveen")
print("Table,Data(rows)")
g2=0
tab_list=["contact","gcct_arbitrationclaimprocessing","gcct_caseassignment","gcct_partssmeassistancerequest","gcct_vehicleowner","incident","calendarrule"]
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-01-2019 11:30AM
# Environment: prod
# Table,Data(rows)
# contact,858
# gcct_arbitrationclaimprocessing,1797
# gcct_caseassignment,561671
# gcct_partssmeassistancerequest,186
# gcct_vehicleowner,0
# incident,0
# calendarrule,0
# Total: 564512

# %%
print("data_captured_on 05-01-2019 11:30AM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-01-2019 11:30AM
# Environment: prod
# Table,Data(rows)
# bad_record,2995
# account,23047
# activityparty,602960
# annotation,0
# appointment,236143
# businessunit,0
# calendar,0
# calendarrule,0
# contact,858
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,284
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,632
# gcct_addportalmessage,34615
# gcct_arbitrationclaimprocessing,1797
# gcct_buybackevaluationmilestones,4626
# gcct_caseassignment,561671
# gcct_caseclassification,21
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,2
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,4563
# gcct_genericinformationtopic,3712
# gcct_generictopic,0
# gcct_goodfaithreview,19990
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,17499
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,206
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,186
# gcct_pcarequest,355
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,27234
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,28426
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,173
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,8300
# gcct_testdriverequest,1572
# gcct_timezone,0
# gcct_userdelegationofauthority,648
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,322
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,2810
# gcct_warrantyloanerpartsdelay,3978
# gcct_warrantyloanerrequest,3766
# gcct_warrantyloanerrequesthistory,17
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,560
# queueitem,136233
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,2625
# task,8331
# team,4
# teammembership,810
# territory,13
# Total: 1742801

# %%
print("data_captured_on 05-01-2019 3:30PM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-01-2019 3:30PM
# Environment: prod
# Table,Data(rows)
# bad_record,3004
# account,26380
# activityparty,968928
# annotation,0
# appointment,241420
# businessunit,0
# calendar,0
# calendarrule,0
# contact,4310
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,307
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,656
# gcct_addportalmessage,35949
# gcct_arbitrationclaimprocessing,1826
# gcct_buybackevaluationmilestones,4776
# gcct_caseassignment,563366
# gcct_caseclassification,21
# gcct_casedispositiontype,0
# gcct_coachback,1
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,2
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,4563
# gcct_genericinformationtopic,3712
# gcct_generictopic,0
# gcct_goodfaithreview,20063
# gcct_knownpartsdelay,1
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,17499
# gcct_loyaltycostdetails,15
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,213
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,186
# gcct_pcarequest,527
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,39644
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,3
# gcct_region,0
# gcct_rentaldetail,28426
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,189
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,8333
# gcct_testdriverequest,1572
# gcct_timezone,0
# gcct_userdelegationofauthority,648
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,339
# gcct_vehicleoffroad,0
# gcct_vehicleowner,3
# gcct_warrantyhistory,2921
# gcct_warrantyloanerpartsdelay,4333
# gcct_warrantyloanerrequest,4195
# gcct_warrantyloanerrequesthistory,17
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,569
# queueitem,237696
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,3650
# task,8396
# team,4
# teammembership,810
# territory,13
# Total: 2240303

# %%
print("data_captured_on 05-01-2019 5:30PM, fresh start")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k).select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-01-2019 5:30PM, fresh start
# Environment: prod
# Table,Data(rows)
# bad_record,0
# account,0
# activityparty,0
# annotation,0
# appointment,0
# businessunit,0
# calendar,0
# calendarrule,0
# contact,0
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,0
# gcct_accountresponsibleagent,0
# gcct_additionalsymptomcodes,0
# gcct_addportalmessage,0
# gcct_arbitrationclaimprocessing,0
# gcct_buybackevaluationmilestones,0
# gcct_caseassignment,0
# gcct_caseclassification,0
# gcct_casedispositiontype,0
# gcct_coachback,0
# gcct_country,0
# gcct_customersatisfactiontools,0
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,0
# gcct_genericinformationtopic,0
# gcct_generictopic,0
# gcct_goodfaithreview,0
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,0
# gcct_loyaltycostdetails,0
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,0
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,0
# gcct_pcarequest,0
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,0
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,0
# gcct_region,0
# gcct_rentaldetail,0
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,0
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,0
# gcct_testdriverequest,0
# gcct_timezone,0
# gcct_userdelegationofauthority,0
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,0
# gcct_vehicleoffroad,0
# gcct_vehicleowner,0
# gcct_warrantyhistory,0
# gcct_warrantyloanerpartsdelay,0
# gcct_warrantyloanerrequest,0
# gcct_warrantyloanerrequesthistory,0
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,0
# msdyn_answer,0
# msdyn_question,0
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,0
# queueitem,0
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,0
# task,0
# team,0
# teammembership,0
# territory,0
# Total: 0

# %%
print("data_captured_on 05-02-2019 10:00AM, re loaded")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime)  = date_sub(CAST(current_timestamp() as DATE), 1)").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-02-2019 10:00AM, re loaded
# Environment: prod
# Table,Data(rows)
# bad_record,774
# account,28480
# activityparty,1307250
# annotation,0
# appointment,242145
# businessunit,0
# calendar,0
# calendarrule,0
# contact,5555
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,310
# gcct_accountresponsibleagent,414
# gcct_additionalsymptomcodes,661
# gcct_addportalmessage,36165
# gcct_arbitrationclaimprocessing,1828
# gcct_buybackevaluationmilestones,4798
# gcct_caseassignment,563951
# gcct_caseclassification,21
# gcct_casedispositiontype,0
# gcct_coachback,169
# gcct_country,0
# gcct_customersatisfactiontools,559
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,2
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,4563
# gcct_genericinformationtopic,3712
# gcct_generictopic,0
# gcct_goodfaithreview,20076
# gcct_knownpartsdelay,1
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,17509
# gcct_loyaltycostdetails,2927
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,214
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,2954
# gcct_pcarequest,548
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,41606
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,1150
# gcct_region,0
# gcct_rentaldetail,28431
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,189
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,8338
# gcct_testdriverequest,1572
# gcct_timezone,0
# gcct_userdelegationofauthority,648
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,345
# gcct_vehicleoffroad,0
# gcct_vehicleowner,45525
# gcct_warrantyhistory,2939
# gcct_warrantyloanerpartsdelay,4388
# gcct_warrantyloanerrequest,4265
# gcct_warrantyloanerrequesthistory,19
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,61
# msdyn_answer,0
# msdyn_question,38
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,1
# optionsetmetadata,0
# phonecall,0
# queue,580
# queueitem,345072
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,4833
# task,8405
# team,4
# teammembership,815
# territory,13
# Total: 2745640

# %%
print("data_captured_on 05-02-2019 12:40PM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime)  = date_sub(CAST(current_timestamp() as DATE), 1)").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-02-2019 12:40PM
# Environment: prod
# Table,Data(rows)
# bad_record,774
# account,28480
# activityparty,1307250
# annotation,0
# appointment,242145
# businessunit,0
# calendar,0
# calendarrule,0
# contact,5555
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,310
# gcct_accountresponsibleagent,414
# gcct_additionalsymptomcodes,661
# gcct_addportalmessage,36165
# gcct_arbitrationclaimprocessing,1828
# gcct_buybackevaluationmilestones,4798
# gcct_caseassignment,563951
# gcct_caseclassification,21
# gcct_casedispositiontype,0
# gcct_coachback,169
# gcct_country,0
# gcct_customersatisfactiontools,559
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,0
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,2
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,4563
# gcct_genericinformationtopic,3712
# gcct_generictopic,0
# gcct_goodfaithreview,20076
# gcct_knownpartsdelay,1
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,17509
# gcct_loyaltycostdetails,2927
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,214
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,2954
# gcct_pcarequest,548
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,41606
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,1150
# gcct_region,0
# gcct_rentaldetail,28431
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,189
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,8338
# gcct_testdriverequest,1572
# gcct_timezone,0
# gcct_userdelegationofauthority,648
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,345
# gcct_vehicleoffroad,0
# gcct_vehicleowner,45525
# gcct_warrantyhistory,2939
# gcct_warrantyloanerpartsdelay,4388
# gcct_warrantyloanerrequest,4265
# gcct_warrantyloanerrequesthistory,19
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,61
# msdyn_answer,0
# msdyn_question,38
# msdyn_questionresponse,0
# msdyn_survey,0
# msdyn_surveyinvite,0
# msdyn_surveyresponse,1
# optionsetmetadata,0
# phonecall,0
# queue,580
# queueitem,345072
# sla,0
# slaitem,0
# slakpiinstance,0
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,4833
# task,8405
# team,4
# teammembership,815
# territory,13
# Total: 2745640

# %%
print("data_captured_on 05-03-2019 10:24AM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.sql("select count(*) from "+k+" where to_date(lastupdatedatetime)  = date_sub(CAST(current_timestamp() as DATE), 1)").select("count(1)").collect()[0].asDict().values()[0]
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-03-2019 10:24AM
# Environment: prod
# Table,Data(rows)
# bad_record,1363
# account,1077
# activityparty,1060038
# annotation,0
# appointment,25507
# businessunit,0
# calendar,0
# calendarrule,0
# contact,2066
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,32
# gcct_accountresponsibleagent,378
# gcct_additionalsymptomcodes,61
# gcct_addportalmessage,3247
# gcct_arbitrationclaimprocessing,185
# gcct_buybackevaluationmilestones,727
# gcct_caseassignment,8675
# gcct_caseclassification,6
# gcct_casedispositiontype,0
# gcct_coachback,173
# gcct_country,0
# gcct_customersatisfactiontools,560
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,521
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,0
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,799
# gcct_genericinformationtopic,716
# gcct_generictopic,0
# gcct_goodfaithreview,330
# gcct_knownpartsdelay,0
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,2433
# gcct_loyaltycostdetails,2188
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,11
# gcct_offer,0
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,802
# gcct_pcarequest,180
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,0
# gcct_ravprocessingmilestones,16669
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,2040
# gcct_region,0
# gcct_rentaldetail,878
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,17
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,0
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,210
# gcct_testdriverequest,2
# gcct_timezone,0
# gcct_userdelegationofauthority,41
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,57
# gcct_vehicleoffroad,0
# gcct_vehicleowner,66403
# gcct_warrantyhistory,213
# gcct_warrantyloanerpartsdelay,296
# gcct_warrantyloanerrequest,589
# gcct_warrantyloanerrequesthistory,5
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,80
# msdyn_answer,0
# msdyn_question,18
# msdyn_questionresponse,1
# msdyn_survey,3
# msdyn_surveyinvite,0
# msdyn_surveyresponse,0
# optionsetmetadata,0
# phonecall,0
# queue,39
# queueitem,341807
# sla,0
# slaitem,0
# slakpiinstance,236
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,2401
# task,491
# team,0
# teammembership,147
# territory,0
# Total: 1544718

# %%
print("data_captured_on 05-03-2019 04:24AM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-03-2019 04:24AM
# Environment: prod
# Table,Data(rows)
# bad_record,2370
# account,29954
# activityparty,3083851
# annotation,0
# appointment,273762
# businessunit,0
# calendar,0
# calendarrule,0
# contact,9981
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,351
# gcct_accountresponsibleagent,813
# gcct_additionalsymptomcodes,740
# gcct_addportalmessage,40029
# gcct_arbitrationclaimprocessing,2045
# gcct_buybackevaluationmilestones,5658
# gcct_caseassignment,578933
# gcct_caseclassification,34
# gcct_casedispositiontype,0
# gcct_coachback,349
# gcct_country,0
# gcct_customersatisfactiontools,1129
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,1328
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,2
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,5525
# gcct_genericinformationtopic,4579
# gcct_generictopic,0
# gcct_goodfaithreview,20491
# gcct_knownpartsdelay,1
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,20420
# gcct_loyaltycostdetails,5208
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,227
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,3926
# gcct_pcarequest,766
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,63046
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,4693
# gcct_region,0
# gcct_rentaldetail,29500
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,207
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,8605
# gcct_testdriverequest,1575
# gcct_timezone,0
# gcct_userdelegationofauthority,719
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,413
# gcct_vehicleoffroad,0
# gcct_vehicleowner,116483
# gcct_warrantyhistory,3218
# gcct_warrantyloanerpartsdelay,4758
# gcct_warrantyloanerrequest,5003
# gcct_warrantyloanerrequesthistory,30
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,153
# msdyn_answer,0
# msdyn_question,56
# msdyn_questionresponse,1
# msdyn_survey,7
# msdyn_surveyinvite,0
# msdyn_surveyresponse,1
# optionsetmetadata,0
# phonecall,0
# queue,640
# queueitem,875956
# sla,0
# slaitem,0
# slakpiinstance,1652
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,8096
# task,9022
# team,5
# teammembership,1142
# territory,13
# Total: 5228283

# %%
print("data_captured_on 05-06-2019 09:45AM")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            print(str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-06-2019 09:45AM
# Environment: prod
# Table,Data(rows)
# bad_record,198194
# account,52812
# activityparty,6002335
# annotation,0
# appointment,362847
# businessunit,0
# calendar,0
# calendarrule,0
# contact,16298
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# cxlvhlp_surveyitem,0
# email,0
# fax,407
# gcct_accountresponsibleagent,837
# gcct_additionalsymptomcodes,852
# gcct_addportalmessage,52119
# gcct_arbitrationclaimprocessing,2340
# gcct_buybackevaluationmilestones,7711
# gcct_caseassignment,596686
# gcct_caseclassification,34
# gcct_casedispositiontype,0
# gcct_coachback,501
# gcct_country,0
# gcct_customersatisfactiontools,1203
# gcct_delegationofauthority,0
# gcct_demandltrtpsmclaimsprocessing,0
# gcct_doaprogramcode,0
# gcct_documentcustomerrecontact,2117
# gcct_engine,0
# gcct_executive,0
# gcct_executiveliaison,0
# gcct_fieldinvolvementassistancerequest,4
# gcct_fmcccontract,0
# gcct_fulfillmentvendor,0
# gcct_genericinformation,6997
# gcct_genericinformationtopic,5320
# gcct_generictopic,0
# gcct_goodfaithreview,21642
# gcct_knownpartsdelay,1
# gcct_lemonlawcriteria,0
# gcct_loanercost,0
# gcct_loyaltyassistance,28646
# gcct_loyaltycostdetails,7449
# gcct_loyaltyprogramcode,0
# gcct_material,0
# gcct_materialrequest,0
# gcct_materialrequestdetail,260
# gcct_offer,725
# gcct_offerdetail,0
# gcct_onlinegaragevehicles,0
# gcct_partsorderstatus,0
# gcct_partsordersystems,0
# gcct_partssmeassistancerequest,6346
# gcct_pcarequest,1316
# gcct_priordealerdecision,0
# gcct_qaincident,0
# gcct_qamonitoring,0
# gcct_queuepriority,66
# gcct_ravprocessingmilestones,106676
# gcct_reactdata,0
# gcct_reacttransmission,0
# gcct_reasoncode,0
# gcct_recall,5254
# gcct_region,0
# gcct_rentaldetail,31650
# gcct_slaconfiguration,0
# gcct_sms,0
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# gcct_socialmediaprofile,275
# gcct_specialloanercode,0
# gcct_state,0
# gcct_surveyconfiguration,26
# gcct_symptomclassification,0
# gcct_tasktype,0
# gcct_technicalassistancerequest,9403
# gcct_testdriverequest,1580
# gcct_timezone,0
# gcct_userdelegationofauthority,719
# gcct_vehicle,0
# gcct_vehiclebrand,0
# gcct_vehicleclass,0
# gcct_vehicleloyaltyallowance,631
# gcct_vehicleoffroad,0
# gcct_vehicleowner,239236
# gcct_warrantyhistory,3922
# gcct_warrantyloanerpartsdelay,5979
# gcct_warrantyloanerrequest,7869
# gcct_warrantyloanerrequesthistory,30
# globaloptionsetmetadata,0
# incident,0
# incidentresolution,0
# letter,158
# msdyn_answer,0
# msdyn_question,56
# msdyn_questionresponse,1
# msdyn_survey,7
# msdyn_surveyinvite,0
# msdyn_surveyresponse,1
# optionsetmetadata,0
# phonecall,0
# queue,676
# queueitem,890268
# sla,0
# slaitem,0
# slakpiinstance,14817
# socialactivity,0
# socialprofile,0
# statemetadata,0
# statusmetadata,0
# systemuser,8112
# task,10961
# team,6
# teammembership,1174
# territory,14
# Total: 8715566

# %%
print("data_captured_on 05-06-2019 09:45AM")
print("Only the tables needed in dashboard")
print("Environment: prod")
print("Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("Priority table,"str(k)+","+str(g1))
            else
                print("Other table,"str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-06-2019 09:45AM
# Only the tables needed in dashboard
# Environment: prod
# Table,Data(rows)
# account,52812
# appointment,362847
# gcct_buybackevaluationmilestones,7711
# calendar,0
# calendarrule,0
# incident,0
# gcct_caseassignment,596686
# cxlvhlp_chatactivity,0
# cxlvhlp_chatqueuestatistic,0
# gcct_documentcustomerrecontact,2117
# email,0
# fax,407
# gcct_fieldinvolvementassistancerequest,4
# gcct_loyaltyassistance,28646
# optionsetmetadata,0
# gcct_partssmeassistancerequest,6346
# phonecall,0
# msdyn_question,56
# msdyn_questionresponse,1
# queueitem,890268
# gcct_ravprocessingmilestones,106676
# gcct_recall,5254
# slakpiinstance,14817
# msdyn_survey,7
# msdyn_surveyinvite,0
# gcct_surveyconfiguration,26
# cxlvhlp_surveyitem,0
# msdyn_surveyresponse,1
# task,10961
# team,6
# gcct_technicalassistancerequest,9403
# systemuser,8112
# annotation,0
# contact,16298
# businessunit,0
# gcct_addportalmessage,52119
# gcct_socialmediaconversation,0
# gcct_socialmediamessage,0
# territory,14
# msdyn_questionresponse,1
# msdyn_question,56
# gcct_vehicle,0
# gcct_warrantyloanerrequest,7869
# globaloptionsetmetadata,0
# statemetadata,0
# statusmetadata,0
# Total: 2179521

# %%
print("data_captured_on 05-07-2019 09:20AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-07-2019 09:20AM
# Environment: prod
# Table,Data(rows)
# Other table,bad_record,198276
# Priority table,account,53893
# Other table,activityparty,6715078
# Priority table,annotation,0
# Priority table,appointment,363836
# Priority table,businessunit,0
# Priority table,calendar,0
# Priority table,calendarrule,0
# Priority table,contact,19938
# Priority table,cxlvhlp_chatactivity,0
# Priority table,cxlvhlp_chatqueuestatistic,0
# Priority table,cxlvhlp_surveyitem,0
# Priority table,email,0
# Priority table,fax,407
# Other table,gcct_accountresponsibleagent,837
# Other table,gcct_additionalsymptomcodes,886
# Priority table,gcct_addportalmessage,52336
# Other table,gcct_arbitrationclaimprocessing,2340
# Priority table,gcct_buybackevaluationmilestones,7778
# Priority table,gcct_caseassignment,602575
# Other table,gcct_caseclassification,34
# Other table,gcct_casedispositiontype,0
# Other table,gcct_coachback,502
# Other table,gcct_country,0
# Other table,gcct_customersatisfactiontools,1204
# Other table,gcct_delegationofauthority,0
# Other table,gcct_demandltrtpsmclaimsprocessing,0
# Other table,gcct_doaprogramcode,3
# Priority table,gcct_documentcustomerrecontact,2121
# Other table,gcct_engine,0
# Other table,gcct_executive,0
# Other table,gcct_executiveliaison,0
# Priority table,gcct_fieldinvolvementassistancerequest,4
# Other table,gcct_fmcccontract,0
# Other table,gcct_fulfillmentvendor,0
# Other table,gcct_genericinformation,7018
# Other table,gcct_genericinformationtopic,5327
# Other table,gcct_generictopic,0
# Other table,gcct_goodfaithreview,21691
# Other table,gcct_knownpartsdelay,1
# Other table,gcct_lemonlawcriteria,0
# Other table,gcct_loanercost,0
# Priority table,gcct_loyaltyassistance,28741
# Other table,gcct_loyaltycostdetails,7470
# Other table,gcct_loyaltyprogramcode,0
# Other table,gcct_material,0
# Other table,gcct_materialrequest,0
# Other table,gcct_materialrequestdetail,260
# Other table,gcct_offer,725
# Other table,gcct_offerdetail,0
# Other table,gcct_onlinegaragevehicles,0
# Other table,gcct_partsorderstatus,0
# Other table,gcct_partsordersystems,0
# Priority table,gcct_partssmeassistancerequest,6374
# Other table,gcct_pcarequest,1333
# Other table,gcct_priordealerdecision,0
# Other table,gcct_qaincident,0
# Other table,gcct_qamonitoring,0
# Other table,gcct_queuepriority,66
# Priority table,gcct_ravprocessingmilestones,107638
# Other table,gcct_reactdata,0
# Other table,gcct_reacttransmission,0
# Other table,gcct_reasoncode,0
# Priority table,gcct_recall,7161
# Other table,gcct_region,0
# Other table,gcct_rentaldetail,31679
# Other table,gcct_slaconfiguration,0
# Other table,gcct_sms,0
# Priority table,gcct_socialmediaconversation,0
# Priority table,gcct_socialmediamessage,0
# Other table,gcct_socialmediaprofile,278
# Other table,gcct_specialloanercode,0
# Other table,gcct_state,0
# Priority table,gcct_surveyconfiguration,26
# Other table,gcct_symptomclassification,0
# Other table,gcct_tasktype,0
# Priority table,gcct_technicalassistancerequest,9403
# Other table,gcct_testdriverequest,1580
# Other table,gcct_timezone,0
# Other table,gcct_userdelegationofauthority,719
# Priority table,gcct_vehicle,0
# Other table,gcct_vehiclebrand,0
# Other table,gcct_vehicleclass,0
# Other table,gcct_vehicleloyaltyallowance,633
# Other table,gcct_vehicleoffroad,0
# Other table,gcct_vehicleowner,953480
# Other table,gcct_warrantyhistory,3960
# Other table,gcct_warrantyloanerpartsdelay,5988
# Priority table,gcct_warrantyloanerrequest,7889
# Other table,gcct_warrantyloanerrequesthistory,30
# Priority table,globaloptionsetmetadata,0
# Priority table,incident,5800
# Other table,incidentresolution,0
# Other table,letter,159
# Other table,msdyn_answer,0
# Priority table,msdyn_question,56
# Priority table,msdyn_questionresponse,1
# Priority table,msdyn_survey,7
# Priority table,msdyn_surveyinvite,0
# Priority table,msdyn_surveyresponse,1
# Priority table,optionsetmetadata,0
# Priority table,phonecall,0
# Other table,queue,697
# Priority table,queueitem,895991
# Other table,sla,0
# Other table,slaitem,0
# Priority table,slakpiinstance,17839
# Other table,socialactivity,0
# Other table,socialprofile,0
# Priority table,statemetadata,0
# Priority table,statusmetadata,0
# Priority table,systemuser,8272
# Priority table,task,11010
# Priority table,team,9
# Other table,teammembership,1300
# Priority table,territory,14
# Total: 10172674

# %%
print("data_captured_on 05-14-2019 08:40AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-14-2019 08:40AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,934174
# True,account,81361
# False,activityparty,8597248
# True,annotation,0
# True,appointment,394787
# True,businessunit,0
# True,calendar,0
# True,calendarrule,0
# True,contact,33551
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,11641
# True,fax,427
# False,gcct_accountresponsibleagent,859
# False,gcct_additionalsymptomcodes,1004
# True,gcct_addportalmessage,58380
# False,gcct_arbitrationclaimprocessing,2420
# True,gcct_buybackevaluationmilestones,8554
# True,gcct_caseassignment,625226
# False,gcct_caseclassification,36
# False,gcct_casedispositiontype,0
# False,gcct_coachback,564
# False,gcct_country,0
# False,gcct_customersatisfactiontools,1217
# False,gcct_delegationofauthority,0
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,7
# True,gcct_documentcustomerrecontact,2318
# False,gcct_engine,0
# False,gcct_executive,0
# False,gcct_executiveliaison,0
# True,gcct_fieldinvolvementassistancerequest,4
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,7396
# False,gcct_genericinformationtopic,5568
# False,gcct_generictopic,0
# False,gcct_goodfaithreview,22231
# False,gcct_knownpartsdelay,1
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,31979
# False,gcct_loyaltycostdetails,8029
# False,gcct_loyaltyprogramcode,0
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,269
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,7268
# False,gcct_pcarequest,1855
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,66
# True,gcct_ravprocessingmilestones,147872
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,0
# True,gcct_recall,12001
# False,gcct_region,0
# False,gcct_rentaldetail,32896
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,0
# False,gcct_socialmediaprofile,297
# False,gcct_specialloanercode,0
# False,gcct_state,0
# True,gcct_surveyconfiguration,43
# False,gcct_symptomclassification,0
# False,gcct_tasktype,0
# True,gcct_technicalassistancerequest,9655
# False,gcct_testdriverequest,1580
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,719
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,0
# False,gcct_vehicleloyaltyallowance,692
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,1621943
# False,gcct_warrantyhistory,4249
# False,gcct_warrantyloanerpartsdelay,6332
# True,gcct_warrantyloanerrequest,8669
# False,gcct_warrantyloanerrequesthistory,40
# True,globaloptionsetmetadata,99
# True,incident,50417
# False,incidentresolution,0
# False,letter,194
# False,msdyn_answer,0
# True,msdyn_question,56
# True,msdyn_questionresponse,1
# True,msdyn_survey,7
# True,msdyn_surveyinvite,0
# True,msdyn_surveyresponse,1
# True,optionsetmetadata,0
# True,phonecall,0
# False,queue,733
# True,queueitem,914921
# False,sla,0
# False,slaitem,0
# True,slakpiinstance,29924
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,378
# True,statusmetadata,0
# True,systemuser,8506
# True,task,11611
# True,team,9
# False,teammembership,1496
# True,territory,19
# Total: 13704525

# %%
print("data_captured_on 05-23-2019 11:40AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-23-2019 11:40AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,7888060
# True,account,177560
# False,activityparty,6060
# True,annotation,0
# True,appointment,225374
# True,businessunit,0
# True,calendar,0
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,212493
# True,fax,225
# False,gcct_accountresponsibleagent,1393
# False,gcct_additionalsymptomcodes,1120
# True,gcct_addportalmessage,30155
# False,gcct_arbitrationclaimprocessing,1166
# True,gcct_buybackevaluationmilestones,5862
# True,gcct_caseassignment,145205
# False,gcct_caseclassification,478
# False,gcct_casedispositiontype,0
# False,gcct_coachback,303
# False,gcct_country,0
# False,gcct_customersatisfactiontools,221
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,11
# True,gcct_documentcustomerrecontact,1027
# False,gcct_engine,0
# False,gcct_executive,0
# False,gcct_executiveliaison,21
# True,gcct_fieldinvolvementassistancerequest,2
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,8494
# False,gcct_genericinformationtopic,6574
# False,gcct_generictopic,0
# False,gcct_goodfaithreview,3757
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,19725
# False,gcct_loyaltycostdetails,5763
# False,gcct_loyaltyprogramcode,23
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,263
# False,gcct_offer,1
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,6220
# False,gcct_pcarequest,1651
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,49
# True,gcct_ravprocessingmilestones,115727
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,0
# True,gcct_recall,31457
# False,gcct_region,0
# False,gcct_rentaldetail,8264
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,0
# False,gcct_socialmediaprofile,977
# False,gcct_specialloanercode,0
# False,gcct_state,0
# True,gcct_surveyconfiguration,19
# False,gcct_symptomclassification,0
# False,gcct_tasktype,0
# True,gcct_technicalassistancerequest,2129
# False,gcct_testdriverequest,151
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,67
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,0
# False,gcct_vehicleloyaltyallowance,644
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3477510
# False,gcct_warrantyhistory,2350
# False,gcct_warrantyloanerpartsdelay,3419
# True,gcct_warrantyloanerrequest,5578
# False,gcct_warrantyloanerrequesthistory,37
# True,globaloptionsetmetadata,0
# True,incident,478546
# False,incidentresolution,0
# False,letter,5435
# False,msdyn_answer,0
# True,msdyn_question,56
# True,msdyn_questionresponse,360
# True,msdyn_survey,8
# True,msdyn_surveyinvite,775
# True,msdyn_surveyresponse,59
# True,optionsetmetadata,0
# True,phonecall,0
# False,queue,271
# True,queueitem,117572
# False,sla,0
# False,slaitem,0
# True,slakpiinstance,80319
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,378
# True,statusmetadata,0
# True,systemuser,523
# True,task,7357
# True,team,15
# False,teammembership,1562
# True,territory,33
# False,gcct_marketingprogram,0
# Total: 13140745

# %%
print("data_captured_on 05-24-2019 10:30AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-24-2019 10:30AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,9252453
# True,account,190855
# False,activityparty,6060
# True,annotation,0
# True,appointment,233582
# True,businessunit,0
# True,calendar,0
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,216067
# True,fax,228
# False,gcct_accountresponsibleagent,1405
# False,gcct_additionalsymptomcodes,1185
# True,gcct_addportalmessage,31790
# False,gcct_arbitrationclaimprocessing,1192
# True,gcct_buybackevaluationmilestones,6239
# True,gcct_caseassignment,161983
# False,gcct_caseclassification,479
# False,gcct_casedispositiontype,0
# False,gcct_coachback,307
# False,gcct_country,0
# False,gcct_customersatisfactiontools,225
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,15
# True,gcct_documentcustomerrecontact,1051
# False,gcct_engine,0
# False,gcct_executive,0
# False,gcct_executiveliaison,24
# True,gcct_fieldinvolvementassistancerequest,2
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,8855
# False,gcct_genericinformationtopic,6688
# False,gcct_generictopic,0
# False,gcct_goodfaithreview,4003
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,20533
# False,gcct_loyaltycostdetails,6157
# False,gcct_loyaltyprogramcode,23
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,264
# False,gcct_offer,1
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,6603
# False,gcct_pcarequest,1651
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,49
# True,gcct_ravprocessingmilestones,152676
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,0
# True,gcct_recall,36854
# False,gcct_region,0
# False,gcct_rentaldetail,8277
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,0
# False,gcct_socialmediaprofile,986
# False,gcct_specialloanercode,0
# False,gcct_state,0
# True,gcct_surveyconfiguration,19
# False,gcct_symptomclassification,0
# False,gcct_tasktype,0
# True,gcct_technicalassistancerequest,2175
# False,gcct_testdriverequest,152
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,68
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,0
# False,gcct_vehicleloyaltyallowance,659
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3493511
# False,gcct_warrantyhistory,2615
# False,gcct_warrantyloanerpartsdelay,3422
# True,gcct_warrantyloanerrequest,5584
# False,gcct_warrantyloanerrequesthistory,42
# True,globaloptionsetmetadata,0
# True,incident,504854
# False,incidentresolution,0
# False,letter,5436
# False,msdyn_answer,0
# True,msdyn_question,56
# True,msdyn_questionresponse,455
# True,msdyn_survey,8
# True,msdyn_surveyinvite,956
# True,msdyn_surveyresponse,75
# True,optionsetmetadata,0
# True,phonecall,0
# False,queue,298
# True,queueitem,136759
# False,sla,0
# False,slaitem,0
# True,slakpiinstance,92974
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,378
# True,statusmetadata,0
# True,systemuser,547
# True,task,7610
# True,team,15
# False,teammembership,1614
# True,territory,44
# False,gcct_marketingprogram,0
# Total: 14668979

# %%
print("data_captured_on 05-28-2019 10:55AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-28-2019 10:55AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,14691340
# True,account,279043
# False,activityparty,6060
# True,annotation,0
# True,appointment,333938
# True,businessunit,0
# True,calendar,0
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,253569
# True,fax,313
# False,gcct_accountresponsibleagent,9964
# False,gcct_additionalsymptomcodes,1310
# True,gcct_addportalmessage,43302
# False,gcct_arbitrationclaimprocessing,1585
# True,gcct_buybackevaluationmilestones,8069
# True,gcct_caseassignment,198276
# False,gcct_caseclassification,484
# False,gcct_casedispositiontype,0
# False,gcct_coachback,401
# False,gcct_country,0
# False,gcct_customersatisfactiontools,347
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,15
# True,gcct_documentcustomerrecontact,1518
# False,gcct_engine,0
# False,gcct_executive,0
# False,gcct_executiveliaison,25
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,10465
# False,gcct_genericinformationtopic,8456
# False,gcct_generictopic,0
# False,gcct_goodfaithreview,5146
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,27777
# False,gcct_loyaltycostdetails,8081
# False,gcct_loyaltyprogramcode,23
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,304
# False,gcct_offer,1
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,9867
# False,gcct_pcarequest,2483
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,49
# True,gcct_ravprocessingmilestones,221710
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,0
# True,gcct_recall,42470
# False,gcct_region,0
# False,gcct_rentaldetail,11635
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,0
# False,gcct_socialmediaprofile,1156
# False,gcct_specialloanercode,0
# False,gcct_state,0
# True,gcct_surveyconfiguration,19
# False,gcct_symptomclassification,0
# False,gcct_tasktype,0
# True,gcct_technicalassistancerequest,3072
# False,gcct_testdriverequest,200
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,68
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,0
# False,gcct_vehicleloyaltyallowance,930
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3557044
# False,gcct_warrantyhistory,3059
# False,gcct_warrantyloanerpartsdelay,4679
# True,gcct_warrantyloanerrequest,8214
# False,gcct_warrantyloanerrequesthistory,52
# True,globaloptionsetmetadata,0
# True,incident,603959
# False,incidentresolution,0
# False,letter,5522
# False,msdyn_answer,0
# True,msdyn_question,56
# True,msdyn_questionresponse,596
# True,msdyn_survey,8
# True,msdyn_surveyinvite,1183
# True,msdyn_surveyresponse,96
# True,optionsetmetadata,0
# True,phonecall,0
# False,queue,345
# True,queueitem,165260
# False,sla,0
# False,slaitem,0
# True,slakpiinstance,116851
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,378
# True,statusmetadata,0
# True,systemuser,616
# True,task,9775
# True,team,15
# False,teammembership,1618
# True,territory,45
# False,gcct_marketingprogram,0
# Total: 20712736

# %%
print("data_captured_on 05-29-2019 1:00 PM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-29-2019 1:00 PM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,15973034
# True,account,294125
# False,activityparty,6060
# True,annotation,0
# True,appointment,340032
# True,businessunit,0
# True,calendar,0
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,255291
# True,fax,331
# False,gcct_accountresponsibleagent,10034
# False,gcct_additionalsymptomcodes,1378
# True,gcct_addportalmessage,44042
# False,gcct_arbitrationclaimprocessing,1627
# True,gcct_buybackevaluationmilestones,8474
# True,gcct_caseassignment,216117
# False,gcct_caseclassification,484
# False,gcct_casedispositiontype,0
# False,gcct_coachback,409
# False,gcct_country,0
# False,gcct_customersatisfactiontools,356
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,15
# True,gcct_documentcustomerrecontact,1550
# False,gcct_engine,0
# False,gcct_executive,0
# False,gcct_executiveliaison,26
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,10860
# False,gcct_genericinformationtopic,8675
# False,gcct_generictopic,0
# False,gcct_goodfaithreview,5340
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,28415
# False,gcct_loyaltycostdetails,43604
# False,gcct_loyaltyprogramcode,23
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,306
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,10033
# False,gcct_pcarequest,2626
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,49
# True,gcct_ravprocessingmilestones,234413
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,0
# True,gcct_recall,47920
# False,gcct_region,0
# False,gcct_rentaldetail,11814
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1174
# False,gcct_specialloanercode,0
# False,gcct_state,0
# True,gcct_surveyconfiguration,19
# False,gcct_symptomclassification,0
# False,gcct_tasktype,0
# True,gcct_technicalassistancerequest,3154
# False,gcct_testdriverequest,200
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,101
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,0
# False,gcct_vehicleloyaltyallowance,948
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3597229
# False,gcct_warrantyhistory,3266
# False,gcct_warrantyloanerpartsdelay,4715
# True,gcct_warrantyloanerrequest,8311
# False,gcct_warrantyloanerrequesthistory,61
# True,globaloptionsetmetadata,0
# True,incident,635826
# False,incidentresolution,0
# False,letter,5522
# False,msdyn_answer,0
# True,msdyn_question,56
# True,msdyn_questionresponse,603
# True,msdyn_survey,8
# True,msdyn_surveyinvite,1268
# True,msdyn_surveyresponse,97
# True,optionsetmetadata,0
# True,phonecall,376508
# False,queue,367
# True,queueitem,182131
# False,sla,12
# False,slaitem,12
# True,slakpiinstance,128509
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,378
# True,statusmetadata,0
# True,systemuser,681
# True,task,10076
# True,team,16
# False,teammembership,1679
# True,territory,45
# False,gcct_marketingprogram,0
# Total: 22571057

# %%
print("data_captured_on 05-30-2019 1:00 PM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-30-2019 1:00 PM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,16959224
# True,account,314792
# False,activityparty,6060
# True,annotation,0
# True,appointment,348732
# True,businessunit,8
# True,calendar,0
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,259126
# True,fax,344
# False,gcct_accountresponsibleagent,10746
# False,gcct_additionalsymptomcodes,1432
# True,gcct_addportalmessage,45049
# False,gcct_arbitrationclaimprocessing,1673
# True,gcct_buybackevaluationmilestones,8889
# True,gcct_caseassignment,226157
# False,gcct_caseclassification,566
# False,gcct_casedispositiontype,0
# False,gcct_coachback,426
# False,gcct_country,0
# False,gcct_customersatisfactiontools,374
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,90
# True,gcct_documentcustomerrecontact,1602
# False,gcct_engine,175
# False,gcct_executive,0
# False,gcct_executiveliaison,27
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,11214
# False,gcct_genericinformationtopic,8927
# False,gcct_generictopic,82
# False,gcct_goodfaithreview,5572
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,29115
# False,gcct_loyaltycostdetails,44531
# False,gcct_loyaltyprogramcode,105
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,310
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,10382
# False,gcct_pcarequest,2784
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,136
# True,gcct_ravprocessingmilestones,246226
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,5
# True,gcct_recall,49432
# False,gcct_region,3
# False,gcct_rentaldetail,12179
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1190
# False,gcct_specialloanercode,0
# False,gcct_state,74
# True,gcct_surveyconfiguration,31
# False,gcct_symptomclassification,0
# False,gcct_tasktype,40
# True,gcct_technicalassistancerequest,3275
# False,gcct_testdriverequest,202
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,101
# True,gcct_vehicle,0
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,23
# False,gcct_vehicleloyaltyallowance,986
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3608876
# False,gcct_warrantyhistory,3433
# False,gcct_warrantyloanerpartsdelay,4803
# True,gcct_warrantyloanerrequest,8533
# False,gcct_warrantyloanerrequesthistory,66
# True,globaloptionsetmetadata,641
# True,incident,657498
# False,incidentresolution,0
# False,letter,5548
# False,msdyn_answer,100
# True,msdyn_question,56
# True,msdyn_questionresponse,639
# True,msdyn_survey,8
# True,msdyn_surveyinvite,1431
# True,msdyn_surveyresponse,102
# True,optionsetmetadata,2992
# True,phonecall,716494
# False,queue,947
# True,queueitem,189990
# False,sla,87
# False,slaitem,149
# True,slakpiinstance,136790
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,756
# True,statusmetadata,0
# True,systemuser,700
# True,task,10417
# True,team,159
# False,teammembership,1683
# True,territory,346
# False,gcct_marketingprogram,0
# Total: 24016283

# %%
print("data_captured_on 05-31-2019 10:30 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 05-31-2019 10:30 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,18799403
# True,account,354299
# False,activityparty,6060
# True,annotation,17417
# True,appointment,389019
# True,businessunit,11
# True,calendar,564
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,273263
# True,fax,390
# False,gcct_accountresponsibleagent,11099
# False,gcct_additionalsymptomcodes,1518
# True,gcct_addportalmessage,49443
# False,gcct_arbitrationclaimprocessing,1765
# True,gcct_buybackevaluationmilestones,9677
# True,gcct_caseassignment,243813
# False,gcct_caseclassification,587
# False,gcct_casedispositiontype,0
# False,gcct_coachback,481
# False,gcct_country,0
# False,gcct_customersatisfactiontools,415
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,112
# True,gcct_documentcustomerrecontact,1779
# False,gcct_engine,221
# False,gcct_executive,0
# False,gcct_executiveliaison,32
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,12086
# False,gcct_genericinformationtopic,9538
# False,gcct_generictopic,100
# False,gcct_goodfaithreview,6081
# False,gcct_knownpartsdelay,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,31845
# False,gcct_loyaltycostdetails,47228
# False,gcct_loyaltyprogramcode,127
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,332
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,11636
# False,gcct_pcarequest,3169
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,153
# True,gcct_ravprocessingmilestones,276932
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,10
# True,gcct_recall,52230
# False,gcct_region,3
# False,gcct_rentaldetail,13556
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1234
# False,gcct_specialloanercode,0
# False,gcct_state,88
# True,gcct_surveyconfiguration,36
# False,gcct_symptomclassification,0
# False,gcct_tasktype,48
# True,gcct_technicalassistancerequest,3672
# False,gcct_testdriverequest,212
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,101
# True,gcct_vehicle,581
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,26
# False,gcct_vehicleloyaltyallowance,1104
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3628848
# False,gcct_warrantyhistory,3704
# False,gcct_warrantyloanerpartsdelay,5374
# True,gcct_warrantyloanerrequest,9652
# False,gcct_warrantyloanerrequesthistory,73
# True,globaloptionsetmetadata,869
# True,incident,702552
# False,incidentresolution,0
# False,letter,5586
# False,msdyn_answer,130
# True,msdyn_question,56
# True,msdyn_questionresponse,700
# True,msdyn_survey,8
# True,msdyn_surveyinvite,1613
# True,msdyn_surveyresponse,113
# True,optionsetmetadata,3352
# True,phonecall,831661
# False,queue,1090
# True,queueitem,204686
# False,sla,103
# False,slaitem,184
# True,slakpiinstance,153264
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,756
# True,statusmetadata,456
# True,systemuser,720
# True,task,11362
# True,team,197
# False,teammembership,1694
# True,territory,427
# False,gcct_marketingprogram,0
# Total: 26253348

# %%
print("data_captured_on 06-03-2019 1:00 PM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 06-03-2019 1:00 PM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,25547390
# True,account,419895
# False,activityparty,6060
# True,annotation,50888
# True,appointment,454420
# True,businessunit,11
# True,calendar,571
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,293562
# True,fax,418
# False,gcct_accountresponsibleagent,11334
# False,gcct_additionalsymptomcodes,1646
# True,gcct_addportalmessage,56464
# False,gcct_arbitrationclaimprocessing,1946
# True,gcct_buybackevaluationmilestones,10996
# True,gcct_caseassignment,275272
# False,gcct_caseclassification,604
# False,gcct_casedispositiontype,0
# False,gcct_coachback,562
# False,gcct_country,0
# False,gcct_customersatisfactiontools,458
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,118
# True,gcct_documentcustomerrecontact,2054
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,36
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,13293
# False,gcct_genericinformationtopic,10406
# False,gcct_generictopic,116
# False,gcct_goodfaithreview,6765
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,34584
# False,gcct_loyaltycostdetails,50694
# False,gcct_loyaltyprogramcode,136
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,365
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,13500
# False,gcct_pcarequest,3650
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,172
# True,gcct_ravprocessingmilestones,329476
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,56781
# False,gcct_region,3
# False,gcct_rentaldetail,14891
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1280
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,38
# False,gcct_symptomclassification,0
# False,gcct_tasktype,55
# True,gcct_technicalassistancerequest,4241
# False,gcct_testdriverequest,249
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,102
# True,gcct_vehicle,2846
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,1222
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3668835
# False,gcct_warrantyhistory,4225
# False,gcct_warrantyloanerpartsdelay,6378
# True,gcct_warrantyloanerrequest,10934
# False,gcct_warrantyloanerrequesthistory,85
# True,globaloptionsetmetadata,1021
# True,incident,762697
# False,incidentresolution,0
# False,letter,5617
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,822
# True,msdyn_survey,8
# True,msdyn_surveyinvite,1949
# True,msdyn_surveyresponse,130
# True,optionsetmetadata,3544
# True,phonecall,934441
# False,queue,1235
# True,queueitem,226980
# False,sla,114
# False,slaitem,207
# True,slakpiinstance,175506
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,756
# True,statusmetadata,456
# True,systemuser,82983
# True,task,12538
# True,team,220
# False,teammembership,1707
# True,territory,466
# False,gcct_marketingprogram,0
# Total: 33634650

# %%
print("data_captured_on 06-04-2019 12:30 PM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 06-04-2019 12:30 PM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,26818082
# True,account,421217
# False,activityparty,6060
# True,annotation,59133
# True,appointment,456953
# True,businessunit,11
# True,calendar,571
# True,calendarrule,0
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,293589
# True,fax,418
# False,gcct_accountresponsibleagent,11342
# False,gcct_additionalsymptomcodes,1693
# True,gcct_addportalmessage,56605
# False,gcct_arbitrationclaimprocessing,1946
# True,gcct_buybackevaluationmilestones,11189
# True,gcct_caseassignment,284990
# False,gcct_caseclassification,604
# False,gcct_casedispositiontype,0
# False,gcct_coachback,562
# False,gcct_country,0
# False,gcct_customersatisfactiontools,458
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,118
# True,gcct_documentcustomerrecontact,2069
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,36
# True,gcct_fieldinvolvementassistancerequest,3
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,13531
# False,gcct_genericinformationtopic,10561
# False,gcct_generictopic,116
# False,gcct_goodfaithreview,6860
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,34718
# False,gcct_loyaltycostdetails,50964
# False,gcct_loyaltyprogramcode,136
# False,gcct_material,0
# False,gcct_materialrequest,0
# False,gcct_materialrequestdetail,365
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,13516
# False,gcct_pcarequest,3650
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,172
# True,gcct_ravprocessingmilestones,329476
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,59426
# False,gcct_region,3
# False,gcct_rentaldetail,14897
# False,gcct_slaconfiguration,0
# False,gcct_sms,0
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1280
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,38
# False,gcct_symptomclassification,0
# False,gcct_tasktype,55
# True,gcct_technicalassistancerequest,4259
# False,gcct_testdriverequest,249
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,102
# True,gcct_vehicle,4131
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,1227
# False,gcct_vehicleoffroad,0
# False,gcct_vehicleowner,3685216
# False,gcct_warrantyhistory,4414
# False,gcct_warrantyloanerpartsdelay,6378
# True,gcct_warrantyloanerrequest,10936
# False,gcct_warrantyloanerrequesthistory,86
# True,globaloptionsetmetadata,1021
# True,incident,788186
# False,incidentresolution,0
# False,letter,5621
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,834
# True,msdyn_survey,8
# True,msdyn_surveyinvite,2026
# True,msdyn_surveyresponse,132
# True,optionsetmetadata,3544
# True,phonecall,936536
# False,queue,1242
# True,queueitem,236001
# False,sla,114
# False,slaitem,207
# True,slakpiinstance,183644
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,756
# True,statusmetadata,456
# True,systemuser,82999
# True,task,12703
# True,team,220
# False,teammembership,1766
# True,territory,467
# False,gcct_marketingprogram,0
# Total: 34994117

# %%
print("data_captured_on 06-13-2019 10:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 06-13-2019 10:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,44567736
# True,account,608348
# False,activityparty,6060
# True,annotation,236426
# True,appointment,637803
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,49887
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,343850
# True,fax,531
# False,gcct_accountresponsibleagent,12715
# False,gcct_additionalsymptomcodes,2318
# True,gcct_addportalmessage,77447
# False,gcct_arbitrationclaimprocessing,2504
# True,gcct_buybackevaluationmilestones,15694
# True,gcct_caseassignment,400759
# False,gcct_caseclassification,631
# False,gcct_casedispositiontype,0
# False,gcct_coachback,674
# False,gcct_country,0
# False,gcct_customersatisfactiontools,667
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,118
# True,gcct_documentcustomerrecontact,2799
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,50
# True,gcct_fieldinvolvementassistancerequest,5
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,18199
# False,gcct_genericinformationtopic,13901
# False,gcct_generictopic,144
# False,gcct_goodfaithreview,9509
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,46883
# False,gcct_loyaltycostdetails,64556
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,96
# False,gcct_materialrequestdetail,461
# False,gcct_offer,725
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,19148
# False,gcct_pcarequest,5611
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,172
# True,gcct_ravprocessingmilestones,484577
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,80063
# False,gcct_region,3
# False,gcct_rentaldetail,20511
# False,gcct_slaconfiguration,0
# False,gcct_sms,3
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1608
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,55
# True,gcct_technicalassistancerequest,6020
# False,gcct_testdriverequest,386
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,233
# True,gcct_vehicle,15091
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,1682
# False,gcct_vehicleoffroad,76328
# False,gcct_vehicleowner,3803643
# False,gcct_warrantyhistory,6939
# False,gcct_warrantyloanerpartsdelay,8769
# True,gcct_warrantyloanerrequest,15813
# False,gcct_warrantyloanerrequesthistory,140
# True,globaloptionsetmetadata,1021
# True,incident,853122
# False,incidentresolution,116000
# False,letter,5860
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,1541
# True,msdyn_survey,11
# True,msdyn_surveyinvite,3707
# True,msdyn_surveyresponse,239
# True,optionsetmetadata,3544
# True,phonecall,1076313
# False,queue,1522
# True,queueitem,336433
# False,sla,114
# False,slaitem,207
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,756
# True,statusmetadata,456
# True,systemuser,83749
# True,task,16936
# True,team,222
# False,teammembership,2378
# True,territory,469
# False,gcct_marketingprogram,12615
# Total: 54414708

# %%
print("data_captured_on 06-21-2019 10:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 06-21-2019 10:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,60922470
# True,account,778516
# False,activityparty,6060
# True,annotation,373080
# True,appointment,795130
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,96309
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,386288
# True,fax,636
# False,gcct_accountresponsibleagent,13729
# False,gcct_additionalsymptomcodes,2873
# True,gcct_addportalmessage,97447
# False,gcct_arbitrationclaimprocessing,3035
# True,gcct_buybackevaluationmilestones,19361
# True,gcct_caseassignment,506735
# False,gcct_caseclassification,643
# False,gcct_casedispositiontype,0
# False,gcct_coachback,777
# False,gcct_country,0
# False,gcct_customersatisfactiontools,848
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,119
# True,gcct_documentcustomerrecontact,3556
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,70
# True,gcct_fieldinvolvementassistancerequest,6
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,23593
# False,gcct_genericinformationtopic,17369
# False,gcct_generictopic,144
# False,gcct_goodfaithreview,11829
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,59091
# False,gcct_loyaltycostdetails,77354
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,193
# False,gcct_materialrequestdetail,538
# False,gcct_offer,726
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,25323
# False,gcct_pcarequest,7599
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,172
# True,gcct_ravprocessingmilestones,640991
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,96772
# False,gcct_region,3
# False,gcct_rentaldetail,26791
# False,gcct_slaconfiguration,0
# False,gcct_sms,7
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,1860
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,56
# True,gcct_technicalassistancerequest,7617
# False,gcct_testdriverequest,465
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,236
# True,gcct_vehicle,24377
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,2208
# False,gcct_vehicleoffroad,135941
# False,gcct_vehicleowner,3911479
# False,gcct_warrantyhistory,8761
# False,gcct_warrantyloanerpartsdelay,11151
# True,gcct_warrantyloanerrequest,20951
# False,gcct_warrantyloanerrequesthistory,209
# True,globaloptionsetmetadata,11276
# True,incident,981436
# False,incidentresolution,250819
# False,letter,5906
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,2518
# True,msdyn_survey,11
# True,msdyn_surveyinvite,6109
# True,msdyn_surveyresponse,386
# True,optionsetmetadata,15585
# True,phonecall,1204278
# False,queue,1819
# True,queueitem,425775
# False,sla,114
# False,slaitem,207
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,3068
# True,statusmetadata,3275
# True,systemuser,129057
# True,task,20892
# True,team,236
# False,teammembership,2378
# True,territory,475
# False,gcct_marketingprogram,23948
# Total: 72440264

# %%
print("data_captured_on 07-01-2019 12:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-01-2019 12:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,82311211
# True,account,968110
# False,activityparty,6060
# True,annotation,566600
# True,appointment,960042
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,665781
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,420213
# True,fax,768
# False,gcct_accountresponsibleagent,14146
# False,gcct_additionalsymptomcodes,3391
# True,gcct_addportalmessage,117219
# False,gcct_arbitrationclaimprocessing,3852
# True,gcct_buybackevaluationmilestones,22823
# True,gcct_caseassignment,613052
# False,gcct_caseclassification,643
# False,gcct_casedispositiontype,776
# False,gcct_coachback,883
# False,gcct_country,0
# False,gcct_customersatisfactiontools,1015
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,119
# True,gcct_documentcustomerrecontact,4378
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,99
# True,gcct_fieldinvolvementassistancerequest,10
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,32736
# False,gcct_genericinformationtopic,23208
# False,gcct_generictopic,144
# False,gcct_goodfaithreview,14248
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,72182
# False,gcct_loyaltycostdetails,92261
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,293
# False,gcct_materialrequestdetail,630
# False,gcct_offer,726
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,32447
# False,gcct_pcarequest,9601
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,174
# True,gcct_ravprocessingmilestones,799368
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,111576
# False,gcct_region,3
# False,gcct_rentaldetail,33897
# False,gcct_slaconfiguration,0
# False,gcct_sms,14
# True,gcct_socialmediaconversation,0
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,2136
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,84
# True,gcct_technicalassistancerequest,9453
# False,gcct_testdriverequest,642
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,263
# True,gcct_vehicle,42458
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,2718
# False,gcct_vehicleoffroad,159039
# False,gcct_vehicleowner,4010655
# False,gcct_warrantyhistory,10354
# False,gcct_warrantyloanerpartsdelay,14195
# True,gcct_warrantyloanerrequest,27022
# False,gcct_warrantyloanerrequesthistory,308
# True,globaloptionsetmetadata,11276
# True,incident,1172431
# False,incidentresolution,472538
# False,letter,5909
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,3738
# True,msdyn_survey,11
# True,msdyn_surveyinvite,8977
# True,msdyn_surveyresponse,571
# True,optionsetmetadata,15585
# True,phonecall,1333068
# False,queue,2242
# True,queueitem,507880
# False,sla,114
# False,slaitem,207
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,3068
# True,statusmetadata,3275
# True,systemuser,130206
# True,task,25325
# True,team,284
# False,teammembership,2378
# True,territory,483
# False,gcct_marketingprogram,23948
# Total: 96136742

# %%
print("data_captured_on 07-02-2019 10:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-02-2019 10:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,84370130
# True,account,976946
# False,activityparty,6060
# True,annotation,582330
# True,appointment,965988
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,679285
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,420660
# True,fax,768
# False,gcct_accountresponsibleagent,14235
# False,gcct_additionalsymptomcodes,3488
# True,gcct_addportalmessage,117661
# False,gcct_arbitrationclaimprocessing,3852
# True,gcct_buybackevaluationmilestones,23197
# True,gcct_caseassignment,627657
# False,gcct_caseclassification,643
# False,gcct_casedispositiontype,776
# False,gcct_coachback,890
# False,gcct_country,0
# False,gcct_customersatisfactiontools,1023
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,119
# True,gcct_documentcustomerrecontact,4465
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,99
# True,gcct_fieldinvolvementassistancerequest,10
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,34066
# False,gcct_genericinformationtopic,24129
# False,gcct_generictopic,144
# False,gcct_goodfaithreview,14512
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,72770
# False,gcct_loyaltycostdetails,93207
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,293
# False,gcct_materialrequestdetail,630
# False,gcct_offer,726
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,32561
# False,gcct_pcarequest,9601
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,174
# True,gcct_ravprocessingmilestones,799368
# False,gcct_reactdata,0
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,114343
# False,gcct_region,3
# False,gcct_rentaldetail,33929
# False,gcct_slaconfiguration,0
# False,gcct_sms,14
# True,gcct_socialmediaconversation,3
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,2142
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,84
# True,gcct_technicalassistancerequest,9525
# False,gcct_testdriverequest,642
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,265
# True,gcct_vehicle,52610
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,2745
# False,gcct_vehicleoffroad,159039
# False,gcct_vehicleowner,4022173
# False,gcct_warrantyhistory,10664
# False,gcct_warrantyloanerpartsdelay,14198
# True,gcct_warrantyloanerrequest,27028
# False,gcct_warrantyloanerrequesthistory,312
# True,globaloptionsetmetadata,11276
# True,incident,1194354
# False,incidentresolution,476775
# False,letter,5909
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,3765
# True,msdyn_survey,11
# True,msdyn_surveyinvite,9260
# True,msdyn_surveyresponse,575
# True,optionsetmetadata,15585
# True,phonecall,1339669
# False,queue,2296
# True,queueitem,520317
# False,sla,117
# False,slaitem,207
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,3068
# True,statusmetadata,3275
# True,systemuser,130777
# True,task,25582
# True,team,290
# False,teammembership,2378
# True,territory,483
# False,gcct_marketingprogram,23948
# Total: 98331301

# %%
print("data_captured_on 07-16-2019 10:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['gcct_country','gcct_demandltrtpsmclaimsprocessing','gcct_executive','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_lemonlawcriteria','gcct_loanercost','gcct_material','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_reactdata','gcct_reacttransmission','gcct_slaconfiguration','gcct_specialloanercode','gcct_symptomclassification','gcct_timezone','gcct_vehiclebrand','socialactivity','socialprofile','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-16-2019 10:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,gcct_country,0
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_executive,0
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# False,gcct_material,0
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_reactdata,61726
# False,gcct_reacttransmission,0
# False,gcct_slaconfiguration,0
# False,gcct_specialloanercode,0
# False,gcct_symptomclassification,0
# False,gcct_timezone,0
# False,gcct_vehiclebrand,0
# False,socialactivity,0
# False,socialprofile,0
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# Total: 61726

# %%
tab_1=['account','activityparty','annotation','appointment','businessunit','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_activitycaseclassificationconfiguration','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_akmsendpoint','gcct_arbitrationclaimprocessing','gcct_autonotificationconfiguration','gcct_bactask','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseassignmentconfiguration','gcct_caseclassification','gcct_caseclassification_team','gcct_casedispositiontype','gcct_casedispositiontype_caseclassification','gcct_casedispositiontype_team','gcct_coachback','gcct_country','gcct_customactivityconfigurationcustomactivi','gcct_customactivityteamconfiguration','gcct_customconfiguration','gcct_customersatisfactiontools','gcct_customersatisfactiontoolsconfiguration','gcct_dealercasecategoryconfiguration','gcct_dealercaseclosureconfiguration','gcct_dealerteamcountryconfiguration','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_emailtemplateaccess','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_externalkbarticle','gcct_externalknowledgearticle','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_gcct_emailtemplateaccess_team','gcct_gcct_smartlink_team','gcct_gcct_symptomclassification_incident','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_integrationcaseconfiguration','gcct_integrationerrordetail','gcct_interfaceconfiguration','gcct_knownpartsdelay','gcct_languageresource','gcct_lemonlawcriteria','gcct_liveassistagentsurveycategory','gcct_loanercost','gcct_location','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_marketingprogram','gcct_masterdispositions','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_messagetracker','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_parameter','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistanceconfiguration','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_phoneextension','gcct_portalmessageconfiguration','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_relatedvehicles','gcct_rentaldetail','gcct_slaconfiguration','gcct_smartlink','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tacassistancerequest','gcct_tasktype','gcct_tasktype_team','gcct_team_gcct_relatedcountry','gcct_team_systemuser','gcct_team_team_canassigntoteam','gcct_teamastuteendpoint','gcct_teamgenerictopicconfiguration','gcct_teamtasktypeconfiguration','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_transmissionspecs','gcct_usd_announcement','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleloyaltyconfiguration','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequestconfiguration','gcct_warrantyloanerrequesthistory','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_question_answer_n_n','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','phonecall','queue','queueitem','queuemembership','sla','slakpiinstance','socialactivity','socialprofile','systemuser','task','team','teammembership','territory']
len(set(tab_list).intersection(set(tab_1)))
a=set(tab_list)

# %%
a.difference(set(tab_1))
# Out:
# {'bad_record',
#  'calendar',
#  'calendarrule',
#  'globaloptionsetmetadata',
#  'optionsetmetadata',
#  'slaitem',
#  'statemetadata',
#  'statusmetadata'}

# %%
print("data_captured_on 07-16-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-16-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,106401113
# True,account,1104976
# False,activityparty,6060
# True,annotation,827212
# True,appointment,1181919
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,849941
# True,cxlvhlp_chatactivity,0
# True,cxlvhlp_chatqueuestatistic,0
# True,cxlvhlp_surveyitem,0
# True,email,466458
# True,fax,931
# False,gcct_accountresponsibleagent,19579
# False,gcct_additionalsymptomcodes,4384
# True,gcct_addportalmessage,139797
# False,gcct_arbitrationclaimprocessing,4471
# True,gcct_buybackevaluationmilestones,27660
# True,gcct_caseassignment,777370
# False,gcct_caseclassification,845
# False,gcct_casedispositiontype,838
# False,gcct_coachback,1026
# False,gcct_country,0
# False,gcct_customersatisfactiontools,1234
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,119
# True,gcct_documentcustomerrecontact,5481
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,132
# True,gcct_fieldinvolvementassistancerequest,13
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,49734
# False,gcct_genericinformationtopic,34897
# False,gcct_generictopic,145
# False,gcct_goodfaithreview,17299
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,88847
# False,gcct_loyaltycostdetails,110177
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,455
# False,gcct_materialrequestdetail,766
# False,gcct_offer,726
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,42246
# False,gcct_pcarequest,12481
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,181
# True,gcct_ravprocessingmilestones,1027747
# False,gcct_reactdata,61726
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,137307
# False,gcct_region,3
# False,gcct_rentaldetail,43718
# False,gcct_slaconfiguration,0
# False,gcct_sms,20
# True,gcct_socialmediaconversation,3
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,2654
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,84
# True,gcct_technicalassistancerequest,11908
# False,gcct_testdriverequest,893
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,265
# True,gcct_vehicle,178933
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,3333
# False,gcct_vehicleoffroad,178268
# False,gcct_vehicleowner,4170809
# False,gcct_warrantyhistory,12948
# False,gcct_warrantyloanerpartsdelay,17945
# True,gcct_warrantyloanerrequest,34582
# False,gcct_warrantyloanerrequesthistory,511
# True,globaloptionsetmetadata,11276
# True,incident,1391549
# False,incidentresolution,656483
# False,letter,6800
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,5566
# True,msdyn_survey,11
# True,msdyn_surveyinvite,13223
# True,msdyn_surveyresponse,848
# True,optionsetmetadata,15585
# True,phonecall,1496140
# False,queue,2601
# True,queueitem,645309
# False,sla,117
# False,slaitem,207
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,3068
# True,statusmetadata,3275
# True,systemuser,131476
# True,task,31224
# True,team,413
# False,teammembership,2378
# True,territory,491
# False,gcct_marketingprogram,23948
# Total: 122734360

# %%
print("data_captured_on 07-18-2019 10:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['gcct_country','gcct_demandltrtpsmclaimsprocessing','gcct_executive','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_lemonlawcriteria','gcct_loanercost','gcct_material','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_reactdata','gcct_reacttransmission','gcct_slaconfiguration','gcct_specialloanercode','gcct_symptomclassification','gcct_timezone','gcct_vehiclebrand','socialactivity','socialprofile','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-18-2019 10:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,gcct_country,0
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_executive,0
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# False,gcct_material,0
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_reactdata,65556
# False,gcct_reacttransmission,0
# False,gcct_slaconfiguration,0
# False,gcct_specialloanercode,0
# False,gcct_symptomclassification,0
# False,gcct_timezone,0
# False,gcct_vehiclebrand,0
# False,socialactivity,0
# False,socialprofile,0
# True,cxlvhlp_chatactivity,4
# True,cxlvhlp_chatqueuestatistic,2
# True,cxlvhlp_surveyitem,0
# Total: 65562

# %%
print("data_captured_on 07-22-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-22-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,106503903
# True,account,1115306
# False,activityparty,6060
# True,annotation,916791
# True,appointment,1247049
# True,businessunit,11
# True,calendar,571
# True,calendarrule,156
# True,contact,907207
# True,cxlvhlp_chatactivity,11
# True,cxlvhlp_chatqueuestatistic,2
# True,cxlvhlp_surveyitem,0
# True,email,474876
# True,fax,977
# False,gcct_accountresponsibleagent,20680
# False,gcct_additionalsymptomcodes,4793
# True,gcct_addportalmessage,145547
# False,gcct_arbitrationclaimprocessing,4633
# True,gcct_buybackevaluationmilestones,29449
# True,gcct_caseassignment,833756
# False,gcct_caseclassification,9692
# False,gcct_casedispositiontype,840
# False,gcct_coachback,1071
# False,gcct_country,0
# False,gcct_customersatisfactiontools,1321
# False,gcct_delegationofauthority,4
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_doaprogramcode,119
# True,gcct_documentcustomerrecontact,5921
# False,gcct_engine,254
# False,gcct_executive,0
# False,gcct_executiveliaison,155
# True,gcct_fieldinvolvementassistancerequest,13
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_genericinformation,57402
# False,gcct_genericinformationtopic,39863
# False,gcct_generictopic,145
# False,gcct_goodfaithreview,18426
# False,gcct_knownpartsdelay,4
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# True,gcct_loyaltyassistance,93878
# False,gcct_loyaltycostdetails,115499
# False,gcct_loyaltyprogramcode,189
# False,gcct_material,0
# False,gcct_materialrequest,504
# False,gcct_materialrequestdetail,789
# False,gcct_offer,727
# False,gcct_offerdetail,0
# False,gcct_onlinegaragevehicles,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# True,gcct_partssmeassistancerequest,44338
# False,gcct_pcarequest,13058
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_queuepriority,181
# True,gcct_ravprocessingmilestones,1073472
# False,gcct_reactdata,85296
# False,gcct_reacttransmission,0
# False,gcct_reasoncode,12
# True,gcct_recall,145536
# False,gcct_region,3
# False,gcct_rentaldetail,46197
# False,gcct_slaconfiguration,0
# False,gcct_sms,23
# True,gcct_socialmediaconversation,3
# True,gcct_socialmediamessage,3
# False,gcct_socialmediaprofile,2776
# False,gcct_specialloanercode,0
# False,gcct_state,102
# True,gcct_surveyconfiguration,40
# False,gcct_symptomclassification,0
# False,gcct_tasktype,95
# True,gcct_technicalassistancerequest,12610
# False,gcct_testdriverequest,925
# False,gcct_timezone,0
# False,gcct_userdelegationofauthority,266
# True,gcct_vehicle,230391
# False,gcct_vehiclebrand,0
# False,gcct_vehicleclass,31
# False,gcct_vehicleloyaltyallowance,3577
# False,gcct_vehicleoffroad,178268
# False,gcct_vehicleowner,4229934
# False,gcct_warrantyhistory,14085
# False,gcct_warrantyloanerpartsdelay,19081
# True,gcct_warrantyloanerrequest,36385
# False,gcct_warrantyloanerrequesthistory,1080
# True,globaloptionsetmetadata,11387
# True,incident,1467769
# False,incidentresolution,687877
# False,letter,7282
# False,msdyn_answer,145
# True,msdyn_question,56
# True,msdyn_questionresponse,6450
# True,msdyn_survey,11
# True,msdyn_surveyinvite,15228
# True,msdyn_surveyresponse,984
# True,optionsetmetadata,15691
# True,phonecall,1541365
# False,queue,2796
# True,queueitem,699907
# False,sla,123
# False,slaitem,213
# True,slakpiinstance,227624
# False,socialactivity,0
# False,socialprofile,0
# True,statemetadata,3086
# True,statusmetadata,3296
# True,systemuser,131984
# True,task,40794
# True,team,429
# False,teammembership,2378
# True,territory,498
# False,gcct_marketingprogram,23948
# Total: 123587683

# %% [markdown]
# # Columns per table

# %%
#Column per table
print("data_captured_on 07-23-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=len(sqlCtx.table(k).columns)
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 07-23-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# False,bad_record,9
# True,account,370
# False,activityparty,43
# True,annotation,64
# True,appointment,129
# True,businessunit,108
# True,calendar,29
# True,calendarrule,44
# True,contact,440
# True,cxlvhlp_chatactivity,177
# True,cxlvhlp_chatqueuestatistic,61
# True,cxlvhlp_surveyitem,58
# True,email,160
# True,fax,103
# False,gcct_accountresponsibleagent,64
# False,gcct_additionalsymptomcodes,74
# True,gcct_addportalmessage,131
# False,gcct_arbitrationclaimprocessing,277
# True,gcct_buybackevaluationmilestones,174
# True,gcct_caseassignment,139
# False,gcct_caseclassification,123
# False,gcct_casedispositiontype,78
# False,gcct_coachback,128
# False,gcct_country,59
# False,gcct_customersatisfactiontools,151
# False,gcct_delegationofauthority,90
# False,gcct_demandltrtpsmclaimsprocessing,169
# False,gcct_doaprogramcode,59
# True,gcct_documentcustomerrecontact,125
# False,gcct_engine,53
# False,gcct_executive,62
# False,gcct_executiveliaison,124
# True,gcct_fieldinvolvementassistancerequest,164
# False,gcct_fmcccontract,101
# False,gcct_fulfillmentvendor,53
# False,gcct_genericinformation,122
# False,gcct_genericinformationtopic,67
# False,gcct_generictopic,52
# False,gcct_goodfaithreview,188
# False,gcct_knownpartsdelay,71
# False,gcct_lemonlawcriteria,63
# False,gcct_loanercost,70
# True,gcct_loyaltyassistance,195
# False,gcct_loyaltycostdetails,111
# False,gcct_loyaltyprogramcode,62
# False,gcct_material,77
# False,gcct_materialrequest,132
# False,gcct_materialrequestdetail,63
# False,gcct_offer,137
# False,gcct_offerdetail,74
# False,gcct_onlinegaragevehicles,83
# False,gcct_partsorderstatus,141
# False,gcct_partsordersystems,53
# True,gcct_partssmeassistancerequest,212
# False,gcct_pcarequest,168
# False,gcct_priordealerdecision,122
# False,gcct_qaincident,74
# False,gcct_qamonitoring,61
# False,gcct_queuepriority,60
# True,gcct_ravprocessingmilestones,209
# False,gcct_reactdata,113
# False,gcct_reacttransmission,147
# False,gcct_reasoncode,55
# True,gcct_recall,121
# False,gcct_region,53
# False,gcct_rentaldetail,182
# False,gcct_slaconfiguration,75
# False,gcct_sms,118
# True,gcct_socialmediaconversation,117
# True,gcct_socialmediamessage,59
# False,gcct_socialmediaprofile,62
# False,gcct_specialloanercode,71
# False,gcct_state,56
# True,gcct_surveyconfiguration,77
# False,gcct_symptomclassification,113
# False,gcct_tasktype,52
# True,gcct_technicalassistancerequest,171
# False,gcct_testdriverequest,183
# False,gcct_timezone,55
# False,gcct_userdelegationofauthority,65
# True,gcct_vehicle,120
# False,gcct_vehiclebrand,52
# False,gcct_vehicleclass,60
# False,gcct_vehicleloyaltyallowance,147
# False,gcct_vehicleoffroad,166
# False,gcct_vehicleowner,104
# False,gcct_warrantyhistory,70
# False,gcct_warrantyloanerpartsdelay,69
# True,gcct_warrantyloanerrequest,208
# False,gcct_warrantyloanerrequesthistory,67
# True,globaloptionsetmetadata,16
# True,incident,383
# False,incidentresolution,128
# False,letter,101
# False,msdyn_answer,72
# True,msdyn_question,154
# True,msdyn_questionresponse,75
# True,msdyn_survey,182
# True,msdyn_surveyinvite,167
# True,msdyn_surveyresponse,210
# True,optionsetmetadata,17
# True,phonecall,122
# False,queue,87
# True,queueitem,75
# False,sla,73
# False,slaitem,65
# True,slakpiinstance,64
# False,socialactivity,112
# False,socialprofile,63
# True,statemetadata,16
# True,statusmetadata,17
# True,systemuser,195
# True,task,130
# True,team,116
# False,teammembership,18
# True,territory,69
# False,gcct_marketingprogram,61
# Total: 12656

# %% [markdown]
# # Include visibility

# %%
#Include visibility
print("data_captured_on 08-02-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows),Visibility")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata','gcct_caseclassification','gcct_casedispositiontype','gcct_country','gcct_region','gcct_symptomclassification','gcct_tasktype','gcct_vehiclebrand','gcct_vehicleclass','letter','msdyn_answer','queue']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
visible=['account','activityparty','annotation','appointment','bad_record','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_marketingprogram','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_state','gcct_surveyconfiguration','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                if k in visible:
                    print("True,"+str(k)+","+str(g1)+","+"True")
                else:
                    print("True,"+str(k)+","+str(g1)+","+"False")
            elif k in visible:            
                print("False,"+str(k)+","+str(g1)+","+"True")
            else:
                print("False,"+str(k)+","+str(g1)+","+"False")
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 08-02-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows),Visibility
# False,bad_record,106804022,True
# True,account,1136486,True
# False,activityparty,6060,True
# True,annotation,1176461,True
# True,appointment,1451983,True
# True,businessunit,11,True
# True,calendar,571,True
# True,calendarrule,156,True
# True,contact,1066780,True
# True,cxlvhlp_chatactivity,8311,True
# True,cxlvhlp_chatqueuestatistic,2780,True
# True,cxlvhlp_surveyitem,0,False
# True,email,514386,True
# True,fax,1118,True
# False,gcct_accountresponsibleagent,22020,True
# False,gcct_additionalsymptomcodes,5848,True
# True,gcct_addportalmessage,164034,True
# False,gcct_arbitrationclaimprocessing,5231,True
# True,gcct_buybackevaluationmilestones,33882,True
# True,gcct_caseassignment,986485,True
# False,gcct_caseclassification,9978,True
# False,gcct_casedispositiontype,840,True
# False,gcct_coachback,1177,True
# False,gcct_country,0,False
# False,gcct_customersatisfactiontools,1560,True
# False,gcct_delegationofauthority,4,True
# False,gcct_demandltrtpsmclaimsprocessing,0,False
# False,gcct_doaprogramcode,121,True
# True,gcct_documentcustomerrecontact,7015,True
# False,gcct_engine,254,True
# False,gcct_executive,0,False
# False,gcct_executiveliaison,196,True
# True,gcct_fieldinvolvementassistancerequest,13,True
# False,gcct_fmcccontract,0,False
# False,gcct_fulfillmentvendor,0,False
# False,gcct_genericinformation,76913,True
# False,gcct_genericinformationtopic,52306,True
# False,gcct_generictopic,146,True
# False,gcct_goodfaithreview,21106,True
# False,gcct_knownpartsdelay,11359,True
# False,gcct_lemonlawcriteria,0,False
# False,gcct_loanercost,0,False
# True,gcct_loyaltyassistance,109314,True
# False,gcct_loyaltycostdetails,130398,True
# False,gcct_loyaltyprogramcode,189,True
# False,gcct_material,0,False
# False,gcct_materialrequest,705,True
# False,gcct_materialrequestdetail,919,True
# False,gcct_offer,728,True
# False,gcct_offerdetail,0,False
# False,gcct_onlinegaragevehicles,3955,False
# False,gcct_partsorderstatus,0,False
# False,gcct_partsordersystems,0,False
# True,gcct_partssmeassistancerequest,51977,True
# False,gcct_pcarequest,15412,True
# False,gcct_priordealerdecision,0,False
# False,gcct_qaincident,0,False
# False,gcct_qamonitoring,0,False
# False,gcct_queuepriority,306,True
# True,gcct_ravprocessingmilestones,1258211,True
# False,gcct_reactdata,205625,True
# False,gcct_reacttransmission,1,False
# False,gcct_reasoncode,12,True
# True,gcct_recall,164016,True
# False,gcct_region,3,True
# False,gcct_rentaldetail,54855,True
# False,gcct_slaconfiguration,0,False
# False,gcct_sms,30,True
# True,gcct_socialmediaconversation,5,True
# True,gcct_socialmediamessage,5,True
# False,gcct_socialmediaprofile,3482,True
# False,gcct_specialloanercode,0,False
# False,gcct_state,102,True
# True,gcct_surveyconfiguration,44,True
# False,gcct_symptomclassification,0,False
# False,gcct_tasktype,96,True
# True,gcct_technicalassistancerequest,14802,True
# False,gcct_testdriverequest,1120,True
# False,gcct_timezone,0,False
# False,gcct_userdelegationofauthority,268,True
# True,gcct_vehicle,375716,True
# False,gcct_vehiclebrand,0,False
# False,gcct_vehicleclass,31,True
# False,gcct_vehicleloyaltyallowance,4115,True
# False,gcct_vehicleoffroad,180112,True
# False,gcct_vehicleowner,4385982,True
# False,gcct_warrantyhistory,17003,True
# False,gcct_warrantyloanerpartsdelay,22277,True
# True,gcct_warrantyloanerrequest,42029,True
# False,gcct_warrantyloanerrequesthistory,2552,True
# True,globaloptionsetmetadata,11405,True
# True,incident,1693864,True
# False,incidentresolution,805160,True
# False,letter,7857,True
# False,msdyn_answer,145,True
# True,msdyn_question,56,True
# True,msdyn_questionresponse,10425,True
# True,msdyn_survey,11,True
# True,msdyn_surveyinvite,23897,True
# True,msdyn_surveyresponse,1552,True
# True,optionsetmetadata,15691,True
# True,phonecall,1683434,True
# False,queue,3299,True
# True,queueitem,836322,True
# False,sla,159,True
# False,slaitem,235,True
# True,slakpiinstance,227624,True
# False,socialactivity,0,False
# False,socialprofile,0,False
# True,statemetadata,3086,True
# True,statusmetadata,3296,True
# True,systemuser,133609,True
# True,task,45719,True
# True,team,459,True
# False,teammembership,2378,True
# True,territory,498,True
# False,gcct_marketingprogram,23948,True
# Total: 126150139

# %%
#Only consider empty tables

# %%
print("data_captured_on 08-05-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata','gcct_caseclassification','gcct_casedispositiontype','gcct_country','gcct_region','gcct_symptomclassification','gcct_tasktype','gcct_vehiclebrand','gcct_vehicleclass','letter','msdyn_answer','queue']
tab_list=['cxlvhlp_surveyitem','gcct_country','gcct_demandltrtpsmclaimsprocessing','gcct_executive','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_lemonlawcriteria','gcct_loanercost','gcct_material','gcct_offerdetail','gcct_partsorderstatus','gcct_partsordersystems','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_slaconfiguration','gcct_specialloanercode','gcct_symptomclassification','gcct_timezone','gcct_vehiclebrand','socialactivity','socialprofile']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 08-05-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# True,cxlvhlp_surveyitem,0
# False,gcct_country,0
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_executive,0
# False,gcct_fmcccontract,0
# False,gcct_fulfillmentvendor,0
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# False,gcct_material,0
# False,gcct_offerdetail,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_slaconfiguration,0
# False,gcct_specialloanercode,0
# False,gcct_symptomclassification,0
# False,gcct_timezone,0
# False,gcct_vehiclebrand,0
# False,socialactivity,0
# False,socialprofile,0
# Total: 0

# %%
print("data_captured_on 09-12-2019 11:00 AM")
print("Environment: prod")
print("Priority,Table,Data(rows)")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata','gcct_caseclassification','gcct_casedispositiontype','gcct_country','gcct_region','gcct_symptomclassification','gcct_tasktype','gcct_vehiclebrand','gcct_vehicleclass','letter','msdyn_answer','queue']
tab_list=['cxlvhlp_surveyitem','gcct_country','gcct_demandltrtpsmclaimsprocessing','gcct_executive','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_lemonlawcriteria','gcct_loanercost','gcct_material','gcct_offerdetail','gcct_partsorderstatus','gcct_partsordersystems','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_slaconfiguration','gcct_specialloanercode','gcct_symptomclassification','gcct_timezone','gcct_vehiclebrand','socialactivity','socialprofile']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                print("True,"+str(k)+","+str(g1))
            else:
                print("False,"+str(k)+","+str(g1))
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 09-12-2019 11:00 AM
# Environment: prod
# Priority,Table,Data(rows)
# True,cxlvhlp_surveyitem,0
# True,gcct_country,0
# False,gcct_demandltrtpsmclaimsprocessing,0
# False,gcct_executive,0
# False,gcct_fmcccontract,44
# False,gcct_fulfillmentvendor,1
# False,gcct_lemonlawcriteria,0
# False,gcct_loanercost,0
# False,gcct_material,273
# False,gcct_offerdetail,0
# False,gcct_partsorderstatus,0
# False,gcct_partsordersystems,0
# False,gcct_priordealerdecision,0
# False,gcct_qaincident,0
# False,gcct_qamonitoring,0
# False,gcct_slaconfiguration,0
# False,gcct_specialloanercode,0
# True,gcct_symptomclassification,0
# False,gcct_timezone,0
# True,gcct_vehiclebrand,0
# False,socialactivity,0
# False,socialprofile,0
# Total: 318

# %%
#Include visibility
print("data_captured_on 08-14-2019 12:00 PM")
print("Environment: prod")
print("Priority,Table,Data(rows),Visibility")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata','gcct_caseclassification','gcct_casedispositiontype','gcct_country','gcct_region','gcct_symptomclassification','gcct_tasktype','gcct_vehiclebrand','gcct_vehicleclass','letter','msdyn_answer','queue']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
visible=['account','activityparty','annotation','appointment','bad_record','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_marketingprogram','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_state','gcct_surveyconfiguration','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                if k in visible:
                    print("True,"+str(k)+","+str(g1)+","+"True")
                else:
                    print("True,"+str(k)+","+str(g1)+","+"False")
            elif k in visible:            
                print("False,"+str(k)+","+str(g1)+","+"True")
            else:
                print("False,"+str(k)+","+str(g1)+","+"False")
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 08-14-2019 12:00 PM
# Environment: prod
# Priority,Table,Data(rows),Visibility
# False,bad_record,107116323,True
# True,account,1425393,True
# False,activityparty,6060,True
# True,annotation,1420563,True
# True,appointment,1641226,True
# True,businessunit,11,True
# True,calendar,571,True
# True,calendarrule,156,True
# True,contact,1220716,True
# True,cxlvhlp_chatactivity,32164,True
# True,cxlvhlp_chatqueuestatistic,8905,True
# True,cxlvhlp_surveyitem,0,False
# True,email,553566,True
# True,fax,1596,True
# False,gcct_accountresponsibleagent,23475,True
# False,gcct_additionalsymptomcodes,6897,True
# True,gcct_addportalmessage,182980,True
# False,gcct_arbitrationclaimprocessing,6042,True
# True,gcct_buybackevaluationmilestones,37971,True
# True,gcct_caseassignment,1166407,True
# True,gcct_caseclassification,10437,True
# True,gcct_casedispositiontype,1091,True
# False,gcct_coachback,1276,True
# True,gcct_country,0,False
# False,gcct_customersatisfactiontools,1768,True
# False,gcct_delegationofauthority,30,True
# False,gcct_demandltrtpsmclaimsprocessing,0,False
# False,gcct_doaprogramcode,206,True
# True,gcct_documentcustomerrecontact,8001,True
# False,gcct_engine,254,True
# False,gcct_executive,0,False
# False,gcct_executiveliaison,221,True
# True,gcct_fieldinvolvementassistancerequest,19,True
# False,gcct_fmcccontract,0,False
# False,gcct_fulfillmentvendor,1,False
# False,gcct_genericinformation,101255,True
# False,gcct_genericinformationtopic,67617,True
# False,gcct_generictopic,147,True
# False,gcct_goodfaithreview,23645,True
# False,gcct_knownpartsdelay,40117,True
# False,gcct_lemonlawcriteria,0,False
# False,gcct_loanercost,0,False
# True,gcct_loyaltyassistance,124174,True
# False,gcct_loyaltycostdetails,144393,True
# False,gcct_loyaltyprogramcode,192,True
# False,gcct_material,273,False
# False,gcct_materialrequest,888,True
# False,gcct_materialrequestdetail,1026,True
# False,gcct_offer,728,True
# False,gcct_offerdetail,0,False
# False,gcct_onlinegaragevehicles,13521,False
# False,gcct_partsorderstatus,0,False
# False,gcct_partsordersystems,0,False
# True,gcct_partssmeassistancerequest,58444,True
# False,gcct_pcarequest,17777,True
# False,gcct_priordealerdecision,0,False
# False,gcct_qaincident,0,False
# False,gcct_qamonitoring,0,False
# False,gcct_queuepriority,309,True
# True,gcct_ravprocessingmilestones,1441983,True
# False,gcct_reactdata,343648,True
# False,gcct_reacttransmission,2,False
# False,gcct_reasoncode,12,True
# True,gcct_recall,182542,True
# True,gcct_region,3,True
# False,gcct_rentaldetail,62383,True
# False,gcct_slaconfiguration,0,False
# False,gcct_sms,36,True
# True,gcct_socialmediaconversation,11,True
# True,gcct_socialmediamessage,9,True
# False,gcct_socialmediaprofile,3987,True
# False,gcct_specialloanercode,0,False
# False,gcct_state,102,True
# True,gcct_surveyconfiguration,44,True
# True,gcct_symptomclassification,0,False
# True,gcct_tasktype,96,True
# True,gcct_technicalassistancerequest,16926,True
# False,gcct_testdriverequest,1293,True
# False,gcct_timezone,0,False
# False,gcct_userdelegationofauthority,489,True
# True,gcct_vehicle,517820,True
# True,gcct_vehiclebrand,0,False
# True,gcct_vehicleclass,2457,True
# False,gcct_vehicleloyaltyallowance,4488,True
# False,gcct_vehicleoffroad,186067,True
# False,gcct_vehicleowner,4517703,True
# False,gcct_warrantyhistory,19696,True
# False,gcct_warrantyloanerpartsdelay,24713,True
# True,gcct_warrantyloanerrequest,46073,True
# False,gcct_warrantyloanerrequesthistory,4278,True
# True,globaloptionsetmetadata,11405,True
# True,incident,1939678,True
# False,incidentresolution,1181040,True
# True,letter,8207,True
# True,msdyn_answer,145,True
# True,msdyn_question,56,True
# True,msdyn_questionresponse,19489,True
# True,msdyn_survey,11,True
# True,msdyn_surveyinvite,41419,True
# True,msdyn_surveyresponse,2833,True
# True,optionsetmetadata,15700,True
# True,phonecall,1826217,True
# True,queue,3536,True
# True,queueitem,1005573,True
# False,sla,159,True
# False,slaitem,235,True
# True,slakpiinstance,227624,True
# False,socialactivity,0,False
# False,socialprofile,0,False
# True,statemetadata,3086,True
# True,statusmetadata,3296,True
# True,systemuser,133987,True
# True,task,52868,True
# True,team,483,True
# False,teammembership,2378,True
# True,territory,498,True
# False,gcct_marketingprogram,23948,True
# Total: 129349564

# %%
#Include visibility
print("data_captured_on 09-12-2019 11:00 PM")
print("Environment: prod")
print("Priority,Table,Data(rows),Visibility")
g2=0
priority_list=['account','appointment','gcct_buybackevaluationmilestones','calendar','calendarrule','incident','gcct_caseassignment','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','gcct_documentcustomerrecontact','email','fax','gcct_fieldinvolvementassistancerequest','gcct_loyaltyassistance','optionsetmetadata','gcct_partssmeassistancerequest','phonecall','msdyn_question','msdyn_questionresponse','queueitem','gcct_ravprocessingmilestones','gcct_recall','slakpiinstance','msdyn_survey','msdyn_surveyinvite','gcct_surveyconfiguration','cxlvhlp_surveyitem','msdyn_surveyresponse','task','team','gcct_technicalassistancerequest','systemuser','annotation','contact','businessunit','gcct_addportalmessage','gcct_socialmediaconversation','gcct_socialmediamessage','territory','msdyn_questionresponse','msdyn_question','gcct_vehicle','gcct_warrantyloanerrequest','globaloptionsetmetadata','statemetadata','statusmetadata','gcct_caseclassification','gcct_casedispositiontype','gcct_country','gcct_region','gcct_symptomclassification','gcct_tasktype','gcct_vehiclebrand','gcct_vehicleclass','letter','msdyn_answer','queue']
tab_list=['bad_record','account','activityparty','annotation','appointment','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','cxlvhlp_surveyitem','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_country','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_demandltrtpsmclaimsprocessing','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executive','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_fmcccontract','gcct_fulfillmentvendor','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_lemonlawcriteria','gcct_loanercost','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_material','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_offerdetail','gcct_onlinegaragevehicles','gcct_partsorderstatus','gcct_partsordersystems','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_priordealerdecision','gcct_qaincident','gcct_qamonitoring','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reacttransmission','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_slaconfiguration','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_specialloanercode','gcct_state','gcct_surveyconfiguration','gcct_symptomclassification','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_timezone','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehiclebrand','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','socialactivity','socialprofile','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory','gcct_marketingprogram']
visible=['account','activityparty','annotation','appointment','bad_record','businessunit','calendar','calendarrule','contact','cxlvhlp_chatactivity','cxlvhlp_chatqueuestatistic','email','fax','gcct_accountresponsibleagent','gcct_additionalsymptomcodes','gcct_addportalmessage','gcct_arbitrationclaimprocessing','gcct_buybackevaluationmilestones','gcct_caseassignment','gcct_caseclassification','gcct_casedispositiontype','gcct_coachback','gcct_customersatisfactiontools','gcct_delegationofauthority','gcct_doaprogramcode','gcct_documentcustomerrecontact','gcct_engine','gcct_executiveliaison','gcct_fieldinvolvementassistancerequest','gcct_genericinformation','gcct_genericinformationtopic','gcct_generictopic','gcct_goodfaithreview','gcct_knownpartsdelay','gcct_loyaltyassistance','gcct_loyaltycostdetails','gcct_loyaltyprogramcode','gcct_marketingprogram','gcct_materialrequest','gcct_materialrequestdetail','gcct_offer','gcct_partssmeassistancerequest','gcct_pcarequest','gcct_queuepriority','gcct_ravprocessingmilestones','gcct_reactdata','gcct_reasoncode','gcct_recall','gcct_region','gcct_rentaldetail','gcct_sms','gcct_socialmediaconversation','gcct_socialmediamessage','gcct_socialmediaprofile','gcct_state','gcct_surveyconfiguration','gcct_tasktype','gcct_technicalassistancerequest','gcct_testdriverequest','gcct_userdelegationofauthority','gcct_vehicle','gcct_vehicleclass','gcct_vehicleloyaltyallowance','gcct_vehicleoffroad','gcct_vehicleowner','gcct_warrantyhistory','gcct_warrantyloanerpartsdelay','gcct_warrantyloanerrequest','gcct_warrantyloanerrequesthistory','globaloptionsetmetadata','incident','incidentresolution','letter','msdyn_answer','msdyn_question','msdyn_questionresponse','msdyn_survey','msdyn_surveyinvite','msdyn_surveyresponse','optionsetmetadata','phonecall','queue','queueitem','sla','slaitem','slakpiinstance','statemetadata','statusmetadata','systemuser','task','team','teammembership','territory']
#for m in sqlContext.tables("dsc60230_gcct_tz_db").select('tableName').where("tableName not like '%dup%'").where("tableName not like '%bkp%'").where("tableName not like '%temptz%'").collect():
            #k=m.asDict().values()[0].encode('utf-8')
for k in tab_list:
            g1=sqlCtx.table(k).count()
            if k in priority_list:
                if k in visible:
                    print("True,"+str(k)+","+str(g1)+","+"True")
                else:
                    print("True,"+str(k)+","+str(g1)+","+"False")
            elif k in visible:            
                print("False,"+str(k)+","+str(g1)+","+"True")
            else:
                print("False,"+str(k)+","+str(g1)+","+"False")
            g2=g2+g1


print("Total: "+str(g2))
# Out:
# data_captured_on 09-12-2019 11:00 PM
# Environment: prod
# Priority,Table,Data(rows),Visibility
# False,bad_record,107712102,True
# True,account,1624332,True
# False,activityparty,6060,True
# True,annotation,1951376,True
# True,appointment,1921699,True
# True,businessunit,11,True
# True,calendar,571,True
# True,calendarrule,156,True
# True,contact,1628298,True
# True,cxlvhlp_chatactivity,86874,True
# True,cxlvhlp_chatqueuestatistic,26846,True
# True,cxlvhlp_surveyitem,0,False
# True,email,614890,True
# True,fax,1745,True
# False,gcct_accountresponsibleagent,25533,True
# False,gcct_additionalsymptomcodes,9576,True
# True,gcct_addportalmessage,203771,True
# False,gcct_arbitrationclaimprocessing,6377,True
# True,gcct_buybackevaluationmilestones,45834,True
# True,gcct_caseassignment,1684445,True
# True,gcct_caseclassification,10491,True
# True,gcct_casedispositiontype,1093,True
# False,gcct_coachback,1407,True
# True,gcct_country,0,False
# False,gcct_customersatisfactiontools,2204,True
# False,gcct_delegationofauthority,35,True
# False,gcct_demandltrtpsmclaimsprocessing,0,False
# False,gcct_doaprogramcode,212,True
# True,gcct_documentcustomerrecontact,10695,True
# False,gcct_engine,254,True
# False,gcct_executive,0,False
# False,gcct_executiveliaison,295,True
# True,gcct_fieldinvolvementassistancerequest,186,True
# False,gcct_fmcccontract,44,False
# False,gcct_fulfillmentvendor,1,False
# False,gcct_genericinformation,146638,True
# False,gcct_genericinformationtopic,98255,True
# False,gcct_generictopic,147,True
# False,gcct_goodfaithreview,28973,True
# False,gcct_knownpartsdelay,88483,True
# False,gcct_lemonlawcriteria,0,False
# False,gcct_loanercost,0,False
# True,gcct_loyaltyassistance,455081,True
# False,gcct_loyaltycostdetails,179020,True
# False,gcct_loyaltyprogramcode,192,True
# False,gcct_material,273,False
# False,gcct_materialrequest,1198,True
# False,gcct_materialrequestdetail,1205,True
# False,gcct_offer,728,True
# False,gcct_offerdetail,0,False
# False,gcct_onlinegaragevehicles,40314,False
# False,gcct_partsorderstatus,0,False
# False,gcct_partsordersystems,0,False
# True,gcct_partssmeassistancerequest,65192,True
# False,gcct_pcarequest,18964,True
# False,gcct_priordealerdecision,0,False
# False,gcct_qaincident,0,False
# False,gcct_qamonitoring,0,False
# False,gcct_queuepriority,2945,True
# True,gcct_ravprocessingmilestones,1532757,True
# False,gcct_reactdata,513662,True
# False,gcct_reacttransmission,2,False
# False,gcct_reasoncode,12,True
# True,gcct_recall,225151,True
# True,gcct_region,3,True
# False,gcct_rentaldetail,71903,True
# False,gcct_slaconfiguration,0,False
# False,gcct_sms,58,True
# True,gcct_socialmediaconversation,11,True
# True,gcct_socialmediamessage,9,True
# False,gcct_socialmediaprofile,5498,True
# False,gcct_specialloanercode,0,False
# False,gcct_state,102,True
# True,gcct_surveyconfiguration,44,True
# True,gcct_symptomclassification,0,False
# True,gcct_tasktype,98,True
# True,gcct_technicalassistancerequest,20189,True
# False,gcct_testdriverequest,1539,True
# False,gcct_timezone,0,False
# False,gcct_userdelegationofauthority,746,True
# True,gcct_vehicle,832505,True
# True,gcct_vehiclebrand,0,False
# True,gcct_vehicleclass,2464,True
# False,gcct_vehicleloyaltyallowance,5183,True
# False,gcct_vehicleoffroad,277234,True
# False,gcct_vehicleowner,4905021,True
# False,gcct_warrantyhistory,25478,True
# False,gcct_warrantyloanerpartsdelay,30428,True
# True,gcct_warrantyloanerrequest,55466,True
# False,gcct_warrantyloanerrequesthistory,9157,True
# True,globaloptionsetmetadata,13044,True
# True,incident,2690923,True
# False,incidentresolution,1479342,True
# True,letter,8495,True
# True,msdyn_answer,145,True
# True,msdyn_question,56,True
# True,msdyn_questionresponse,42589,True
# True,msdyn_survey,12,True
# True,msdyn_surveyinvite,89508,True
# True,msdyn_surveyresponse,6128,True
# True,optionsetmetadata,20878,True
# True,phonecall,2104560,True
# True,queue,4752,True
# True,queueitem,1567261,True
# False,sla,182,True
# False,slaitem,245,True
# True,slakpiinstance,227624,True
# False,socialactivity,0,False
# False,socialprofile,0,False
# True,statemetadata,3473,True
# True,statusmetadata,3731,True
# True,systemuser,135707,True
# True,task,66880,True
# True,team,613,True
# False,teammembership,2378,True
# True,territory,520,True
# False,gcct_marketingprogram,23948,True
# Total: 135712735
